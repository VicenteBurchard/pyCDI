# %% [markdown]
# # Processing the Composite Drought Index using python and STAC
#
# This notebook will introduce the the **Composite Drought Index (CDI)** and how it can be readily estimated using python and open-source satellite products readily available through the **SpatioTemporal Asset Catalogs (STAC)** framework.
#
# The CDI incorporates **three main components** that impact drought severity: 1) precipitation deficit, 2) excess temperature and 3) vegetation response, incorporating within the CDI three drought indices:
#
# - Precipiation Drought Index (PDI)
# - Temperature Drought Index (TDI)
# - Vegetation Drought Index (VDI)
#
# In this example, we will use [ERA5-Land](https://cds.climate.copernicus.eu/cdsapp#!/dataset/reanalysis-era5-land?tab=overview) from the Copernicus Climate Change Service to calculate the **PDI** and **TDI**, while we will use [MODIS 8-day Surface Reflectance](https://lpdaac.usgs.gov/products/mod09gqv061/) product to calculate the Normalize-Difference Vegetation Index (NDVI) as the response variable to produce the **VDI**.
#
# The general form of each of the drought indices is:
#
# ![equation](images/DroughtIndex_equation.png)
#
# where IP is the interest period, LTM is the long-term mean and the right side refers to the ratio between the run length of continuous deficit (in the case of precipiration and NDVI) or excess (in the case of temperature) compared to the long-term-mean.
#
# In this example, we use a monthly time step and the interest period uses a the 3-month moving window .
#
# We will produce a CDI time series over the Borena region in Southern Ethiopia, which is particularly vulnerable to drought and their impacts. This notebook will showcase the use of open-source satellite-based datasets readily available in the STAC to produce an early warning system for drought events.
#
# ![study area](images/Borena_LULC_DEM.png)
#
# This notebook will follow the following structure:
#
# ## General structure of notebook
#
# ### 1. Precipiation Drought Index (PDI)
#
# ##### 1.1 Long-term-mean (LTM)
# ##### 1.2 Actual conditions over the interest period (IP)
# ##### 1.3 PDI calculation
#
# ### 2. Temperature Drought Index (TDI)
#
# ##### 2.1 Long-term-mean (LTM)
# ##### 2.2 Actual conditions over the interest period (IP)
# ##### 2.3 TDI calculation
#
# ### 3. Vegetation Drought Index (VDI)
#
# ##### 3.1 Computing monthly mean NDVI
# ##### 3.2 Long-term-mean (LTM)
# ##### 3.3 Actual conditions over the interest period (IP)
# ##### 3.4 VDI calculation
#
# ### 4. Composite Drought Index (CDI)
# ##### 4.1 Merging drought indices and calculating CDI
# ##### 4.2 Visualizing results with leafmap
#
#
# ## Acknowledgements
#
# This work was done within the [EO Africa](https://www.eoafrica-rd.org/) [R&D research projects](https://www.eoafrica-rd.org/research/research-projects-2023-2024/) funded by the European Space Agency (ESA)
#
# ![EO AFRICA](images/EOAFRICA-logo.png)

# %% [markdown]
# ## 0. import libraries
# Before begining, make sure to view the readme and install all the dependencies needed to run this code

# %%
from pathlib import Path
from cubo import cubo
from rasterio.crs import CRS
import gdal_utils as gu
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pyCDI import cdi_functions as cdi
import xarray as xr
import ee
print('libraries imported correctly')
# Out:
# libraries imported correctly

# %% [markdown]
# ### 1. PDI estimation
#
# Monthly precipitation is obtained from the monthly [ERA5-Land dataset](https://radiantearth.github.io/stac-browser/#/external/storage.googleapis.com/earthengine-stac/catalog/ECMWF/ECMWF_ERA5_MONTHLY.json) available from the STAC images available from the google earth engine repositories
#
# We will extract the data using [Cubo](https://github.com/ESDS-Leipzig/cubo), which facilitates the manipulation of geospatial datasets in STAC format. You will need to authenticate first your GEE account using ee.Authenticate()

# %%
ee.Authenticate()
# Out:
# True

# %% [markdown]
# Once authenticated, initialize the high volume endpoint from Google Earth Engine:

# %%
ee.Initialize(opt_url='https://earthengine-highvolume.googleapis.com')

# %% [markdown]
# #### Acquire STAC data using cubo
# As first step, we will need to extract the dataset from GEE and use Cubo to import it as an xarray dataset. We need to specify the start and end date and also geographical location of center of the area of interest. We will take advantage to already import both Precipitation and air temperature.

# %%
# select start and end date
start_date = '2001-01-01'
end_date = '2022-12-31'

# select centroid of area of interest (Borena Region, Ethiopia)
lon = 38.18749189093533
lat = 4.428931591589981


# get monthly precipitation and air temperature from ERA5-Land STAC from GEE
da = cubo.create(
     lat=lat,
     lon=lon,
     collection="ECMWF/ERA5_LAND/MONTHLY_AGGR", # ID of the GEE collection
     bands=["total_precipitation_sum", "temperature_2m"], # Bands to retrieve
     start_date=start_date,
     end_date=end_date, # End date of the cube (remember in GEE this date is not included)
     edge_size=70,
     resolution=10000,
     gee=True # Set to True
)

da = da.assign_coords(epsg=da.attrs['epsg'])
da = da.rio.write_crs(f"EPSG:{da['epsg'].data}")

# get georeferencing metadata
epsg_code = da.attrs['epsg']
center_x = da.attrs['central_x']
center_y = da.attrs['central_y']
width = da.attrs['edge_size']
pixel_size = da.attrs['resolution']

# get geotransform and projection info to be used later to save outputs as rasters
gt = gu.calculate_geotransform(center_x, center_y, pixel_size, width, width)
proj = CRS.from_epsg(epsg_code).wkt

# %% [markdown]
# You can inspect the Cubo xarray dataset

# %%
da
# Out:
# <xarray.DataArray 'ECMWF/ERA5_LAND/MONTHLY_AGGR' (time: 264, band: 2, y: 70,
#                                                   x: 70)>
# dask.array<transpose, shape=(264, 2, 70, 70), dtype=float32, chunksize=(48, 1, 70, 70), chunktype=numpy.ndarray>
# Coordinates:
#   * time                       (time) datetime64[ns] 2001-01-01 ... 2022-12-01
#   * x                          (x) float64 6.5e+04 7.5e+04 ... 7.45e+05 7.55e+05
#   * y                          (y) float64 1.45e+05 1.55e+05 ... 8.35e+05
#   * band                       (band) object 'total_precipitation_sum' 'tempe...
#     cubo:distance_from_center  (y, x) float64 4.875e+05 4.805e+05 ... 4.883e+05
#     epsg                       int64 32637
#     spatial_ref                int64 0
# Attributes:
#     collection:           ECMWF/ERA5_LAND/MONTHLY_AGGR
#     stac:                 https://earthengine-stac.storage.googleapis.com/cat...
#     epsg:                 32637
#     resolution:           10000
#     edge_size:            70
#     edge_size_m:          700000
#     central_lat:          4.428931591589981
#     central_lon:          38.18749189093533
#     central_y:            489589.15404775797
#     central_x:            409853.36537346453
#     time_coverage_start:  2001-01-01
#     time_coverage_end:    2022-12-31

# %% [markdown]
# #### 1.1 calculation of Long-term-mean (LTM) of Precipitation

# %%
# select precipitation and slice the xarray DataArray
var = "total_precipitation_sum"
da_var = da.sel(band=var)
# get all time steps
time_steps = pd.to_datetime(da['time'].values)
years = np.array(time_steps.year)

# select outfolder to save LTM inputs
outfolder_ltm = Path() / 'CDI_data' / 'inputs_downloads' / 'Precip' / 'LTM'

# %% [markdown]
# Since calculating the LTM may take some time, if the LTM were already produced you can directly import them by setting ltm_produced=True. If it is the first time calculating or you want to calculate it again set ltm_produced=False

# %%
ltm_produced = False
if ltm_produced:
    # get mean data
    mean_ltm_folder = outfolder_ltm / 'mean'
    mean_img_list = sorted(list(mean_ltm_folder.glob('*.tif')))
    P_ltm_ds = gu.rasterlist2dict(mean_img_list)
    
    # get RL data
    rl_img_folder = outfolder_ltm / 'RL'
    rl_img_list = sorted(list(rl_img_folder.glob('*.tif')))
    P_rl_ltm_ds = gu.rasterlist2dict(rl_img_list)

else:
    P_ltm_ds, P_rl_ltm_ds = cdi.compute_ltm(da_var, time_steps, gt, proj, outfolder_ltm, unit_scaler=1000, deficit=True, gee=True)
# Out:
# Processing Long-Term-Mean (LTM) for Month 1
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/mean/Mean_LTM_1.tif
# 	Processing deficit run length for year 2001
# /Users/vicenteburchard/miniconda3/envs/sentseb/lib/python3.9/site-packages/osgeo/gdal.py:312: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/RL/RL_LTM_1.tif
#
# Processing Long-Term-Mean (LTM) for Month 2
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/mean/Mean_LTM_2.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/RL/RL_LTM_2.tif
#
# Processing Long-Term-Mean (LTM) for Month 3
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/mean/Mean_LTM_3.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/RL/RL_LTM_3.tif
#
# Processing Long-Term-Mean (LTM) for Month 4
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/mean/Mean_LTM_4.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/RL/RL_LTM_4.tif
#
# Processing Long-Term-Mean (LTM) for Month 5
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/mean/Mean_LTM_5.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/RL/RL_LTM_5.tif
#
# Processing Long-Term-Mean (LTM) for Month 6
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/mean/Mean_LTM_6.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/RL/RL_LTM_6.tif
#
# Processing Long-Term-Mean (LTM) for Month 7
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/mean/Mean_LTM_7.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/RL/RL_LTM_7.tif
#
# Processing Long-Term-Mean (LTM) for Month 8
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/mean/Mean_LTM_8.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/RL/RL_LTM_8.tif
#
# Processing Long-Term-Mean (LTM) for Month 9
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/mean/Mean_LTM_9.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/RL/RL_LTM_9.tif
#
# Processing Long-Term-Mean (LTM) for Month 10
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/mean/Mean_LTM_10.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/RL/RL_LTM_10.tif
#
# Processing Long-Term-Mean (LTM) for Month 11
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/mean/Mean_LTM_11.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/RL/RL_LTM_11.tif
#
# Processing Long-Term-Mean (LTM) for Month 12
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/mean/Mean_LTM_12.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/Precip/LTM/RL/RL_LTM_12.tif

# %% [markdown]
# #### 1.2 calculation of Precipitation during IP
# once LTM data is produced, we can calculate the actual conditions for the diferent interest periods (IP). To limit processing time, we will only process for the year 2021 as an example

# %%
mask = years > 1999
# set output folder for IP
outfolder_ip = Path() / 'CDI_data' / 'inputs_downloads' / 'Precip' / 'IP'

# %% [markdown]
# Again, if the IP results were already produced you can directly import them by setting ip_produced=True. If it is the first time calculating or you want to calculate it again set ip_produced=False

# %%
ip_produced = False

if ip_produced:
    # get mean IP
    mean_ip_folder = outfolder_ip / 'mean'
    mean_ip_list = sorted(list(mean_ip_folder.glob('*.tif')))
    P_ip_ds = gu.rasterlist2dict(mean_ip_list)

    # remove any dates outside of interest period
    dates_to_remove = [key for key in P_ip_ds if not (pd.to_datetime(start_date) <= key <= pd.to_datetime(end_date))]
    # Removing the keys
    for date in dates_to_remove:
        del P_ip_ds[date]
    
    # get RL data
    rl_ip_folder = outfolder_ip / 'RL'
    mean_rl_list = sorted(list(rl_ip_folder.glob('*.tif')))
    P_rl_ip_ds = gu.rasterlist2dict(mean_rl_list)

    # remove any dates outside of interest period
    dates_to_remove = [key for key in P_rl_ip_ds if not (pd.to_datetime(start_date) <= key <= pd.to_datetime(end_date))]
    # Removing the keys
    for date in dates_to_remove:
        del P_rl_ip_ds[date]
    

else:
    P_ip_ds, P_rl_ip_ds = cdi.compute_ip(da_var[mask, :, :], time_steps[mask], gt, proj, outfolder_ip, unit_scaler=1000, deficit=True, gee=True)
# Out:
# Processing IP periods for year 2001
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2001_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2001_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2001_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2001_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2001_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2001_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2001_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2001_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2001_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2001_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2001_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2001_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2001_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2001_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2001_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2001_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2001_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2001_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2001_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2001_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2001_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2001_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2001_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2001_12.tif
#
# Processing IP periods for year 2002
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2002_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2002_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2002_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2002_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2002_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2002_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2002_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2002_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2002_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2002_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2002_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2002_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2002_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2002_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2002_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2002_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2002_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2002_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2002_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2002_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2002_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2002_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2002_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2002_12.tif
#
# Processing IP periods for year 2003
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2003_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2003_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2003_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2003_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2003_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2003_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2003_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2003_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2003_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2003_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2003_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2003_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2003_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2003_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2003_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2003_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2003_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2003_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2003_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2003_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2003_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2003_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2003_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2003_12.tif
#
# Processing IP periods for year 2004
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2004_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2004_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2004_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2004_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2004_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2004_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2004_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2004_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2004_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2004_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2004_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2004_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2004_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2004_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2004_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2004_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2004_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2004_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2004_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2004_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2004_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2004_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2004_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2004_12.tif
#
# Processing IP periods for year 2005
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2005_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2005_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2005_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2005_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2005_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2005_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2005_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2005_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2005_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2005_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2005_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2005_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2005_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2005_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2005_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2005_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2005_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2005_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2005_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2005_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2005_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2005_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2005_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2005_12.tif
#
# Processing IP periods for year 2006
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2006_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2006_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2006_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2006_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2006_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2006_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2006_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2006_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2006_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2006_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2006_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2006_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2006_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2006_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2006_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2006_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2006_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2006_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2006_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2006_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2006_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2006_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2006_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2006_12.tif
#
# Processing IP periods for year 2007
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2007_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2007_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2007_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2007_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2007_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2007_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2007_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2007_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2007_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2007_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2007_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2007_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2007_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2007_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2007_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2007_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2007_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2007_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2007_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2007_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2007_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2007_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2007_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2007_12.tif
#
# Processing IP periods for year 2008
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2008_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2008_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2008_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2008_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2008_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2008_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2008_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2008_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2008_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2008_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2008_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2008_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2008_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2008_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2008_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2008_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2008_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2008_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2008_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2008_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2008_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2008_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2008_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2008_12.tif
#
# Processing IP periods for year 2009
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2009_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2009_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2009_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2009_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2009_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2009_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2009_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2009_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2009_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2009_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2009_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2009_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2009_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2009_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2009_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2009_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2009_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2009_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2009_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2009_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2009_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2009_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2009_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2009_12.tif
#
# Processing IP periods for year 2010
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2010_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2010_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2010_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2010_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2010_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2010_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2010_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2010_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2010_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2010_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2010_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2010_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2010_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2010_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2010_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2010_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2010_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2010_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2010_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2010_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2010_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2010_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2010_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2010_12.tif
#
# Processing IP periods for year 2011
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2011_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2011_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2011_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2011_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2011_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2011_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2011_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2011_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2011_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2011_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2011_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2011_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2011_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2011_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2011_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2011_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2011_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2011_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2011_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2011_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2011_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2011_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2011_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2011_12.tif
#
# Processing IP periods for year 2012
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2012_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2012_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2012_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2012_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2012_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2012_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2012_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2012_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2012_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2012_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2012_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2012_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2012_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2012_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2012_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2012_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2012_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2012_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2012_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2012_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2012_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2012_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2012_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2012_12.tif
#
# Processing IP periods for year 2013
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2013_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2013_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2013_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2013_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2013_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2013_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2013_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2013_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2013_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2013_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2013_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2013_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2013_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2013_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2013_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2013_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2013_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2013_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2013_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2013_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2013_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2013_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2013_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2013_12.tif
#
# Processing IP periods for year 2014
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2014_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2014_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2014_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2014_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2014_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2014_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2014_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2014_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2014_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2014_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2014_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2014_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2014_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2014_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2014_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2014_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2014_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2014_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2014_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2014_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2014_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2014_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2014_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2014_12.tif
#
# Processing IP periods for year 2015
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2015_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2015_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2015_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2015_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2015_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2015_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2015_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2015_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2015_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2015_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2015_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2015_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2015_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2015_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2015_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2015_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2015_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2015_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2015_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2015_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2015_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2015_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2015_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2015_12.tif
#
# Processing IP periods for year 2016
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2016_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2016_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2016_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2016_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2016_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2016_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2016_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2016_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2016_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2016_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2016_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2016_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2016_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2016_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2016_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2016_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2016_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2016_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2016_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2016_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2016_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2016_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2016_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2016_12.tif
#
# Processing IP periods for year 2017
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2017_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2017_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2017_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2017_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2017_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2017_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2017_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2017_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2017_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2017_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2017_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2017_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2017_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2017_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2017_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2017_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2017_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2017_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2017_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2017_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2017_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2017_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2017_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2017_12.tif
#
# Processing IP periods for year 2018
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2018_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2018_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2018_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2018_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2018_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2018_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2018_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2018_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2018_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2018_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2018_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2018_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2018_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2018_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2018_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2018_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2018_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2018_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2018_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2018_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2018_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2018_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2018_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2018_12.tif
#
# Processing IP periods for year 2019
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2019_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2019_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2019_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2019_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2019_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2019_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2019_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2019_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2019_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2019_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2019_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2019_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2019_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2019_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2019_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2019_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2019_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2019_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2019_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2019_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2019_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2019_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2019_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2019_12.tif
#
# Processing IP periods for year 2020
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2020_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2020_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2020_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2020_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2020_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2020_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2020_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2020_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2020_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2020_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2020_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2020_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2020_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2020_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2020_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2020_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2020_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2020_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2020_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2020_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2020_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2020_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2020_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2020_12.tif
#
# Processing IP periods for year 2021
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2021_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2021_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2021_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2021_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2021_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2021_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2021_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2021_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2021_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2021_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2021_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2021_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2021_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2021_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2021_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2021_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2021_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2021_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2021_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2021_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2021_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2021_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2021_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2021_12.tif
#
# Processing IP periods for year 2022
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2022_1.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2022_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2022_2.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2022_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2022_3.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2022_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2022_4.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2022_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2022_5.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2022_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2022_6.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2022_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2022_7.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2022_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2022_8.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2022_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2022_9.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2022_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2022_10.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2022_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2022_11.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2022_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Precip/IP/mean/Mean_IP_2022_12.tif
# 	saving result to CDI_data/inputs_downloads/Precip/IP/RL/RL_IP_2022_12.tif

# %% [markdown]
# #### 1.3 PDI calculation
# Once we have both the LTM and IP values for precipitation, we can calculate the PDI

# %%
## 1.3 calculate PDI
outfolder = Path() / 'CDI_data' / 'drought_indices'
pdi = cdi.calc_pdi(P_ip_ds, P_rl_ip_ds, P_ltm_ds, P_rl_ltm_ds, gt, proj, outfolder)
# Out:
# 2001
# 	Month: 1
# 	saving PDI result for 2001-1 to CDI_data/drought_indices/PDI/PDI_IP_2001_1.tif
#
# 	Month: 2
# 	saving PDI result for 2001-2 to CDI_data/drought_indices/PDI/PDI_IP_2001_2.tif
#
# 	Month: 3
# 	saving PDI result for 2001-3 to CDI_data/drought_indices/PDI/PDI_IP_2001_3.tif
#
# 	Month: 4
# 	saving PDI result for 2001-4 to CDI_data/drought_indices/PDI/PDI_IP_2001_4.tif
#
# 	Month: 5
# 	saving PDI result for 2001-5 to CDI_data/drought_indices/PDI/PDI_IP_2001_5.tif
#
# 	Month: 6
# 	saving PDI result for 2001-6 to CDI_data/drought_indices/PDI/PDI_IP_2001_6.tif
#
# 	Month: 7
# 	saving PDI result for 2001-7 to CDI_data/drought_indices/PDI/PDI_IP_2001_7.tif
#
# 	Month: 8
# 	saving PDI result for 2001-8 to CDI_data/drought_indices/PDI/PDI_IP_2001_8.tif
#
# 	Month: 9
# 	saving PDI result for 2001-9 to CDI_data/drought_indices/PDI/PDI_IP_2001_9.tif
#
# 	Month: 10
# 	saving PDI result for 2001-10 to CDI_data/drought_indices/PDI/PDI_IP_2001_10.tif
#
# 	Month: 11
# 	saving PDI result for 2001-11 to CDI_data/drought_indices/PDI/PDI_IP_2001_11.tif
#
# 	Month: 12
# 	saving PDI result for 2001-12 to CDI_data/drought_indices/PDI/PDI_IP_2001_12.tif
#
# 2002
# 	Month: 1
# 	saving PDI result for 2002-1 to CDI_data/drought_indices/PDI/PDI_IP_2002_1.tif
#
# 	Month: 2
# 	saving PDI result for 2002-2 to CDI_data/drought_indices/PDI/PDI_IP_2002_2.tif
#
# 	Month: 3
# 	saving PDI result for 2002-3 to CDI_data/drought_indices/PDI/PDI_IP_2002_3.tif
#
# 	Month: 4
# 	saving PDI result for 2002-4 to CDI_data/drought_indices/PDI/PDI_IP_2002_4.tif
#
# 	Month: 5
# 	saving PDI result for 2002-5 to CDI_data/drought_indices/PDI/PDI_IP_2002_5.tif
#
# 	Month: 6
# 	saving PDI result for 2002-6 to CDI_data/drought_indices/PDI/PDI_IP_2002_6.tif
#
# 	Month: 7
# 	saving PDI result for 2002-7 to CDI_data/drought_indices/PDI/PDI_IP_2002_7.tif
#
# 	Month: 8
# 	saving PDI result for 2002-8 to CDI_data/drought_indices/PDI/PDI_IP_2002_8.tif
#
# 	Month: 9
# 	saving PDI result for 2002-9 to CDI_data/drought_indices/PDI/PDI_IP_2002_9.tif
#
# 	Month: 10
# 	saving PDI result for 2002-10 to CDI_data/drought_indices/PDI/PDI_IP_2002_10.tif
#
# 	Month: 11
# 	saving PDI result for 2002-11 to CDI_data/drought_indices/PDI/PDI_IP_2002_11.tif
#
# 	Month: 12
# 	saving PDI result for 2002-12 to CDI_data/drought_indices/PDI/PDI_IP_2002_12.tif
#
# 2003
# 	Month: 1
# 	saving PDI result for 2003-1 to CDI_data/drought_indices/PDI/PDI_IP_2003_1.tif
#
# 	Month: 2
# 	saving PDI result for 2003-2 to CDI_data/drought_indices/PDI/PDI_IP_2003_2.tif
#
# 	Month: 3
# 	saving PDI result for 2003-3 to CDI_data/drought_indices/PDI/PDI_IP_2003_3.tif
#
# 	Month: 4
# 	saving PDI result for 2003-4 to CDI_data/drought_indices/PDI/PDI_IP_2003_4.tif
#
# 	Month: 5
# 	saving PDI result for 2003-5 to CDI_data/drought_indices/PDI/PDI_IP_2003_5.tif
#
# 	Month: 6
# 	saving PDI result for 2003-6 to CDI_data/drought_indices/PDI/PDI_IP_2003_6.tif
#
# 	Month: 7
# 	saving PDI result for 2003-7 to CDI_data/drought_indices/PDI/PDI_IP_2003_7.tif
#
# 	Month: 8
# 	saving PDI result for 2003-8 to CDI_data/drought_indices/PDI/PDI_IP_2003_8.tif
#
# 	Month: 9
# 	saving PDI result for 2003-9 to CDI_data/drought_indices/PDI/PDI_IP_2003_9.tif
#
# 	Month: 10
# 	saving PDI result for 2003-10 to CDI_data/drought_indices/PDI/PDI_IP_2003_10.tif
#
# 	Month: 11
# 	saving PDI result for 2003-11 to CDI_data/drought_indices/PDI/PDI_IP_2003_11.tif
#
# 	Month: 12
# 	saving PDI result for 2003-12 to CDI_data/drought_indices/PDI/PDI_IP_2003_12.tif
#
# 2004
# 	Month: 1
# 	saving PDI result for 2004-1 to CDI_data/drought_indices/PDI/PDI_IP_2004_1.tif
#
# 	Month: 2
# 	saving PDI result for 2004-2 to CDI_data/drought_indices/PDI/PDI_IP_2004_2.tif
#
# 	Month: 3
# 	saving PDI result for 2004-3 to CDI_data/drought_indices/PDI/PDI_IP_2004_3.tif
#
# 	Month: 4
# 	saving PDI result for 2004-4 to CDI_data/drought_indices/PDI/PDI_IP_2004_4.tif
#
# 	Month: 5
# 	saving PDI result for 2004-5 to CDI_data/drought_indices/PDI/PDI_IP_2004_5.tif
#
# 	Month: 6
# 	saving PDI result for 2004-6 to CDI_data/drought_indices/PDI/PDI_IP_2004_6.tif
#
# 	Month: 7
# 	saving PDI result for 2004-7 to CDI_data/drought_indices/PDI/PDI_IP_2004_7.tif
#
# 	Month: 8
# 	saving PDI result for 2004-8 to CDI_data/drought_indices/PDI/PDI_IP_2004_8.tif
#
# 	Month: 9
# 	saving PDI result for 2004-9 to CDI_data/drought_indices/PDI/PDI_IP_2004_9.tif
#
# 	Month: 10
# 	saving PDI result for 2004-10 to CDI_data/drought_indices/PDI/PDI_IP_2004_10.tif
#
# 	Month: 11
# 	saving PDI result for 2004-11 to CDI_data/drought_indices/PDI/PDI_IP_2004_11.tif
#
# 	Month: 12
# 	saving PDI result for 2004-12 to CDI_data/drought_indices/PDI/PDI_IP_2004_12.tif
#
# 2005
# 	Month: 1
# 	saving PDI result for 2005-1 to CDI_data/drought_indices/PDI/PDI_IP_2005_1.tif
#
# 	Month: 2
# 	saving PDI result for 2005-2 to CDI_data/drought_indices/PDI/PDI_IP_2005_2.tif
#
# 	Month: 3
# 	saving PDI result for 2005-3 to CDI_data/drought_indices/PDI/PDI_IP_2005_3.tif
#
# 	Month: 4
# 	saving PDI result for 2005-4 to CDI_data/drought_indices/PDI/PDI_IP_2005_4.tif
#
# 	Month: 5
# 	saving PDI result for 2005-5 to CDI_data/drought_indices/PDI/PDI_IP_2005_5.tif
#
# 	Month: 6
# 	saving PDI result for 2005-6 to CDI_data/drought_indices/PDI/PDI_IP_2005_6.tif
#
# 	Month: 7
# 	saving PDI result for 2005-7 to CDI_data/drought_indices/PDI/PDI_IP_2005_7.tif
#
# 	Month: 8
# 	saving PDI result for 2005-8 to CDI_data/drought_indices/PDI/PDI_IP_2005_8.tif
#
# 	Month: 9
# 	saving PDI result for 2005-9 to CDI_data/drought_indices/PDI/PDI_IP_2005_9.tif
#
# 	Month: 10
# 	saving PDI result for 2005-10 to CDI_data/drought_indices/PDI/PDI_IP_2005_10.tif
#
# 	Month: 11
# 	saving PDI result for 2005-11 to CDI_data/drought_indices/PDI/PDI_IP_2005_11.tif
#
# 	Month: 12
# 	saving PDI result for 2005-12 to CDI_data/drought_indices/PDI/PDI_IP_2005_12.tif
#
# 2006
# 	Month: 1
# 	saving PDI result for 2006-1 to CDI_data/drought_indices/PDI/PDI_IP_2006_1.tif
#
# 	Month: 2
# 	saving PDI result for 2006-2 to CDI_data/drought_indices/PDI/PDI_IP_2006_2.tif
#
# 	Month: 3
# 	saving PDI result for 2006-3 to CDI_data/drought_indices/PDI/PDI_IP_2006_3.tif
#
# 	Month: 4
# 	saving PDI result for 2006-4 to CDI_data/drought_indices/PDI/PDI_IP_2006_4.tif
#
# 	Month: 5
# 	saving PDI result for 2006-5 to CDI_data/drought_indices/PDI/PDI_IP_2006_5.tif
#
# 	Month: 6
# 	saving PDI result for 2006-6 to CDI_data/drought_indices/PDI/PDI_IP_2006_6.tif
#
# 	Month: 7
# 	saving PDI result for 2006-7 to CDI_data/drought_indices/PDI/PDI_IP_2006_7.tif
#
# 	Month: 8
# 	saving PDI result for 2006-8 to CDI_data/drought_indices/PDI/PDI_IP_2006_8.tif
#
# 	Month: 9
# 	saving PDI result for 2006-9 to CDI_data/drought_indices/PDI/PDI_IP_2006_9.tif
#
# 	Month: 10
# 	saving PDI result for 2006-10 to CDI_data/drought_indices/PDI/PDI_IP_2006_10.tif
#
# 	Month: 11
# 	saving PDI result for 2006-11 to CDI_data/drought_indices/PDI/PDI_IP_2006_11.tif
#
# 	Month: 12
# 	saving PDI result for 2006-12 to CDI_data/drought_indices/PDI/PDI_IP_2006_12.tif
#
# 2007
# 	Month: 1
# 	saving PDI result for 2007-1 to CDI_data/drought_indices/PDI/PDI_IP_2007_1.tif
#
# 	Month: 2
# 	saving PDI result for 2007-2 to CDI_data/drought_indices/PDI/PDI_IP_2007_2.tif
#
# 	Month: 3
# 	saving PDI result for 2007-3 to CDI_data/drought_indices/PDI/PDI_IP_2007_3.tif
#
# 	Month: 4
# 	saving PDI result for 2007-4 to CDI_data/drought_indices/PDI/PDI_IP_2007_4.tif
#
# 	Month: 5
# 	saving PDI result for 2007-5 to CDI_data/drought_indices/PDI/PDI_IP_2007_5.tif
#
# 	Month: 6
# 	saving PDI result for 2007-6 to CDI_data/drought_indices/PDI/PDI_IP_2007_6.tif
#
# 	Month: 7
# 	saving PDI result for 2007-7 to CDI_data/drought_indices/PDI/PDI_IP_2007_7.tif
#
# 	Month: 8
# 	saving PDI result for 2007-8 to CDI_data/drought_indices/PDI/PDI_IP_2007_8.tif
#
# 	Month: 9
# 	saving PDI result for 2007-9 to CDI_data/drought_indices/PDI/PDI_IP_2007_9.tif
#
# 	Month: 10
# 	saving PDI result for 2007-10 to CDI_data/drought_indices/PDI/PDI_IP_2007_10.tif
#
# 	Month: 11
# 	saving PDI result for 2007-11 to CDI_data/drought_indices/PDI/PDI_IP_2007_11.tif
#
# 	Month: 12
# 	saving PDI result for 2007-12 to CDI_data/drought_indices/PDI/PDI_IP_2007_12.tif
#
# 2008
# 	Month: 1
# 	saving PDI result for 2008-1 to CDI_data/drought_indices/PDI/PDI_IP_2008_1.tif
#
# 	Month: 2
# 	saving PDI result for 2008-2 to CDI_data/drought_indices/PDI/PDI_IP_2008_2.tif
#
# 	Month: 3
# 	saving PDI result for 2008-3 to CDI_data/drought_indices/PDI/PDI_IP_2008_3.tif
#
# 	Month: 4
# 	saving PDI result for 2008-4 to CDI_data/drought_indices/PDI/PDI_IP_2008_4.tif
#
# 	Month: 5
# 	saving PDI result for 2008-5 to CDI_data/drought_indices/PDI/PDI_IP_2008_5.tif
#
# 	Month: 6
# 	saving PDI result for 2008-6 to CDI_data/drought_indices/PDI/PDI_IP_2008_6.tif
#
# 	Month: 7
# 	saving PDI result for 2008-7 to CDI_data/drought_indices/PDI/PDI_IP_2008_7.tif
#
# 	Month: 8
# 	saving PDI result for 2008-8 to CDI_data/drought_indices/PDI/PDI_IP_2008_8.tif
#
# 	Month: 9
# 	saving PDI result for 2008-9 to CDI_data/drought_indices/PDI/PDI_IP_2008_9.tif
#
# 	Month: 10
# 	saving PDI result for 2008-10 to CDI_data/drought_indices/PDI/PDI_IP_2008_10.tif
#
# 	Month: 11
# 	saving PDI result for 2008-11 to CDI_data/drought_indices/PDI/PDI_IP_2008_11.tif
#
# 	Month: 12
# 	saving PDI result for 2008-12 to CDI_data/drought_indices/PDI/PDI_IP_2008_12.tif
#
# 2009
# 	Month: 1
# 	saving PDI result for 2009-1 to CDI_data/drought_indices/PDI/PDI_IP_2009_1.tif
#
# 	Month: 2
# 	saving PDI result for 2009-2 to CDI_data/drought_indices/PDI/PDI_IP_2009_2.tif
#
# 	Month: 3
# 	saving PDI result for 2009-3 to CDI_data/drought_indices/PDI/PDI_IP_2009_3.tif
#
# 	Month: 4
# 	saving PDI result for 2009-4 to CDI_data/drought_indices/PDI/PDI_IP_2009_4.tif
#
# 	Month: 5
# 	saving PDI result for 2009-5 to CDI_data/drought_indices/PDI/PDI_IP_2009_5.tif
#
# 	Month: 6
# 	saving PDI result for 2009-6 to CDI_data/drought_indices/PDI/PDI_IP_2009_6.tif
#
# 	Month: 7
# 	saving PDI result for 2009-7 to CDI_data/drought_indices/PDI/PDI_IP_2009_7.tif
#
# 	Month: 8
# 	saving PDI result for 2009-8 to CDI_data/drought_indices/PDI/PDI_IP_2009_8.tif
#
# 	Month: 9
# 	saving PDI result for 2009-9 to CDI_data/drought_indices/PDI/PDI_IP_2009_9.tif
#
# 	Month: 10
# 	saving PDI result for 2009-10 to CDI_data/drought_indices/PDI/PDI_IP_2009_10.tif
#
# 	Month: 11
# 	saving PDI result for 2009-11 to CDI_data/drought_indices/PDI/PDI_IP_2009_11.tif
#
# 	Month: 12
# 	saving PDI result for 2009-12 to CDI_data/drought_indices/PDI/PDI_IP_2009_12.tif
#
# 2010
# 	Month: 1
# 	saving PDI result for 2010-1 to CDI_data/drought_indices/PDI/PDI_IP_2010_1.tif
#
# 	Month: 2
# 	saving PDI result for 2010-2 to CDI_data/drought_indices/PDI/PDI_IP_2010_2.tif
#
# 	Month: 3
# 	saving PDI result for 2010-3 to CDI_data/drought_indices/PDI/PDI_IP_2010_3.tif
#
# 	Month: 4
# 	saving PDI result for 2010-4 to CDI_data/drought_indices/PDI/PDI_IP_2010_4.tif
#
# 	Month: 5
# 	saving PDI result for 2010-5 to CDI_data/drought_indices/PDI/PDI_IP_2010_5.tif
#
# 	Month: 6
# 	saving PDI result for 2010-6 to CDI_data/drought_indices/PDI/PDI_IP_2010_6.tif
#
# 	Month: 7
# 	saving PDI result for 2010-7 to CDI_data/drought_indices/PDI/PDI_IP_2010_7.tif
#
# 	Month: 8
# 	saving PDI result for 2010-8 to CDI_data/drought_indices/PDI/PDI_IP_2010_8.tif
#
# 	Month: 9
# 	saving PDI result for 2010-9 to CDI_data/drought_indices/PDI/PDI_IP_2010_9.tif
#
# 	Month: 10
# 	saving PDI result for 2010-10 to CDI_data/drought_indices/PDI/PDI_IP_2010_10.tif
#
# 	Month: 11
# 	saving PDI result for 2010-11 to CDI_data/drought_indices/PDI/PDI_IP_2010_11.tif
#
# 	Month: 12
# 	saving PDI result for 2010-12 to CDI_data/drought_indices/PDI/PDI_IP_2010_12.tif
#
# 2011
# 	Month: 1
# 	saving PDI result for 2011-1 to CDI_data/drought_indices/PDI/PDI_IP_2011_1.tif
#
# 	Month: 2
# 	saving PDI result for 2011-2 to CDI_data/drought_indices/PDI/PDI_IP_2011_2.tif
#
# 	Month: 3
# 	saving PDI result for 2011-3 to CDI_data/drought_indices/PDI/PDI_IP_2011_3.tif
#
# 	Month: 4
# 	saving PDI result for 2011-4 to CDI_data/drought_indices/PDI/PDI_IP_2011_4.tif
#
# 	Month: 5
# 	saving PDI result for 2011-5 to CDI_data/drought_indices/PDI/PDI_IP_2011_5.tif
#
# 	Month: 6
# 	saving PDI result for 2011-6 to CDI_data/drought_indices/PDI/PDI_IP_2011_6.tif
#
# 	Month: 7
# 	saving PDI result for 2011-7 to CDI_data/drought_indices/PDI/PDI_IP_2011_7.tif
#
# 	Month: 8
# 	saving PDI result for 2011-8 to CDI_data/drought_indices/PDI/PDI_IP_2011_8.tif
#
# 	Month: 9
# 	saving PDI result for 2011-9 to CDI_data/drought_indices/PDI/PDI_IP_2011_9.tif
#
# 	Month: 10
# 	saving PDI result for 2011-10 to CDI_data/drought_indices/PDI/PDI_IP_2011_10.tif
#
# 	Month: 11
# 	saving PDI result for 2011-11 to CDI_data/drought_indices/PDI/PDI_IP_2011_11.tif
#
# 	Month: 12
# 	saving PDI result for 2011-12 to CDI_data/drought_indices/PDI/PDI_IP_2011_12.tif
#
# 2012
# 	Month: 1
# 	saving PDI result for 2012-1 to CDI_data/drought_indices/PDI/PDI_IP_2012_1.tif
#
# 	Month: 2
# 	saving PDI result for 2012-2 to CDI_data/drought_indices/PDI/PDI_IP_2012_2.tif
#
# 	Month: 3
# 	saving PDI result for 2012-3 to CDI_data/drought_indices/PDI/PDI_IP_2012_3.tif
#
# 	Month: 4
# 	saving PDI result for 2012-4 to CDI_data/drought_indices/PDI/PDI_IP_2012_4.tif
#
# 	Month: 5
# 	saving PDI result for 2012-5 to CDI_data/drought_indices/PDI/PDI_IP_2012_5.tif
#
# 	Month: 6
# 	saving PDI result for 2012-6 to CDI_data/drought_indices/PDI/PDI_IP_2012_6.tif
#
# 	Month: 7
# 	saving PDI result for 2012-7 to CDI_data/drought_indices/PDI/PDI_IP_2012_7.tif
#
# 	Month: 8
# 	saving PDI result for 2012-8 to CDI_data/drought_indices/PDI/PDI_IP_2012_8.tif
#
# 	Month: 9
# 	saving PDI result for 2012-9 to CDI_data/drought_indices/PDI/PDI_IP_2012_9.tif
#
# 	Month: 10
# 	saving PDI result for 2012-10 to CDI_data/drought_indices/PDI/PDI_IP_2012_10.tif
#
# 	Month: 11
# 	saving PDI result for 2012-11 to CDI_data/drought_indices/PDI/PDI_IP_2012_11.tif
#
# 	Month: 12
# 	saving PDI result for 2012-12 to CDI_data/drought_indices/PDI/PDI_IP_2012_12.tif
#
# 2013
# 	Month: 1
# 	saving PDI result for 2013-1 to CDI_data/drought_indices/PDI/PDI_IP_2013_1.tif
#
# 	Month: 2
# 	saving PDI result for 2013-2 to CDI_data/drought_indices/PDI/PDI_IP_2013_2.tif
#
# 	Month: 3
# 	saving PDI result for 2013-3 to CDI_data/drought_indices/PDI/PDI_IP_2013_3.tif
#
# 	Month: 4
# 	saving PDI result for 2013-4 to CDI_data/drought_indices/PDI/PDI_IP_2013_4.tif
#
# 	Month: 5
# 	saving PDI result for 2013-5 to CDI_data/drought_indices/PDI/PDI_IP_2013_5.tif
#
# 	Month: 6
# 	saving PDI result for 2013-6 to CDI_data/drought_indices/PDI/PDI_IP_2013_6.tif
#
# 	Month: 7
# 	saving PDI result for 2013-7 to CDI_data/drought_indices/PDI/PDI_IP_2013_7.tif
#
# 	Month: 8
# 	saving PDI result for 2013-8 to CDI_data/drought_indices/PDI/PDI_IP_2013_8.tif
#
# 	Month: 9
# 	saving PDI result for 2013-9 to CDI_data/drought_indices/PDI/PDI_IP_2013_9.tif
#
# 	Month: 10
# 	saving PDI result for 2013-10 to CDI_data/drought_indices/PDI/PDI_IP_2013_10.tif
#
# 	Month: 11
# 	saving PDI result for 2013-11 to CDI_data/drought_indices/PDI/PDI_IP_2013_11.tif
#
# 	Month: 12
# 	saving PDI result for 2013-12 to CDI_data/drought_indices/PDI/PDI_IP_2013_12.tif
#
# 2014
# 	Month: 1
# 	saving PDI result for 2014-1 to CDI_data/drought_indices/PDI/PDI_IP_2014_1.tif
#
# 	Month: 2
# 	saving PDI result for 2014-2 to CDI_data/drought_indices/PDI/PDI_IP_2014_2.tif
#
# 	Month: 3
# 	saving PDI result for 2014-3 to CDI_data/drought_indices/PDI/PDI_IP_2014_3.tif
#
# 	Month: 4
# 	saving PDI result for 2014-4 to CDI_data/drought_indices/PDI/PDI_IP_2014_4.tif
#
# 	Month: 5
# 	saving PDI result for 2014-5 to CDI_data/drought_indices/PDI/PDI_IP_2014_5.tif
#
# 	Month: 6
# 	saving PDI result for 2014-6 to CDI_data/drought_indices/PDI/PDI_IP_2014_6.tif
#
# 	Month: 7
# 	saving PDI result for 2014-7 to CDI_data/drought_indices/PDI/PDI_IP_2014_7.tif
#
# 	Month: 8
# 	saving PDI result for 2014-8 to CDI_data/drought_indices/PDI/PDI_IP_2014_8.tif
#
# 	Month: 9
# 	saving PDI result for 2014-9 to CDI_data/drought_indices/PDI/PDI_IP_2014_9.tif
#
# 	Month: 10
# 	saving PDI result for 2014-10 to CDI_data/drought_indices/PDI/PDI_IP_2014_10.tif
#
# 	Month: 11
# 	saving PDI result for 2014-11 to CDI_data/drought_indices/PDI/PDI_IP_2014_11.tif
#
# 	Month: 12
# 	saving PDI result for 2014-12 to CDI_data/drought_indices/PDI/PDI_IP_2014_12.tif
#
# 2015
# 	Month: 1
# 	saving PDI result for 2015-1 to CDI_data/drought_indices/PDI/PDI_IP_2015_1.tif
#
# 	Month: 2
# 	saving PDI result for 2015-2 to CDI_data/drought_indices/PDI/PDI_IP_2015_2.tif
#
# 	Month: 3
# 	saving PDI result for 2015-3 to CDI_data/drought_indices/PDI/PDI_IP_2015_3.tif
#
# 	Month: 4
# 	saving PDI result for 2015-4 to CDI_data/drought_indices/PDI/PDI_IP_2015_4.tif
#
# 	Month: 5
# 	saving PDI result for 2015-5 to CDI_data/drought_indices/PDI/PDI_IP_2015_5.tif
#
# 	Month: 6
# 	saving PDI result for 2015-6 to CDI_data/drought_indices/PDI/PDI_IP_2015_6.tif
#
# 	Month: 7
# 	saving PDI result for 2015-7 to CDI_data/drought_indices/PDI/PDI_IP_2015_7.tif
#
# 	Month: 8
# 	saving PDI result for 2015-8 to CDI_data/drought_indices/PDI/PDI_IP_2015_8.tif
#
# 	Month: 9
# 	saving PDI result for 2015-9 to CDI_data/drought_indices/PDI/PDI_IP_2015_9.tif
#
# 	Month: 10
# 	saving PDI result for 2015-10 to CDI_data/drought_indices/PDI/PDI_IP_2015_10.tif
#
# 	Month: 11
# 	saving PDI result for 2015-11 to CDI_data/drought_indices/PDI/PDI_IP_2015_11.tif
#
# 	Month: 12
# 	saving PDI result for 2015-12 to CDI_data/drought_indices/PDI/PDI_IP_2015_12.tif
#
# 2016
# 	Month: 1
# 	saving PDI result for 2016-1 to CDI_data/drought_indices/PDI/PDI_IP_2016_1.tif
#
# 	Month: 2
# 	saving PDI result for 2016-2 to CDI_data/drought_indices/PDI/PDI_IP_2016_2.tif
#
# 	Month: 3
# 	saving PDI result for 2016-3 to CDI_data/drought_indices/PDI/PDI_IP_2016_3.tif
#
# 	Month: 4
# 	saving PDI result for 2016-4 to CDI_data/drought_indices/PDI/PDI_IP_2016_4.tif
#
# 	Month: 5
# 	saving PDI result for 2016-5 to CDI_data/drought_indices/PDI/PDI_IP_2016_5.tif
#
# 	Month: 6
# 	saving PDI result for 2016-6 to CDI_data/drought_indices/PDI/PDI_IP_2016_6.tif
#
# 	Month: 7
# 	saving PDI result for 2016-7 to CDI_data/drought_indices/PDI/PDI_IP_2016_7.tif
#
# 	Month: 8
# 	saving PDI result for 2016-8 to CDI_data/drought_indices/PDI/PDI_IP_2016_8.tif
#
# 	Month: 9
# 	saving PDI result for 2016-9 to CDI_data/drought_indices/PDI/PDI_IP_2016_9.tif
#
# 	Month: 10
# 	saving PDI result for 2016-10 to CDI_data/drought_indices/PDI/PDI_IP_2016_10.tif
#
# 	Month: 11
# 	saving PDI result for 2016-11 to CDI_data/drought_indices/PDI/PDI_IP_2016_11.tif
#
# 	Month: 12
# 	saving PDI result for 2016-12 to CDI_data/drought_indices/PDI/PDI_IP_2016_12.tif
#
# 2017
# 	Month: 1
# 	saving PDI result for 2017-1 to CDI_data/drought_indices/PDI/PDI_IP_2017_1.tif
#
# 	Month: 2
# 	saving PDI result for 2017-2 to CDI_data/drought_indices/PDI/PDI_IP_2017_2.tif
#
# 	Month: 3
# 	saving PDI result for 2017-3 to CDI_data/drought_indices/PDI/PDI_IP_2017_3.tif
#
# 	Month: 4
# 	saving PDI result for 2017-4 to CDI_data/drought_indices/PDI/PDI_IP_2017_4.tif
#
# 	Month: 5
# 	saving PDI result for 2017-5 to CDI_data/drought_indices/PDI/PDI_IP_2017_5.tif
#
# 	Month: 6
# 	saving PDI result for 2017-6 to CDI_data/drought_indices/PDI/PDI_IP_2017_6.tif
#
# 	Month: 7
# 	saving PDI result for 2017-7 to CDI_data/drought_indices/PDI/PDI_IP_2017_7.tif
#
# 	Month: 8
# 	saving PDI result for 2017-8 to CDI_data/drought_indices/PDI/PDI_IP_2017_8.tif
#
# 	Month: 9
# 	saving PDI result for 2017-9 to CDI_data/drought_indices/PDI/PDI_IP_2017_9.tif
#
# 	Month: 10
# 	saving PDI result for 2017-10 to CDI_data/drought_indices/PDI/PDI_IP_2017_10.tif
#
# 	Month: 11
# 	saving PDI result for 2017-11 to CDI_data/drought_indices/PDI/PDI_IP_2017_11.tif
#
# 	Month: 12
# 	saving PDI result for 2017-12 to CDI_data/drought_indices/PDI/PDI_IP_2017_12.tif
#
# 2018
# 	Month: 1
# 	saving PDI result for 2018-1 to CDI_data/drought_indices/PDI/PDI_IP_2018_1.tif
#
# 	Month: 2
# 	saving PDI result for 2018-2 to CDI_data/drought_indices/PDI/PDI_IP_2018_2.tif
#
# 	Month: 3
# 	saving PDI result for 2018-3 to CDI_data/drought_indices/PDI/PDI_IP_2018_3.tif
#
# 	Month: 4
# 	saving PDI result for 2018-4 to CDI_data/drought_indices/PDI/PDI_IP_2018_4.tif
#
# 	Month: 5
# 	saving PDI result for 2018-5 to CDI_data/drought_indices/PDI/PDI_IP_2018_5.tif
#
# 	Month: 6
# 	saving PDI result for 2018-6 to CDI_data/drought_indices/PDI/PDI_IP_2018_6.tif
#
# 	Month: 7
# 	saving PDI result for 2018-7 to CDI_data/drought_indices/PDI/PDI_IP_2018_7.tif
#
# 	Month: 8
# 	saving PDI result for 2018-8 to CDI_data/drought_indices/PDI/PDI_IP_2018_8.tif
#
# 	Month: 9
# 	saving PDI result for 2018-9 to CDI_data/drought_indices/PDI/PDI_IP_2018_9.tif
#
# 	Month: 10
# 	saving PDI result for 2018-10 to CDI_data/drought_indices/PDI/PDI_IP_2018_10.tif
#
# 	Month: 11
# 	saving PDI result for 2018-11 to CDI_data/drought_indices/PDI/PDI_IP_2018_11.tif
#
# 	Month: 12
# 	saving PDI result for 2018-12 to CDI_data/drought_indices/PDI/PDI_IP_2018_12.tif
#
# 2019
# 	Month: 1
# 	saving PDI result for 2019-1 to CDI_data/drought_indices/PDI/PDI_IP_2019_1.tif
#
# 	Month: 2
# 	saving PDI result for 2019-2 to CDI_data/drought_indices/PDI/PDI_IP_2019_2.tif
#
# 	Month: 3
# 	saving PDI result for 2019-3 to CDI_data/drought_indices/PDI/PDI_IP_2019_3.tif
#
# 	Month: 4
# 	saving PDI result for 2019-4 to CDI_data/drought_indices/PDI/PDI_IP_2019_4.tif
#
# 	Month: 5
# 	saving PDI result for 2019-5 to CDI_data/drought_indices/PDI/PDI_IP_2019_5.tif
#
# 	Month: 6
# 	saving PDI result for 2019-6 to CDI_data/drought_indices/PDI/PDI_IP_2019_6.tif
#
# 	Month: 7
# 	saving PDI result for 2019-7 to CDI_data/drought_indices/PDI/PDI_IP_2019_7.tif
#
# 	Month: 8
# 	saving PDI result for 2019-8 to CDI_data/drought_indices/PDI/PDI_IP_2019_8.tif
#
# 	Month: 9
# 	saving PDI result for 2019-9 to CDI_data/drought_indices/PDI/PDI_IP_2019_9.tif
#
# 	Month: 10
# 	saving PDI result for 2019-10 to CDI_data/drought_indices/PDI/PDI_IP_2019_10.tif
#
# 	Month: 11
# 	saving PDI result for 2019-11 to CDI_data/drought_indices/PDI/PDI_IP_2019_11.tif
#
# 	Month: 12
# 	saving PDI result for 2019-12 to CDI_data/drought_indices/PDI/PDI_IP_2019_12.tif
#
# 2020
# 	Month: 1
# 	saving PDI result for 2020-1 to CDI_data/drought_indices/PDI/PDI_IP_2020_1.tif
#
# 	Month: 2
# 	saving PDI result for 2020-2 to CDI_data/drought_indices/PDI/PDI_IP_2020_2.tif
#
# 	Month: 3
# 	saving PDI result for 2020-3 to CDI_data/drought_indices/PDI/PDI_IP_2020_3.tif
#
# 	Month: 4
# 	saving PDI result for 2020-4 to CDI_data/drought_indices/PDI/PDI_IP_2020_4.tif
#
# 	Month: 5
# 	saving PDI result for 2020-5 to CDI_data/drought_indices/PDI/PDI_IP_2020_5.tif
#
# 	Month: 6
# 	saving PDI result for 2020-6 to CDI_data/drought_indices/PDI/PDI_IP_2020_6.tif
#
# 	Month: 7
# 	saving PDI result for 2020-7 to CDI_data/drought_indices/PDI/PDI_IP_2020_7.tif
#
# 	Month: 8
# 	saving PDI result for 2020-8 to CDI_data/drought_indices/PDI/PDI_IP_2020_8.tif
#
# 	Month: 9
# 	saving PDI result for 2020-9 to CDI_data/drought_indices/PDI/PDI_IP_2020_9.tif
#
# 	Month: 10
# 	saving PDI result for 2020-10 to CDI_data/drought_indices/PDI/PDI_IP_2020_10.tif
#
# 	Month: 11
# 	saving PDI result for 2020-11 to CDI_data/drought_indices/PDI/PDI_IP_2020_11.tif
#
# 	Month: 12
# 	saving PDI result for 2020-12 to CDI_data/drought_indices/PDI/PDI_IP_2020_12.tif
#
# 2021
# 	Month: 1
# 	saving PDI result for 2021-1 to CDI_data/drought_indices/PDI/PDI_IP_2021_1.tif
#
# 	Month: 2
# 	saving PDI result for 2021-2 to CDI_data/drought_indices/PDI/PDI_IP_2021_2.tif
#
# 	Month: 3
# 	saving PDI result for 2021-3 to CDI_data/drought_indices/PDI/PDI_IP_2021_3.tif
#
# 	Month: 4
# 	saving PDI result for 2021-4 to CDI_data/drought_indices/PDI/PDI_IP_2021_4.tif
#
# 	Month: 5
# 	saving PDI result for 2021-5 to CDI_data/drought_indices/PDI/PDI_IP_2021_5.tif
#
# 	Month: 6
# 	saving PDI result for 2021-6 to CDI_data/drought_indices/PDI/PDI_IP_2021_6.tif
#
# 	Month: 7
# 	saving PDI result for 2021-7 to CDI_data/drought_indices/PDI/PDI_IP_2021_7.tif
#
# 	Month: 8
# 	saving PDI result for 2021-8 to CDI_data/drought_indices/PDI/PDI_IP_2021_8.tif
#
# 	Month: 9
# 	saving PDI result for 2021-9 to CDI_data/drought_indices/PDI/PDI_IP_2021_9.tif
#
# 	Month: 10
# 	saving PDI result for 2021-10 to CDI_data/drought_indices/PDI/PDI_IP_2021_10.tif
#
# 	Month: 11
# 	saving PDI result for 2021-11 to CDI_data/drought_indices/PDI/PDI_IP_2021_11.tif
#
# 	Month: 12
# 	saving PDI result for 2021-12 to CDI_data/drought_indices/PDI/PDI_IP_2021_12.tif
#
# 2022
# 	Month: 1
# 	saving PDI result for 2022-1 to CDI_data/drought_indices/PDI/PDI_IP_2022_1.tif
#
# 	Month: 2
# 	saving PDI result for 2022-2 to CDI_data/drought_indices/PDI/PDI_IP_2022_2.tif
#
# 	Month: 3
# 	saving PDI result for 2022-3 to CDI_data/drought_indices/PDI/PDI_IP_2022_3.tif
#
# 	Month: 4
# 	saving PDI result for 2022-4 to CDI_data/drought_indices/PDI/PDI_IP_2022_4.tif
#
# 	Month: 5
# 	saving PDI result for 2022-5 to CDI_data/drought_indices/PDI/PDI_IP_2022_5.tif
#
# 	Month: 6
# 	saving PDI result for 2022-6 to CDI_data/drought_indices/PDI/PDI_IP_2022_6.tif
#
# 	Month: 7
# 	saving PDI result for 2022-7 to CDI_data/drought_indices/PDI/PDI_IP_2022_7.tif
#
# 	Month: 8
# 	saving PDI result for 2022-8 to CDI_data/drought_indices/PDI/PDI_IP_2022_8.tif
#
# 	Month: 9
# 	saving PDI result for 2022-9 to CDI_data/drought_indices/PDI/PDI_IP_2022_9.tif
#
# 	Month: 10
# 	saving PDI result for 2022-10 to CDI_data/drought_indices/PDI/PDI_IP_2022_10.tif
#
# 	Month: 11
# 	saving PDI result for 2022-11 to CDI_data/drought_indices/PDI/PDI_IP_2022_11.tif
#
# 	Month: 12
# 	saving PDI result for 2022-12 to CDI_data/drought_indices/PDI/PDI_IP_2022_12.tif

# %% [markdown]
# ### 2. TDI estimation
# Now, we do a very similar procedure with the air temperature data

# %% [markdown]
# #### 2.1 calculation of Long-term-mean (LTM) of air temperature
# We will use the same xarray dataset already opened for precipitation but slice it for air temperature

# %%
# select precipitation and slice the xarray
var = "temperature_2m"
da_var = da.sel(band=var)
# get all time steps
time_steps = pd.to_datetime(da['time'].values)
years = np.array(time_steps.year)

# select output folder for Ta
outfolder_ltm = Path() / 'CDI_data' / 'inputs_downloads' / 'Ta' / 'LTM'

# %% [markdown]
# Since calculating the LTM may take some time, if the LTM were already produced you can directly import them by setting ltm_produced=True. If it is the first time calculating or you want to calculate it again set ltm_produced=False

# %%
ltm_produced = True
if ltm_produced:
    # get mean
    mean_ltm_folder = outfolder_ltm / 'mean'
    mean_img_list = sorted(list(mean_ltm_folder.glob('*.tif')))
    Ta_ltm_ds = gu.rasterlist2dict(mean_img_list)
    
    # get RL data
    rl_img_folder = outfolder_ltm / 'RL'
    rl_img_list = sorted(list(rl_img_folder.glob('*.tif')))
    Ta_rl_ltm_ds = gu.rasterlist2dict(rl_img_list)

else:
    Ta_ltm_ds, Ta_rl_ltm_ds = cdi.compute_ltm(da_var, time_steps, gt, proj, outfolder_ltm, unit_scaler=1, deficit=False, gee=True)

# %% [markdown]
# #### 2.2 Air Temperature during IP
# once LTM data is produced, we can calculate the actual conditions for the diferent interest periods (IP). To limit processing time, we will only process for the year 2021 as an example

# %%
mask = years > 1999
outfolder_ip = Path() / 'CDI_data' / 'inputs_downloads' / 'Ta' / 'IP'

# %% [markdown]
# Again, if the IP results were already produced you can directly import them by setting ip_produced=True. If it is the first time calculating or you want to calculate it again set ip_produced=False

# %%
ip_produced = False

if ip_produced:
    # get mean IP
    mean_ip_folder = outfolder_ip / 'mean'
    mean_ip_list = sorted(list(mean_ip_folder.glob('*.tif')))
    Ta_ip_ds = gu.rasterlist2dict(mean_ip_list)
    
    # remove any dates outside of interest period
    dates_to_remove = [key for key in Ta_ip_ds if not (pd.to_datetime(start_date) <= key <= pd.to_datetime(end_date))]
    # Removing the keys
    for date in dates_to_remove:
        del Ta_ip_ds[date]

    # get RL data
    rl_ip_folder = outfolder_ip / 'RL'
    mean_rl_list = sorted(list(rl_ip_folder.glob('*.tif')))
    Ta_rl_ip_ds = gu.rasterlist2dict(mean_rl_list)

    # remove any dates outside of interest period
    dates_to_remove = [key for key in Ta_rl_ip_ds if not (pd.to_datetime(start_date) <= key <= pd.to_datetime(end_date))]
    # Removing the keys
    for date in dates_to_remove:
        del Ta_rl_ip_ds[date]

else:
    Ta_ip_ds, Ta_rl_ip_ds = cdi.compute_ip(da_var[mask, :, :], time_steps[mask], gt, proj, outfolder_ip, unit_scaler=1, deficit=False, gee=True)
# Out:
# Processing IP periods for year 2001
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2001_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2001_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2001_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2001_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2001_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2001_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2001_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2001_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2001_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2001_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2001_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2001_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2001_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2001_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2001_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2001_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2001_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2001_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2001_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2001_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2001_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2001_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2001_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2001_12.tif
#
# Processing IP periods for year 2002
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2002_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2002_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2002_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2002_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2002_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2002_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2002_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2002_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2002_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2002_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2002_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2002_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2002_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2002_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2002_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2002_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2002_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2002_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2002_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2002_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2002_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2002_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2002_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2002_12.tif
#
# Processing IP periods for year 2003
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2003_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2003_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2003_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2003_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2003_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2003_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2003_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2003_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2003_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2003_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2003_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2003_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2003_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2003_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2003_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2003_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2003_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2003_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2003_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2003_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2003_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2003_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2003_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2003_12.tif
#
# Processing IP periods for year 2004
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2004_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2004_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2004_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2004_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2004_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2004_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2004_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2004_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2004_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2004_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2004_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2004_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2004_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2004_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2004_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2004_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2004_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2004_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2004_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2004_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2004_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2004_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2004_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2004_12.tif
#
# Processing IP periods for year 2005
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2005_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2005_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2005_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2005_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2005_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2005_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2005_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2005_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2005_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2005_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2005_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2005_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2005_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2005_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2005_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2005_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2005_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2005_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2005_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2005_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2005_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2005_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2005_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2005_12.tif
#
# Processing IP periods for year 2006
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2006_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2006_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2006_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2006_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2006_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2006_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2006_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2006_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2006_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2006_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2006_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2006_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2006_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2006_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2006_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2006_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2006_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2006_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2006_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2006_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2006_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2006_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2006_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2006_12.tif
#
# Processing IP periods for year 2007
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2007_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2007_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2007_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2007_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2007_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2007_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2007_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2007_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2007_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2007_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2007_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2007_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2007_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2007_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2007_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2007_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2007_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2007_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2007_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2007_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2007_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2007_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2007_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2007_12.tif
#
# Processing IP periods for year 2008
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2008_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2008_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2008_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2008_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2008_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2008_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2008_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2008_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2008_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2008_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2008_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2008_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2008_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2008_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2008_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2008_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2008_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2008_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2008_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2008_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2008_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2008_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2008_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2008_12.tif
#
# Processing IP periods for year 2009
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2009_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2009_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2009_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2009_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2009_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2009_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2009_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2009_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2009_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2009_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2009_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2009_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2009_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2009_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2009_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2009_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2009_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2009_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2009_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2009_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2009_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2009_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2009_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2009_12.tif
#
# Processing IP periods for year 2010
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2010_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2010_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2010_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2010_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2010_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2010_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2010_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2010_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2010_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2010_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2010_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2010_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2010_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2010_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2010_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2010_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2010_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2010_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2010_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2010_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2010_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2010_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2010_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2010_12.tif
#
# Processing IP periods for year 2011
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2011_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2011_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2011_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2011_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2011_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2011_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2011_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2011_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2011_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2011_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2011_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2011_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2011_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2011_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2011_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2011_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2011_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2011_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2011_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2011_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2011_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2011_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2011_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2011_12.tif
#
# Processing IP periods for year 2012
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2012_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2012_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2012_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2012_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2012_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2012_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2012_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2012_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2012_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2012_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2012_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2012_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2012_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2012_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2012_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2012_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2012_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2012_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2012_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2012_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2012_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2012_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2012_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2012_12.tif
#
# Processing IP periods for year 2013
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2013_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2013_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2013_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2013_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2013_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2013_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2013_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2013_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2013_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2013_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2013_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2013_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2013_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2013_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2013_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2013_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2013_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2013_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2013_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2013_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2013_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2013_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2013_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2013_12.tif
#
# Processing IP periods for year 2014
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2014_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2014_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2014_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2014_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2014_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2014_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2014_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2014_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2014_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2014_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2014_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2014_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2014_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2014_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2014_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2014_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2014_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2014_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2014_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2014_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2014_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2014_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2014_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2014_12.tif
#
# Processing IP periods for year 2015
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2015_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2015_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2015_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2015_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2015_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2015_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2015_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2015_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2015_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2015_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2015_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2015_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2015_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2015_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2015_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2015_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2015_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2015_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2015_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2015_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2015_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2015_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2015_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2015_12.tif
#
# Processing IP periods for year 2016
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2016_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2016_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2016_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2016_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2016_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2016_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2016_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2016_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2016_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2016_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2016_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2016_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2016_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2016_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2016_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2016_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2016_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2016_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2016_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2016_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2016_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2016_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2016_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2016_12.tif
#
# Processing IP periods for year 2017
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2017_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2017_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2017_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2017_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2017_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2017_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2017_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2017_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2017_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2017_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2017_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2017_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2017_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2017_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2017_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2017_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2017_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2017_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2017_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2017_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2017_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2017_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2017_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2017_12.tif
#
# Processing IP periods for year 2018
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2018_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2018_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2018_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2018_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2018_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2018_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2018_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2018_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2018_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2018_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2018_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2018_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2018_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2018_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2018_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2018_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2018_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2018_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2018_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2018_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2018_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2018_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2018_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2018_12.tif
#
# Processing IP periods for year 2019
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2019_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2019_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2019_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2019_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2019_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2019_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2019_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2019_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2019_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2019_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2019_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2019_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2019_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2019_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2019_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2019_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2019_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2019_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2019_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2019_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2019_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2019_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2019_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2019_12.tif
#
# Processing IP periods for year 2020
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2020_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2020_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2020_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2020_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2020_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2020_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2020_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2020_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2020_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2020_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2020_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2020_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2020_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2020_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2020_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2020_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2020_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2020_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2020_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2020_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2020_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2020_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2020_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2020_12.tif
#
# Processing IP periods for year 2021
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2021_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2021_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2021_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2021_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2021_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2021_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2021_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2021_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2021_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2021_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2021_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2021_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2021_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2021_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2021_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2021_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2021_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2021_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2021_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2021_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2021_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2021_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2021_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2021_12.tif
#
# Processing IP periods for year 2022
# 	month 1
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2022_1.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2022_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2022_2.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2022_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2022_3.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2022_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2022_4.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2022_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2022_5.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2022_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2022_6.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2022_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2022_7.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2022_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2022_8.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2022_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2022_9.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2022_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2022_10.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2022_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2022_11.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2022_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/Ta/IP/mean/Mean_IP_2022_12.tif
# 	saving result to CDI_data/inputs_downloads/Ta/IP/RL/RL_IP_2022_12.tif

# %% [markdown]
# #### 2.3 Calculate TDI
# Once we have both the LTM and IP values for precipitation, we can calculate the TDI

# %%
# get maximum air temperature during whole period to normalize air temperature when computing TDI
Ta_ar = da_var.values
Ta_max_ar = np.nanmax(Ta_ar)

outfolder = Path() / 'CDI_data' / 'drought_indices'
tdi = cdi.calc_tdi(Ta_ip_ds, Ta_rl_ip_ds, Ta_ltm_ds, Ta_rl_ltm_ds, Ta_max_ar, gt, proj, outfolder)
# Out:
# 2001
# 	Month: 1
# 	saving TDI result for 2001-1 to CDI_data/drought_indices/TDI/TDI_IP_2001_1.tif
#
# 	Month: 2
# 	saving TDI result for 2001-2 to CDI_data/drought_indices/TDI/TDI_IP_2001_2.tif
#
# 	Month: 3
# 	saving TDI result for 2001-3 to CDI_data/drought_indices/TDI/TDI_IP_2001_3.tif
#
# 	Month: 4
# 	saving TDI result for 2001-4 to CDI_data/drought_indices/TDI/TDI_IP_2001_4.tif
#
# 	Month: 5
# 	saving TDI result for 2001-5 to CDI_data/drought_indices/TDI/TDI_IP_2001_5.tif
#
# 	Month: 6
# 	saving TDI result for 2001-6 to CDI_data/drought_indices/TDI/TDI_IP_2001_6.tif
#
# 	Month: 7
# 	saving TDI result for 2001-7 to CDI_data/drought_indices/TDI/TDI_IP_2001_7.tif
#
# 	Month: 8
# 	saving TDI result for 2001-8 to CDI_data/drought_indices/TDI/TDI_IP_2001_8.tif
#
# 	Month: 9
# 	saving TDI result for 2001-9 to CDI_data/drought_indices/TDI/TDI_IP_2001_9.tif
#
# 	Month: 10
# 	saving TDI result for 2001-10 to CDI_data/drought_indices/TDI/TDI_IP_2001_10.tif
#
# 	Month: 11
# 	saving TDI result for 2001-11 to CDI_data/drought_indices/TDI/TDI_IP_2001_11.tif
#
# 	Month: 12
# 	saving TDI result for 2001-12 to CDI_data/drought_indices/TDI/TDI_IP_2001_12.tif
#
# 2002
# 	Month: 1
# 	saving TDI result for 2002-1 to CDI_data/drought_indices/TDI/TDI_IP_2002_1.tif
#
# 	Month: 2
# 	saving TDI result for 2002-2 to CDI_data/drought_indices/TDI/TDI_IP_2002_2.tif
#
# 	Month: 3
# 	saving TDI result for 2002-3 to CDI_data/drought_indices/TDI/TDI_IP_2002_3.tif
#
# 	Month: 4
# 	saving TDI result for 2002-4 to CDI_data/drought_indices/TDI/TDI_IP_2002_4.tif
#
# 	Month: 5
# 	saving TDI result for 2002-5 to CDI_data/drought_indices/TDI/TDI_IP_2002_5.tif
#
# 	Month: 6
# 	saving TDI result for 2002-6 to CDI_data/drought_indices/TDI/TDI_IP_2002_6.tif
#
# 	Month: 7
# 	saving TDI result for 2002-7 to CDI_data/drought_indices/TDI/TDI_IP_2002_7.tif
#
# 	Month: 8
# 	saving TDI result for 2002-8 to CDI_data/drought_indices/TDI/TDI_IP_2002_8.tif
#
# 	Month: 9
# 	saving TDI result for 2002-9 to CDI_data/drought_indices/TDI/TDI_IP_2002_9.tif
#
# 	Month: 10
# 	saving TDI result for 2002-10 to CDI_data/drought_indices/TDI/TDI_IP_2002_10.tif
#
# 	Month: 11
# 	saving TDI result for 2002-11 to CDI_data/drought_indices/TDI/TDI_IP_2002_11.tif
#
# 	Month: 12
# 	saving TDI result for 2002-12 to CDI_data/drought_indices/TDI/TDI_IP_2002_12.tif
#
# 2003
# 	Month: 1
# 	saving TDI result for 2003-1 to CDI_data/drought_indices/TDI/TDI_IP_2003_1.tif
#
# 	Month: 2
# 	saving TDI result for 2003-2 to CDI_data/drought_indices/TDI/TDI_IP_2003_2.tif
#
# 	Month: 3
# 	saving TDI result for 2003-3 to CDI_data/drought_indices/TDI/TDI_IP_2003_3.tif
#
# 	Month: 4
# 	saving TDI result for 2003-4 to CDI_data/drought_indices/TDI/TDI_IP_2003_4.tif
#
# 	Month: 5
# 	saving TDI result for 2003-5 to CDI_data/drought_indices/TDI/TDI_IP_2003_5.tif
#
# 	Month: 6
# 	saving TDI result for 2003-6 to CDI_data/drought_indices/TDI/TDI_IP_2003_6.tif
#
# 	Month: 7
# 	saving TDI result for 2003-7 to CDI_data/drought_indices/TDI/TDI_IP_2003_7.tif
#
# 	Month: 8
# 	saving TDI result for 2003-8 to CDI_data/drought_indices/TDI/TDI_IP_2003_8.tif
#
# 	Month: 9
# 	saving TDI result for 2003-9 to CDI_data/drought_indices/TDI/TDI_IP_2003_9.tif
#
# 	Month: 10
# 	saving TDI result for 2003-10 to CDI_data/drought_indices/TDI/TDI_IP_2003_10.tif
#
# 	Month: 11
# 	saving TDI result for 2003-11 to CDI_data/drought_indices/TDI/TDI_IP_2003_11.tif
#
# 	Month: 12
# 	saving TDI result for 2003-12 to CDI_data/drought_indices/TDI/TDI_IP_2003_12.tif
#
# 2004
# 	Month: 1
# 	saving TDI result for 2004-1 to CDI_data/drought_indices/TDI/TDI_IP_2004_1.tif
#
# 	Month: 2
# 	saving TDI result for 2004-2 to CDI_data/drought_indices/TDI/TDI_IP_2004_2.tif
#
# 	Month: 3
# 	saving TDI result for 2004-3 to CDI_data/drought_indices/TDI/TDI_IP_2004_3.tif
#
# 	Month: 4
# 	saving TDI result for 2004-4 to CDI_data/drought_indices/TDI/TDI_IP_2004_4.tif
#
# 	Month: 5
# 	saving TDI result for 2004-5 to CDI_data/drought_indices/TDI/TDI_IP_2004_5.tif
#
# 	Month: 6
# 	saving TDI result for 2004-6 to CDI_data/drought_indices/TDI/TDI_IP_2004_6.tif
#
# 	Month: 7
# 	saving TDI result for 2004-7 to CDI_data/drought_indices/TDI/TDI_IP_2004_7.tif
#
# 	Month: 8
# 	saving TDI result for 2004-8 to CDI_data/drought_indices/TDI/TDI_IP_2004_8.tif
#
# 	Month: 9
# 	saving TDI result for 2004-9 to CDI_data/drought_indices/TDI/TDI_IP_2004_9.tif
#
# 	Month: 10
# 	saving TDI result for 2004-10 to CDI_data/drought_indices/TDI/TDI_IP_2004_10.tif
#
# 	Month: 11
# 	saving TDI result for 2004-11 to CDI_data/drought_indices/TDI/TDI_IP_2004_11.tif
#
# 	Month: 12
# 	saving TDI result for 2004-12 to CDI_data/drought_indices/TDI/TDI_IP_2004_12.tif
#
# 2005
# 	Month: 1
# 	saving TDI result for 2005-1 to CDI_data/drought_indices/TDI/TDI_IP_2005_1.tif
#
# 	Month: 2
# 	saving TDI result for 2005-2 to CDI_data/drought_indices/TDI/TDI_IP_2005_2.tif
#
# 	Month: 3
# 	saving TDI result for 2005-3 to CDI_data/drought_indices/TDI/TDI_IP_2005_3.tif
#
# 	Month: 4
# 	saving TDI result for 2005-4 to CDI_data/drought_indices/TDI/TDI_IP_2005_4.tif
#
# 	Month: 5
# 	saving TDI result for 2005-5 to CDI_data/drought_indices/TDI/TDI_IP_2005_5.tif
#
# 	Month: 6
# 	saving TDI result for 2005-6 to CDI_data/drought_indices/TDI/TDI_IP_2005_6.tif
#
# 	Month: 7
# 	saving TDI result for 2005-7 to CDI_data/drought_indices/TDI/TDI_IP_2005_7.tif
#
# 	Month: 8
# 	saving TDI result for 2005-8 to CDI_data/drought_indices/TDI/TDI_IP_2005_8.tif
#
# 	Month: 9
# 	saving TDI result for 2005-9 to CDI_data/drought_indices/TDI/TDI_IP_2005_9.tif
#
# 	Month: 10
# 	saving TDI result for 2005-10 to CDI_data/drought_indices/TDI/TDI_IP_2005_10.tif
#
# 	Month: 11
# 	saving TDI result for 2005-11 to CDI_data/drought_indices/TDI/TDI_IP_2005_11.tif
#
# 	Month: 12
# 	saving TDI result for 2005-12 to CDI_data/drought_indices/TDI/TDI_IP_2005_12.tif
#
# 2006
# 	Month: 1
# 	saving TDI result for 2006-1 to CDI_data/drought_indices/TDI/TDI_IP_2006_1.tif
#
# 	Month: 2
# 	saving TDI result for 2006-2 to CDI_data/drought_indices/TDI/TDI_IP_2006_2.tif
#
# 	Month: 3
# 	saving TDI result for 2006-3 to CDI_data/drought_indices/TDI/TDI_IP_2006_3.tif
#
# 	Month: 4
# 	saving TDI result for 2006-4 to CDI_data/drought_indices/TDI/TDI_IP_2006_4.tif
#
# 	Month: 5
# 	saving TDI result for 2006-5 to CDI_data/drought_indices/TDI/TDI_IP_2006_5.tif
#
# 	Month: 6
# 	saving TDI result for 2006-6 to CDI_data/drought_indices/TDI/TDI_IP_2006_6.tif
#
# 	Month: 7
# 	saving TDI result for 2006-7 to CDI_data/drought_indices/TDI/TDI_IP_2006_7.tif
#
# 	Month: 8
# 	saving TDI result for 2006-8 to CDI_data/drought_indices/TDI/TDI_IP_2006_8.tif
#
# 	Month: 9
# 	saving TDI result for 2006-9 to CDI_data/drought_indices/TDI/TDI_IP_2006_9.tif
#
# 	Month: 10
# 	saving TDI result for 2006-10 to CDI_data/drought_indices/TDI/TDI_IP_2006_10.tif
#
# 	Month: 11
# 	saving TDI result for 2006-11 to CDI_data/drought_indices/TDI/TDI_IP_2006_11.tif
#
# 	Month: 12
# 	saving TDI result for 2006-12 to CDI_data/drought_indices/TDI/TDI_IP_2006_12.tif
#
# 2007
# 	Month: 1
# 	saving TDI result for 2007-1 to CDI_data/drought_indices/TDI/TDI_IP_2007_1.tif
#
# 	Month: 2
# 	saving TDI result for 2007-2 to CDI_data/drought_indices/TDI/TDI_IP_2007_2.tif
#
# 	Month: 3
# 	saving TDI result for 2007-3 to CDI_data/drought_indices/TDI/TDI_IP_2007_3.tif
#
# 	Month: 4
# 	saving TDI result for 2007-4 to CDI_data/drought_indices/TDI/TDI_IP_2007_4.tif
#
# 	Month: 5
# 	saving TDI result for 2007-5 to CDI_data/drought_indices/TDI/TDI_IP_2007_5.tif
#
# 	Month: 6
# 	saving TDI result for 2007-6 to CDI_data/drought_indices/TDI/TDI_IP_2007_6.tif
#
# 	Month: 7
# 	saving TDI result for 2007-7 to CDI_data/drought_indices/TDI/TDI_IP_2007_7.tif
#
# 	Month: 8
# 	saving TDI result for 2007-8 to CDI_data/drought_indices/TDI/TDI_IP_2007_8.tif
#
# 	Month: 9
# 	saving TDI result for 2007-9 to CDI_data/drought_indices/TDI/TDI_IP_2007_9.tif
#
# 	Month: 10
# 	saving TDI result for 2007-10 to CDI_data/drought_indices/TDI/TDI_IP_2007_10.tif
#
# 	Month: 11
# 	saving TDI result for 2007-11 to CDI_data/drought_indices/TDI/TDI_IP_2007_11.tif
#
# 	Month: 12
# 	saving TDI result for 2007-12 to CDI_data/drought_indices/TDI/TDI_IP_2007_12.tif
#
# 2008
# 	Month: 1
# 	saving TDI result for 2008-1 to CDI_data/drought_indices/TDI/TDI_IP_2008_1.tif
#
# 	Month: 2
# 	saving TDI result for 2008-2 to CDI_data/drought_indices/TDI/TDI_IP_2008_2.tif
#
# 	Month: 3
# 	saving TDI result for 2008-3 to CDI_data/drought_indices/TDI/TDI_IP_2008_3.tif
#
# 	Month: 4
# 	saving TDI result for 2008-4 to CDI_data/drought_indices/TDI/TDI_IP_2008_4.tif
#
# 	Month: 5
# 	saving TDI result for 2008-5 to CDI_data/drought_indices/TDI/TDI_IP_2008_5.tif
#
# 	Month: 6
# 	saving TDI result for 2008-6 to CDI_data/drought_indices/TDI/TDI_IP_2008_6.tif
#
# 	Month: 7
# 	saving TDI result for 2008-7 to CDI_data/drought_indices/TDI/TDI_IP_2008_7.tif
#
# 	Month: 8
# 	saving TDI result for 2008-8 to CDI_data/drought_indices/TDI/TDI_IP_2008_8.tif
#
# 	Month: 9
# 	saving TDI result for 2008-9 to CDI_data/drought_indices/TDI/TDI_IP_2008_9.tif
#
# 	Month: 10
# 	saving TDI result for 2008-10 to CDI_data/drought_indices/TDI/TDI_IP_2008_10.tif
#
# 	Month: 11
# 	saving TDI result for 2008-11 to CDI_data/drought_indices/TDI/TDI_IP_2008_11.tif
#
# 	Month: 12
# 	saving TDI result for 2008-12 to CDI_data/drought_indices/TDI/TDI_IP_2008_12.tif
#
# 2009
# 	Month: 1
# 	saving TDI result for 2009-1 to CDI_data/drought_indices/TDI/TDI_IP_2009_1.tif
#
# 	Month: 2
# 	saving TDI result for 2009-2 to CDI_data/drought_indices/TDI/TDI_IP_2009_2.tif
#
# 	Month: 3
# 	saving TDI result for 2009-3 to CDI_data/drought_indices/TDI/TDI_IP_2009_3.tif
#
# 	Month: 4
# 	saving TDI result for 2009-4 to CDI_data/drought_indices/TDI/TDI_IP_2009_4.tif
#
# 	Month: 5
# 	saving TDI result for 2009-5 to CDI_data/drought_indices/TDI/TDI_IP_2009_5.tif
#
# 	Month: 6
# 	saving TDI result for 2009-6 to CDI_data/drought_indices/TDI/TDI_IP_2009_6.tif
#
# 	Month: 7
# 	saving TDI result for 2009-7 to CDI_data/drought_indices/TDI/TDI_IP_2009_7.tif
#
# 	Month: 8
# 	saving TDI result for 2009-8 to CDI_data/drought_indices/TDI/TDI_IP_2009_8.tif
#
# 	Month: 9
# 	saving TDI result for 2009-9 to CDI_data/drought_indices/TDI/TDI_IP_2009_9.tif
#
# 	Month: 10
# 	saving TDI result for 2009-10 to CDI_data/drought_indices/TDI/TDI_IP_2009_10.tif
#
# 	Month: 11
# 	saving TDI result for 2009-11 to CDI_data/drought_indices/TDI/TDI_IP_2009_11.tif
#
# 	Month: 12
# 	saving TDI result for 2009-12 to CDI_data/drought_indices/TDI/TDI_IP_2009_12.tif
#
# 2010
# 	Month: 1
# 	saving TDI result for 2010-1 to CDI_data/drought_indices/TDI/TDI_IP_2010_1.tif
#
# 	Month: 2
# 	saving TDI result for 2010-2 to CDI_data/drought_indices/TDI/TDI_IP_2010_2.tif
#
# 	Month: 3
# 	saving TDI result for 2010-3 to CDI_data/drought_indices/TDI/TDI_IP_2010_3.tif
#
# 	Month: 4
# 	saving TDI result for 2010-4 to CDI_data/drought_indices/TDI/TDI_IP_2010_4.tif
#
# 	Month: 5
# 	saving TDI result for 2010-5 to CDI_data/drought_indices/TDI/TDI_IP_2010_5.tif
#
# 	Month: 6
# 	saving TDI result for 2010-6 to CDI_data/drought_indices/TDI/TDI_IP_2010_6.tif
#
# 	Month: 7
# 	saving TDI result for 2010-7 to CDI_data/drought_indices/TDI/TDI_IP_2010_7.tif
#
# 	Month: 8
# 	saving TDI result for 2010-8 to CDI_data/drought_indices/TDI/TDI_IP_2010_8.tif
#
# 	Month: 9
# 	saving TDI result for 2010-9 to CDI_data/drought_indices/TDI/TDI_IP_2010_9.tif
#
# 	Month: 10
# 	saving TDI result for 2010-10 to CDI_data/drought_indices/TDI/TDI_IP_2010_10.tif
#
# 	Month: 11
# 	saving TDI result for 2010-11 to CDI_data/drought_indices/TDI/TDI_IP_2010_11.tif
#
# 	Month: 12
# 	saving TDI result for 2010-12 to CDI_data/drought_indices/TDI/TDI_IP_2010_12.tif
#
# 2011
# 	Month: 1
# 	saving TDI result for 2011-1 to CDI_data/drought_indices/TDI/TDI_IP_2011_1.tif
#
# 	Month: 2
# 	saving TDI result for 2011-2 to CDI_data/drought_indices/TDI/TDI_IP_2011_2.tif
#
# 	Month: 3
# 	saving TDI result for 2011-3 to CDI_data/drought_indices/TDI/TDI_IP_2011_3.tif
#
# 	Month: 4
# 	saving TDI result for 2011-4 to CDI_data/drought_indices/TDI/TDI_IP_2011_4.tif
#
# 	Month: 5
# 	saving TDI result for 2011-5 to CDI_data/drought_indices/TDI/TDI_IP_2011_5.tif
#
# 	Month: 6
# 	saving TDI result for 2011-6 to CDI_data/drought_indices/TDI/TDI_IP_2011_6.tif
#
# 	Month: 7
# 	saving TDI result for 2011-7 to CDI_data/drought_indices/TDI/TDI_IP_2011_7.tif
#
# 	Month: 8
# 	saving TDI result for 2011-8 to CDI_data/drought_indices/TDI/TDI_IP_2011_8.tif
#
# 	Month: 9
# 	saving TDI result for 2011-9 to CDI_data/drought_indices/TDI/TDI_IP_2011_9.tif
#
# 	Month: 10
# 	saving TDI result for 2011-10 to CDI_data/drought_indices/TDI/TDI_IP_2011_10.tif
#
# 	Month: 11
# 	saving TDI result for 2011-11 to CDI_data/drought_indices/TDI/TDI_IP_2011_11.tif
#
# 	Month: 12
# 	saving TDI result for 2011-12 to CDI_data/drought_indices/TDI/TDI_IP_2011_12.tif
#
# 2012
# 	Month: 1
# 	saving TDI result for 2012-1 to CDI_data/drought_indices/TDI/TDI_IP_2012_1.tif
#
# 	Month: 2
# 	saving TDI result for 2012-2 to CDI_data/drought_indices/TDI/TDI_IP_2012_2.tif
#
# 	Month: 3
# 	saving TDI result for 2012-3 to CDI_data/drought_indices/TDI/TDI_IP_2012_3.tif
#
# 	Month: 4
# 	saving TDI result for 2012-4 to CDI_data/drought_indices/TDI/TDI_IP_2012_4.tif
#
# 	Month: 5
# 	saving TDI result for 2012-5 to CDI_data/drought_indices/TDI/TDI_IP_2012_5.tif
#
# 	Month: 6
# 	saving TDI result for 2012-6 to CDI_data/drought_indices/TDI/TDI_IP_2012_6.tif
#
# 	Month: 7
# 	saving TDI result for 2012-7 to CDI_data/drought_indices/TDI/TDI_IP_2012_7.tif
#
# 	Month: 8
# 	saving TDI result for 2012-8 to CDI_data/drought_indices/TDI/TDI_IP_2012_8.tif
#
# 	Month: 9
# 	saving TDI result for 2012-9 to CDI_data/drought_indices/TDI/TDI_IP_2012_9.tif
#
# 	Month: 10
# 	saving TDI result for 2012-10 to CDI_data/drought_indices/TDI/TDI_IP_2012_10.tif
#
# 	Month: 11
# 	saving TDI result for 2012-11 to CDI_data/drought_indices/TDI/TDI_IP_2012_11.tif
#
# 	Month: 12
# 	saving TDI result for 2012-12 to CDI_data/drought_indices/TDI/TDI_IP_2012_12.tif
#
# 2013
# 	Month: 1
# 	saving TDI result for 2013-1 to CDI_data/drought_indices/TDI/TDI_IP_2013_1.tif
#
# 	Month: 2
# 	saving TDI result for 2013-2 to CDI_data/drought_indices/TDI/TDI_IP_2013_2.tif
#
# 	Month: 3
# 	saving TDI result for 2013-3 to CDI_data/drought_indices/TDI/TDI_IP_2013_3.tif
#
# 	Month: 4
# 	saving TDI result for 2013-4 to CDI_data/drought_indices/TDI/TDI_IP_2013_4.tif
#
# 	Month: 5
# 	saving TDI result for 2013-5 to CDI_data/drought_indices/TDI/TDI_IP_2013_5.tif
#
# 	Month: 6
# 	saving TDI result for 2013-6 to CDI_data/drought_indices/TDI/TDI_IP_2013_6.tif
#
# 	Month: 7
# 	saving TDI result for 2013-7 to CDI_data/drought_indices/TDI/TDI_IP_2013_7.tif
#
# 	Month: 8
# 	saving TDI result for 2013-8 to CDI_data/drought_indices/TDI/TDI_IP_2013_8.tif
#
# 	Month: 9
# 	saving TDI result for 2013-9 to CDI_data/drought_indices/TDI/TDI_IP_2013_9.tif
#
# 	Month: 10
# 	saving TDI result for 2013-10 to CDI_data/drought_indices/TDI/TDI_IP_2013_10.tif
#
# 	Month: 11
# 	saving TDI result for 2013-11 to CDI_data/drought_indices/TDI/TDI_IP_2013_11.tif
#
# 	Month: 12
# 	saving TDI result for 2013-12 to CDI_data/drought_indices/TDI/TDI_IP_2013_12.tif
#
# 2014
# 	Month: 1
# 	saving TDI result for 2014-1 to CDI_data/drought_indices/TDI/TDI_IP_2014_1.tif
#
# 	Month: 2
# 	saving TDI result for 2014-2 to CDI_data/drought_indices/TDI/TDI_IP_2014_2.tif
#
# 	Month: 3
# 	saving TDI result for 2014-3 to CDI_data/drought_indices/TDI/TDI_IP_2014_3.tif
#
# 	Month: 4
# 	saving TDI result for 2014-4 to CDI_data/drought_indices/TDI/TDI_IP_2014_4.tif
#
# 	Month: 5
# 	saving TDI result for 2014-5 to CDI_data/drought_indices/TDI/TDI_IP_2014_5.tif
#
# 	Month: 6
# 	saving TDI result for 2014-6 to CDI_data/drought_indices/TDI/TDI_IP_2014_6.tif
#
# 	Month: 7
# 	saving TDI result for 2014-7 to CDI_data/drought_indices/TDI/TDI_IP_2014_7.tif
#
# 	Month: 8
# 	saving TDI result for 2014-8 to CDI_data/drought_indices/TDI/TDI_IP_2014_8.tif
#
# 	Month: 9
# 	saving TDI result for 2014-9 to CDI_data/drought_indices/TDI/TDI_IP_2014_9.tif
#
# 	Month: 10
# 	saving TDI result for 2014-10 to CDI_data/drought_indices/TDI/TDI_IP_2014_10.tif
#
# 	Month: 11
# 	saving TDI result for 2014-11 to CDI_data/drought_indices/TDI/TDI_IP_2014_11.tif
#
# 	Month: 12
# 	saving TDI result for 2014-12 to CDI_data/drought_indices/TDI/TDI_IP_2014_12.tif
#
# 2015
# 	Month: 1
# 	saving TDI result for 2015-1 to CDI_data/drought_indices/TDI/TDI_IP_2015_1.tif
#
# 	Month: 2
# 	saving TDI result for 2015-2 to CDI_data/drought_indices/TDI/TDI_IP_2015_2.tif
#
# 	Month: 3
# 	saving TDI result for 2015-3 to CDI_data/drought_indices/TDI/TDI_IP_2015_3.tif
#
# 	Month: 4
# 	saving TDI result for 2015-4 to CDI_data/drought_indices/TDI/TDI_IP_2015_4.tif
#
# 	Month: 5
# 	saving TDI result for 2015-5 to CDI_data/drought_indices/TDI/TDI_IP_2015_5.tif
#
# 	Month: 6
# 	saving TDI result for 2015-6 to CDI_data/drought_indices/TDI/TDI_IP_2015_6.tif
#
# 	Month: 7
# 	saving TDI result for 2015-7 to CDI_data/drought_indices/TDI/TDI_IP_2015_7.tif
#
# 	Month: 8
# 	saving TDI result for 2015-8 to CDI_data/drought_indices/TDI/TDI_IP_2015_8.tif
#
# 	Month: 9
# 	saving TDI result for 2015-9 to CDI_data/drought_indices/TDI/TDI_IP_2015_9.tif
#
# 	Month: 10
# 	saving TDI result for 2015-10 to CDI_data/drought_indices/TDI/TDI_IP_2015_10.tif
#
# 	Month: 11
# 	saving TDI result for 2015-11 to CDI_data/drought_indices/TDI/TDI_IP_2015_11.tif
#
# 	Month: 12
# 	saving TDI result for 2015-12 to CDI_data/drought_indices/TDI/TDI_IP_2015_12.tif
#
# 2016
# 	Month: 1
# 	saving TDI result for 2016-1 to CDI_data/drought_indices/TDI/TDI_IP_2016_1.tif
#
# 	Month: 2
# 	saving TDI result for 2016-2 to CDI_data/drought_indices/TDI/TDI_IP_2016_2.tif
#
# 	Month: 3
# 	saving TDI result for 2016-3 to CDI_data/drought_indices/TDI/TDI_IP_2016_3.tif
#
# 	Month: 4
# 	saving TDI result for 2016-4 to CDI_data/drought_indices/TDI/TDI_IP_2016_4.tif
#
# 	Month: 5
# 	saving TDI result for 2016-5 to CDI_data/drought_indices/TDI/TDI_IP_2016_5.tif
#
# 	Month: 6
# 	saving TDI result for 2016-6 to CDI_data/drought_indices/TDI/TDI_IP_2016_6.tif
#
# 	Month: 7
# 	saving TDI result for 2016-7 to CDI_data/drought_indices/TDI/TDI_IP_2016_7.tif
#
# 	Month: 8
# 	saving TDI result for 2016-8 to CDI_data/drought_indices/TDI/TDI_IP_2016_8.tif
#
# 	Month: 9
# 	saving TDI result for 2016-9 to CDI_data/drought_indices/TDI/TDI_IP_2016_9.tif
#
# 	Month: 10
# 	saving TDI result for 2016-10 to CDI_data/drought_indices/TDI/TDI_IP_2016_10.tif
#
# 	Month: 11
# 	saving TDI result for 2016-11 to CDI_data/drought_indices/TDI/TDI_IP_2016_11.tif
#
# 	Month: 12
# 	saving TDI result for 2016-12 to CDI_data/drought_indices/TDI/TDI_IP_2016_12.tif
#
# 2017
# 	Month: 1
# 	saving TDI result for 2017-1 to CDI_data/drought_indices/TDI/TDI_IP_2017_1.tif
#
# 	Month: 2
# 	saving TDI result for 2017-2 to CDI_data/drought_indices/TDI/TDI_IP_2017_2.tif
#
# 	Month: 3
# 	saving TDI result for 2017-3 to CDI_data/drought_indices/TDI/TDI_IP_2017_3.tif
#
# 	Month: 4
# 	saving TDI result for 2017-4 to CDI_data/drought_indices/TDI/TDI_IP_2017_4.tif
#
# 	Month: 5
# 	saving TDI result for 2017-5 to CDI_data/drought_indices/TDI/TDI_IP_2017_5.tif
#
# 	Month: 6
# 	saving TDI result for 2017-6 to CDI_data/drought_indices/TDI/TDI_IP_2017_6.tif
#
# 	Month: 7
# 	saving TDI result for 2017-7 to CDI_data/drought_indices/TDI/TDI_IP_2017_7.tif
#
# 	Month: 8
# 	saving TDI result for 2017-8 to CDI_data/drought_indices/TDI/TDI_IP_2017_8.tif
#
# 	Month: 9
# 	saving TDI result for 2017-9 to CDI_data/drought_indices/TDI/TDI_IP_2017_9.tif
#
# 	Month: 10
# 	saving TDI result for 2017-10 to CDI_data/drought_indices/TDI/TDI_IP_2017_10.tif
#
# 	Month: 11
# 	saving TDI result for 2017-11 to CDI_data/drought_indices/TDI/TDI_IP_2017_11.tif
#
# 	Month: 12
# 	saving TDI result for 2017-12 to CDI_data/drought_indices/TDI/TDI_IP_2017_12.tif
#
# 2018
# 	Month: 1
# 	saving TDI result for 2018-1 to CDI_data/drought_indices/TDI/TDI_IP_2018_1.tif
#
# 	Month: 2
# 	saving TDI result for 2018-2 to CDI_data/drought_indices/TDI/TDI_IP_2018_2.tif
#
# 	Month: 3
# 	saving TDI result for 2018-3 to CDI_data/drought_indices/TDI/TDI_IP_2018_3.tif
#
# 	Month: 4
# 	saving TDI result for 2018-4 to CDI_data/drought_indices/TDI/TDI_IP_2018_4.tif
#
# 	Month: 5
# 	saving TDI result for 2018-5 to CDI_data/drought_indices/TDI/TDI_IP_2018_5.tif
#
# 	Month: 6
# 	saving TDI result for 2018-6 to CDI_data/drought_indices/TDI/TDI_IP_2018_6.tif
#
# 	Month: 7
# 	saving TDI result for 2018-7 to CDI_data/drought_indices/TDI/TDI_IP_2018_7.tif
#
# 	Month: 8
# 	saving TDI result for 2018-8 to CDI_data/drought_indices/TDI/TDI_IP_2018_8.tif
#
# 	Month: 9
# 	saving TDI result for 2018-9 to CDI_data/drought_indices/TDI/TDI_IP_2018_9.tif
#
# 	Month: 10
# 	saving TDI result for 2018-10 to CDI_data/drought_indices/TDI/TDI_IP_2018_10.tif
#
# 	Month: 11
# 	saving TDI result for 2018-11 to CDI_data/drought_indices/TDI/TDI_IP_2018_11.tif
#
# 	Month: 12
# 	saving TDI result for 2018-12 to CDI_data/drought_indices/TDI/TDI_IP_2018_12.tif
#
# 2019
# 	Month: 1
# 	saving TDI result for 2019-1 to CDI_data/drought_indices/TDI/TDI_IP_2019_1.tif
#
# 	Month: 2
# 	saving TDI result for 2019-2 to CDI_data/drought_indices/TDI/TDI_IP_2019_2.tif
#
# 	Month: 3
# 	saving TDI result for 2019-3 to CDI_data/drought_indices/TDI/TDI_IP_2019_3.tif
#
# 	Month: 4
# 	saving TDI result for 2019-4 to CDI_data/drought_indices/TDI/TDI_IP_2019_4.tif
#
# 	Month: 5
# 	saving TDI result for 2019-5 to CDI_data/drought_indices/TDI/TDI_IP_2019_5.tif
#
# 	Month: 6
# 	saving TDI result for 2019-6 to CDI_data/drought_indices/TDI/TDI_IP_2019_6.tif
#
# 	Month: 7
# 	saving TDI result for 2019-7 to CDI_data/drought_indices/TDI/TDI_IP_2019_7.tif
#
# 	Month: 8
# 	saving TDI result for 2019-8 to CDI_data/drought_indices/TDI/TDI_IP_2019_8.tif
#
# 	Month: 9
# 	saving TDI result for 2019-9 to CDI_data/drought_indices/TDI/TDI_IP_2019_9.tif
#
# 	Month: 10
# 	saving TDI result for 2019-10 to CDI_data/drought_indices/TDI/TDI_IP_2019_10.tif
#
# 	Month: 11
# 	saving TDI result for 2019-11 to CDI_data/drought_indices/TDI/TDI_IP_2019_11.tif
#
# 	Month: 12
# 	saving TDI result for 2019-12 to CDI_data/drought_indices/TDI/TDI_IP_2019_12.tif
#
# 2020
# 	Month: 1
# 	saving TDI result for 2020-1 to CDI_data/drought_indices/TDI/TDI_IP_2020_1.tif
#
# 	Month: 2
# 	saving TDI result for 2020-2 to CDI_data/drought_indices/TDI/TDI_IP_2020_2.tif
#
# 	Month: 3
# 	saving TDI result for 2020-3 to CDI_data/drought_indices/TDI/TDI_IP_2020_3.tif
#
# 	Month: 4
# 	saving TDI result for 2020-4 to CDI_data/drought_indices/TDI/TDI_IP_2020_4.tif
#
# 	Month: 5
# 	saving TDI result for 2020-5 to CDI_data/drought_indices/TDI/TDI_IP_2020_5.tif
#
# 	Month: 6
# 	saving TDI result for 2020-6 to CDI_data/drought_indices/TDI/TDI_IP_2020_6.tif
#
# 	Month: 7
# 	saving TDI result for 2020-7 to CDI_data/drought_indices/TDI/TDI_IP_2020_7.tif
#
# 	Month: 8
# 	saving TDI result for 2020-8 to CDI_data/drought_indices/TDI/TDI_IP_2020_8.tif
#
# 	Month: 9
# 	saving TDI result for 2020-9 to CDI_data/drought_indices/TDI/TDI_IP_2020_9.tif
#
# 	Month: 10
# 	saving TDI result for 2020-10 to CDI_data/drought_indices/TDI/TDI_IP_2020_10.tif
#
# 	Month: 11
# 	saving TDI result for 2020-11 to CDI_data/drought_indices/TDI/TDI_IP_2020_11.tif
#
# 	Month: 12
# 	saving TDI result for 2020-12 to CDI_data/drought_indices/TDI/TDI_IP_2020_12.tif
#
# 2021
# 	Month: 1
# 	saving TDI result for 2021-1 to CDI_data/drought_indices/TDI/TDI_IP_2021_1.tif
#
# 	Month: 2
# 	saving TDI result for 2021-2 to CDI_data/drought_indices/TDI/TDI_IP_2021_2.tif
#
# 	Month: 3
# 	saving TDI result for 2021-3 to CDI_data/drought_indices/TDI/TDI_IP_2021_3.tif
#
# 	Month: 4
# 	saving TDI result for 2021-4 to CDI_data/drought_indices/TDI/TDI_IP_2021_4.tif
#
# 	Month: 5
# 	saving TDI result for 2021-5 to CDI_data/drought_indices/TDI/TDI_IP_2021_5.tif
#
# 	Month: 6
# 	saving TDI result for 2021-6 to CDI_data/drought_indices/TDI/TDI_IP_2021_6.tif
#
# 	Month: 7
# 	saving TDI result for 2021-7 to CDI_data/drought_indices/TDI/TDI_IP_2021_7.tif
#
# 	Month: 8
# 	saving TDI result for 2021-8 to CDI_data/drought_indices/TDI/TDI_IP_2021_8.tif
#
# 	Month: 9
# 	saving TDI result for 2021-9 to CDI_data/drought_indices/TDI/TDI_IP_2021_9.tif
#
# 	Month: 10
# 	saving TDI result for 2021-10 to CDI_data/drought_indices/TDI/TDI_IP_2021_10.tif
#
# 	Month: 11
# 	saving TDI result for 2021-11 to CDI_data/drought_indices/TDI/TDI_IP_2021_11.tif
#
# 	Month: 12
# 	saving TDI result for 2021-12 to CDI_data/drought_indices/TDI/TDI_IP_2021_12.tif
#
# 2022
# 	Month: 1
# 	saving TDI result for 2022-1 to CDI_data/drought_indices/TDI/TDI_IP_2022_1.tif
#
# 	Month: 2
# 	saving TDI result for 2022-2 to CDI_data/drought_indices/TDI/TDI_IP_2022_2.tif
#
# 	Month: 3
# 	saving TDI result for 2022-3 to CDI_data/drought_indices/TDI/TDI_IP_2022_3.tif
#
# 	Month: 4
# 	saving TDI result for 2022-4 to CDI_data/drought_indices/TDI/TDI_IP_2022_4.tif
#
# 	Month: 5
# 	saving TDI result for 2022-5 to CDI_data/drought_indices/TDI/TDI_IP_2022_5.tif
#
# 	Month: 6
# 	saving TDI result for 2022-6 to CDI_data/drought_indices/TDI/TDI_IP_2022_6.tif
#
# 	Month: 7
# 	saving TDI result for 2022-7 to CDI_data/drought_indices/TDI/TDI_IP_2022_7.tif
#
# 	Month: 8
# 	saving TDI result for 2022-8 to CDI_data/drought_indices/TDI/TDI_IP_2022_8.tif
#
# 	Month: 9
# 	saving TDI result for 2022-9 to CDI_data/drought_indices/TDI/TDI_IP_2022_9.tif
#
# 	Month: 10
# 	saving TDI result for 2022-10 to CDI_data/drought_indices/TDI/TDI_IP_2022_10.tif
#
# 	Month: 11
# 	saving TDI result for 2022-11 to CDI_data/drought_indices/TDI/TDI_IP_2022_11.tif
#
# 	Month: 12
# 	saving TDI result for 2022-12 to CDI_data/drought_indices/TDI/TDI_IP_2022_12.tif

# %% [markdown]
# ### 3. VDI estimation
#
# In this case of VDI, we will use NDVI as a proxie of vegetation vigor. We will process the monthly values from the 8-day surface reflectance product from MODIS through the STAC browser of the [Microsoft Planetry Computer](https://planetarycomputer.microsoft.com/dataset/modis-09Q1-061)
#
# #### 3.1 Deriving monthly mean NDVI
#
# As a first step we need to get monthly mean NDVI from these 8-day products

# %%
# select start and end date
start_date = '2001-01-01'
end_date = '2022-12-31'

# for ndvi product we use microsoft planetery computer STAC
stac = 'https://planetarycomputer.microsoft.com/api/stac/v1'

# 8-day surface reflectance (250m)
collection = 'modis-09Q1-061'
da = cubo.create(lat, lon,
                 collection,
                 start_date,
                 end_date,
                 bands=['sur_refl_b01', 'sur_refl_b02', 'sur_refl_qc_250m'],
                 edge_size=1400, # 1400 roughly size of roi
                 resolution=250,
                 stac=stac,
                 )

da = da.assign_coords(epsg=da.attrs['epsg'])
da = da.rio.write_crs(f"EPSG:{da['epsg'].data}")
# get georeferencing metadata
epsg_code = da.attrs['epsg']
center_x = da.attrs['central_x']
center_y = da.attrs['central_y']
width = da.attrs['edge_size']
pixel_size = da.attrs['resolution']

gt = gu.calculate_geotransform(center_x, center_y, pixel_size, width, width)
proj = CRS.from_epsg(epsg_code).wkt
# use start datetime as time (some issues with original time domain)
da['time'] = da['start_datetime']
# Out:
# /Users/vicenteburchard/miniconda3/envs/sentseb/lib/python3.9/site-packages/stackstac/prepare.py:408: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   times = pd.to_datetime(

# %% [markdown]
# #### 3.1 Deriving monthly mean NDVI
#
# As a first step we need to get monthly mean NDVI from these 8-day products. If these data were already produced, simply set ndvi_produced=True.

# %%
ndvi_produced = True

outfolder_ndvi = Path() / 'CDI_data' / 'inputs_downloads' / 'ndvi'
if ndvi_produced:
    mean_folder = outfolder_ndvi / 'monthly_rasters'
    mean_list = sorted(list(mean_folder.glob('*.tif')))
    ndvi_monthly = gu.rasterlist2xarray(mean_list)
else:
    ndvi_monthly = cdi.compute_ndvi_monthly(da, start_date, end_date, gt, proj, outfolder_ndvi)

# convert xarray to DataArray to match cubo array type
# Define dimensions and coordinates
dims = ('time', 'x', 'y')  # Example dimensions
coords = {'time': ndvi_monthly['time'].values, 'x': ndvi_monthly['x'].values, 'y': ndvi_monthly['y'].values}
# store in xarray DataArray
da_ndvi = xr.DataArray(data=ndvi_monthly.to_array(), dims=dims, coords=coords)
date_mask = np.logical_and(da_ndvi['time'] >= pd.to_datetime(start_date), da_ndvi['time'] <= pd.to_datetime(end_date))
da_ndvi = da_ndvi[date_mask, :, :]
# sort data array by time
da_ndvi = da_ndvi.sortby('time')

time_steps = pd.to_datetime(da_ndvi['time'])
years = time_steps.year
months = time_steps.month

# %% [markdown]
# #### 3.2 calculation of Long-term-mean (LTM) of NDVI
# we will use the output of the monthly mean processed above to calculate the LTM, which was stored in xarray dataset similar to maintain consistency with the processing of precipitation and air temperature

# %%
# set output folder
outfolder_ndvi_ltm = Path() / 'CDI_data' / 'inputs_downloads' / 'ndvi'/'LTM'

ltm_produced = False
if ltm_produced:
    # get mean data

    mean_ltm_folder = outfolder_ndvi_ltm / 'mean'
    mean_img_list = sorted(list(mean_ltm_folder.glob('*.tif')))
    ndvi_ltm_ds = gu.rasterlist2dict(mean_img_list)
    
    # get RL data
    rl_img_folder = outfolder_ndvi_ltm / 'RL'
    rl_img_list = sorted(list(rl_img_folder.glob('*.tif')))
    ndvi_rl_ltm_ds = gu.rasterlist2dict(rl_img_list)

else:
    ndvi_ltm_ds, ndvi_rl_ltm_ds = cdi.compute_ltm(da_ndvi, time_steps, gt, proj, outfolder_ndvi_ltm, unit_scaler=1, deficit=True)
# Out:
# Processing Long-Term-Mean (LTM) for Month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/mean/Mean_LTM_1.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/RL/RL_LTM_1.tif
#
# Processing Long-Term-Mean (LTM) for Month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/mean/Mean_LTM_2.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/RL/RL_LTM_2.tif
#
# Processing Long-Term-Mean (LTM) for Month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/mean/Mean_LTM_3.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/RL/RL_LTM_3.tif
#
# Processing Long-Term-Mean (LTM) for Month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/mean/Mean_LTM_4.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/RL/RL_LTM_4.tif
#
# Processing Long-Term-Mean (LTM) for Month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/mean/Mean_LTM_5.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/RL/RL_LTM_5.tif
#
# Processing Long-Term-Mean (LTM) for Month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/mean/Mean_LTM_6.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/RL/RL_LTM_6.tif
#
# Processing Long-Term-Mean (LTM) for Month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/mean/Mean_LTM_7.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/RL/RL_LTM_7.tif
#
# Processing Long-Term-Mean (LTM) for Month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/mean/Mean_LTM_8.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/RL/RL_LTM_8.tif
#
# Processing Long-Term-Mean (LTM) for Month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/mean/Mean_LTM_9.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/RL/RL_LTM_9.tif
#
# Processing Long-Term-Mean (LTM) for Month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/mean/Mean_LTM_10.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/RL/RL_LTM_10.tif
#
# Processing Long-Term-Mean (LTM) for Month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/mean/Mean_LTM_11.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/RL/RL_LTM_11.tif
#
# Processing Long-Term-Mean (LTM) for Month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/mean/Mean_LTM_12.tif
# 	Processing deficit run length for year 2001
# 	Processing deficit run length for year 2002
# 	Processing deficit run length for year 2003
# 	Processing deficit run length for year 2004
# 	Processing deficit run length for year 2005
# 	Processing deficit run length for year 2006
# 	Processing deficit run length for year 2007
# 	Processing deficit run length for year 2008
# 	Processing deficit run length for year 2009
# 	Processing deficit run length for year 2010
# 	Processing deficit run length for year 2011
# 	Processing deficit run length for year 2012
# 	Processing deficit run length for year 2013
# 	Processing deficit run length for year 2014
# 	Processing deficit run length for year 2015
# 	Processing deficit run length for year 2016
# 	Processing deficit run length for year 2017
# 	Processing deficit run length for year 2018
# 	Processing deficit run length for year 2019
# 	Processing deficit run length for year 2020
# 	Processing deficit run length for year 2021
# 	Processing deficit run length for year 2022
# 	saving result to CDI_data/inputs_downloads/ndvi/LTM/RL/RL_LTM_12.tif

# %% [markdown]
# #### 3.3 NDVI during IP
# once LTM data is produced, we can calculate the actual conditions for the diferent interest periods (IP). To limit processing time, we will only process for the year 2021 as an example

# %%
# select output folder
outfolder_ndvi_ip = Path() / 'CDI_data' / 'inputs_downloads' / 'ndvi' / 'IP'

ip_produced = False
# select years to produce
mask = years > 1999

if ip_produced:
    # get mean IP
    mean_ip_folder = outfolder_ndvi_ip / 'mean'
    mean_ip_list = sorted(list(mean_ip_folder.glob('*.tif')))
    ndvi_ip_ds = gu.rasterlist2dict(mean_ip_list)
    
    # remove any dates outside of interest period
    dates_to_remove = [key for key in ndvi_ip_ds if not (pd.to_datetime(start_date) <= key <= pd.to_datetime(end_date))]
    # Removing the keys
    for date in dates_to_remove:
        del ndvi_ip_ds[date]

    
    # get RL data
    rl_ip_folder = outfolder_ndvi_ip / 'RL'
    mean_rl_list = sorted(list(rl_ip_folder.glob('*.tif')))
    ndvi_rl_ip_ds = gu.rasterlist2dict(mean_rl_list)

    # remove any dates outside of interest period
    dates_to_remove = [key for key in ndvi_rl_ip_ds if not (pd.to_datetime(start_date) <= key <= pd.to_datetime(end_date))]
    # Removing the keys
    for date in dates_to_remove:
        del ndvi_rl_ip_ds[date]


else:
    ndvi_ip_ds, ndvi_rl_ip_ds = cdi.compute_ip(da_ndvi[mask, :, :], time_steps[mask], gt, proj, outfolder_ndvi_ip, deficit=True, unit_scaler=1)
# Out:
# Processing IP periods for year 2001
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2001_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2001_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2001_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2001_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2001_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2001_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2001_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2001_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2001_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2001_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2001_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2001_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2001_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2001_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2001_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2001_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2001_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2001_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2001_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2001_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2001_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2001_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2001_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2001_12.tif
#
# Processing IP periods for year 2002
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2002_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2002_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2002_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2002_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2002_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2002_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2002_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2002_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2002_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2002_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2002_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2002_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2002_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2002_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2002_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2002_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2002_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2002_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2002_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2002_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2002_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2002_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2002_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2002_12.tif
#
# Processing IP periods for year 2003
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2003_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2003_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2003_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2003_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2003_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2003_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2003_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2003_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2003_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2003_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2003_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2003_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2003_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2003_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2003_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2003_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2003_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2003_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2003_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2003_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2003_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2003_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2003_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2003_12.tif
#
# Processing IP periods for year 2004
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2004_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2004_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2004_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2004_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2004_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2004_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2004_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2004_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2004_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2004_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2004_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2004_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2004_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2004_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2004_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2004_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2004_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2004_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2004_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2004_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2004_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2004_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2004_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2004_12.tif
#
# Processing IP periods for year 2005
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2005_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2005_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2005_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2005_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2005_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2005_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2005_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2005_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2005_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2005_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2005_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2005_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2005_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2005_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2005_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2005_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2005_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2005_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2005_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2005_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2005_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2005_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2005_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2005_12.tif
#
# Processing IP periods for year 2006
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2006_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2006_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2006_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2006_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2006_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2006_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2006_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2006_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2006_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2006_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2006_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2006_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2006_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2006_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2006_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2006_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2006_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2006_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2006_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2006_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2006_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2006_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2006_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2006_12.tif
#
# Processing IP periods for year 2007
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2007_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2007_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2007_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2007_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2007_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2007_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2007_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2007_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2007_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2007_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2007_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2007_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2007_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2007_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2007_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2007_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2007_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2007_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2007_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2007_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2007_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2007_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2007_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2007_12.tif
#
# Processing IP periods for year 2008
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2008_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2008_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2008_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2008_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2008_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2008_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2008_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2008_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2008_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2008_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2008_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2008_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2008_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2008_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2008_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2008_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2008_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2008_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2008_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2008_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2008_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2008_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2008_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2008_12.tif
#
# Processing IP periods for year 2009
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2009_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2009_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2009_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2009_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2009_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2009_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2009_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2009_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2009_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2009_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2009_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2009_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2009_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2009_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2009_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2009_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2009_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2009_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2009_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2009_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2009_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2009_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2009_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2009_12.tif
#
# Processing IP periods for year 2010
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2010_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2010_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2010_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2010_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2010_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2010_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2010_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2010_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2010_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2010_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2010_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2010_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2010_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2010_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2010_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2010_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2010_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2010_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2010_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2010_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2010_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2010_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2010_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2010_12.tif
#
# Processing IP periods for year 2011
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2011_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2011_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2011_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2011_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2011_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2011_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2011_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2011_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2011_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2011_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2011_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2011_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2011_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2011_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2011_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2011_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2011_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2011_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2011_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2011_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2011_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2011_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2011_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2011_12.tif
#
# Processing IP periods for year 2012
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2012_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2012_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2012_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2012_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2012_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2012_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2012_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2012_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2012_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2012_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2012_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2012_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2012_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2012_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2012_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2012_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2012_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2012_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2012_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2012_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2012_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2012_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2012_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2012_12.tif
#
# Processing IP periods for year 2013
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2013_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2013_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2013_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2013_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2013_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2013_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2013_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2013_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2013_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2013_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2013_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2013_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2013_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2013_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2013_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2013_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2013_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2013_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2013_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2013_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2013_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2013_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2013_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2013_12.tif
#
# Processing IP periods for year 2014
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2014_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2014_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2014_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2014_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2014_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2014_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2014_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2014_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2014_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2014_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2014_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2014_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2014_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2014_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2014_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2014_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2014_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2014_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2014_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2014_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2014_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2014_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2014_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2014_12.tif
#
# Processing IP periods for year 2015
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2015_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2015_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2015_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2015_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2015_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2015_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2015_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2015_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2015_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2015_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2015_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2015_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2015_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2015_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2015_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2015_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2015_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2015_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2015_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2015_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2015_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2015_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2015_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2015_12.tif
#
# Processing IP periods for year 2016
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2016_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2016_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2016_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2016_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2016_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2016_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2016_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2016_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2016_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2016_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2016_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2016_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2016_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2016_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2016_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2016_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2016_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2016_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2016_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2016_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2016_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2016_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2016_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2016_12.tif
#
# Processing IP periods for year 2017
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2017_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2017_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2017_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2017_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2017_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2017_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2017_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2017_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2017_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2017_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2017_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2017_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2017_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2017_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2017_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2017_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2017_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2017_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2017_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2017_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2017_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2017_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2017_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2017_12.tif
#
# Processing IP periods for year 2018
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2018_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2018_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2018_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2018_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2018_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2018_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2018_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2018_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2018_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2018_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2018_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2018_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2018_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2018_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2018_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2018_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2018_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2018_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2018_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2018_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2018_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2018_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2018_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2018_12.tif
#
# Processing IP periods for year 2019
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2019_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2019_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2019_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2019_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2019_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2019_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2019_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2019_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2019_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2019_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2019_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2019_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2019_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2019_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2019_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2019_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2019_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2019_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2019_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2019_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2019_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2019_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2019_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2019_12.tif
#
# Processing IP periods for year 2020
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2020_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2020_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2020_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2020_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2020_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2020_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2020_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2020_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2020_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2020_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2020_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2020_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2020_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2020_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2020_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2020_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2020_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2020_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2020_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2020_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2020_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2020_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2020_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2020_12.tif
#
# Processing IP periods for year 2021
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2021_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2021_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2021_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2021_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2021_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2021_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2021_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2021_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2021_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2021_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2021_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2021_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2021_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2021_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2021_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2021_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2021_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2021_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2021_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2021_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2021_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2021_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2021_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2021_12.tif
#
# Processing IP periods for year 2022
# 	month 1
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2022_1.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2022_1.tif
#
# 	month 2
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2022_2.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2022_2.tif
#
# 	month 3
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2022_3.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2022_3.tif
#
# 	month 4
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2022_4.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2022_4.tif
#
# 	month 5
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2022_5.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2022_5.tif
#
# 	month 6
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2022_6.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2022_6.tif
#
# 	month 7
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2022_7.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2022_7.tif
#
# 	month 8
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2022_8.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2022_8.tif
#
# 	month 9
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2022_9.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2022_9.tif
#
# 	month 10
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2022_10.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2022_10.tif
#
# 	month 11
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2022_11.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2022_11.tif
#
# 	month 12
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/mean/Mean_IP_2022_12.tif
# 	saving result to CDI_data/inputs_downloads/ndvi/IP/RL/RL_IP_2022_12.tif

# %% [markdown]
# #### 3.4 Calculate VDI

# %%
# get minimum NDVI for the entire study period
ndvi_ar = da_ndvi.values
ndvi_min_ar = np.nanmin(ndvi_ar)
ndvi_min = 0.15
# select output folder
outfolder = Path() / 'CDI_data' / 'drought_indices'

# calculate VDI
vdi = cdi.calc_vdi(ndvi_ip_ds, ndvi_rl_ip_ds, ndvi_ltm_ds, ndvi_rl_ltm_ds, ndvi_min, gt, proj, outfolder)
# Out:
# 2001
# 	Month: 1
# 	saving VDI result for 2001-1 to CDI_data/drought_indices/VDI/VDI_IP_2001_1.tif
#
# 	Month: 2
# 	saving VDI result for 2001-2 to CDI_data/drought_indices/VDI/VDI_IP_2001_2.tif
#
# 	Month: 3
# 	saving VDI result for 2001-3 to CDI_data/drought_indices/VDI/VDI_IP_2001_3.tif
#
# 	Month: 4
# 	saving VDI result for 2001-4 to CDI_data/drought_indices/VDI/VDI_IP_2001_4.tif
#
# 	Month: 5
# 	saving VDI result for 2001-5 to CDI_data/drought_indices/VDI/VDI_IP_2001_5.tif
#
# 	Month: 6
# 	saving VDI result for 2001-6 to CDI_data/drought_indices/VDI/VDI_IP_2001_6.tif
#
# 	Month: 7
# 	saving VDI result for 2001-7 to CDI_data/drought_indices/VDI/VDI_IP_2001_7.tif
#
# 	Month: 8
# 	saving VDI result for 2001-8 to CDI_data/drought_indices/VDI/VDI_IP_2001_8.tif
#
# 	Month: 9
# 	saving VDI result for 2001-9 to CDI_data/drought_indices/VDI/VDI_IP_2001_9.tif
#
# 	Month: 10
# 	saving VDI result for 2001-10 to CDI_data/drought_indices/VDI/VDI_IP_2001_10.tif
#
# 	Month: 11
# 	saving VDI result for 2001-11 to CDI_data/drought_indices/VDI/VDI_IP_2001_11.tif
#
# 	Month: 12
# 	saving VDI result for 2001-12 to CDI_data/drought_indices/VDI/VDI_IP_2001_12.tif
#
# 2002
# 	Month: 1
# 	saving VDI result for 2002-1 to CDI_data/drought_indices/VDI/VDI_IP_2002_1.tif
#
# 	Month: 2
# 	saving VDI result for 2002-2 to CDI_data/drought_indices/VDI/VDI_IP_2002_2.tif
#
# 	Month: 3
# 	saving VDI result for 2002-3 to CDI_data/drought_indices/VDI/VDI_IP_2002_3.tif
#
# 	Month: 4
# 	saving VDI result for 2002-4 to CDI_data/drought_indices/VDI/VDI_IP_2002_4.tif
#
# 	Month: 5
# 	saving VDI result for 2002-5 to CDI_data/drought_indices/VDI/VDI_IP_2002_5.tif
#
# 	Month: 6
# 	saving VDI result for 2002-6 to CDI_data/drought_indices/VDI/VDI_IP_2002_6.tif
#
# 	Month: 7
# 	saving VDI result for 2002-7 to CDI_data/drought_indices/VDI/VDI_IP_2002_7.tif
#
# 	Month: 8
# 	saving VDI result for 2002-8 to CDI_data/drought_indices/VDI/VDI_IP_2002_8.tif
#
# 	Month: 9
# 	saving VDI result for 2002-9 to CDI_data/drought_indices/VDI/VDI_IP_2002_9.tif
#
# 	Month: 10
# 	saving VDI result for 2002-10 to CDI_data/drought_indices/VDI/VDI_IP_2002_10.tif
#
# 	Month: 11
# 	saving VDI result for 2002-11 to CDI_data/drought_indices/VDI/VDI_IP_2002_11.tif
#
# 	Month: 12
# 	saving VDI result for 2002-12 to CDI_data/drought_indices/VDI/VDI_IP_2002_12.tif
#
# 2003
# 	Month: 1
# 	saving VDI result for 2003-1 to CDI_data/drought_indices/VDI/VDI_IP_2003_1.tif
#
# 	Month: 2
# 	saving VDI result for 2003-2 to CDI_data/drought_indices/VDI/VDI_IP_2003_2.tif
#
# 	Month: 3
# 	saving VDI result for 2003-3 to CDI_data/drought_indices/VDI/VDI_IP_2003_3.tif
#
# 	Month: 4
# 	saving VDI result for 2003-4 to CDI_data/drought_indices/VDI/VDI_IP_2003_4.tif
#
# 	Month: 5
# 	saving VDI result for 2003-5 to CDI_data/drought_indices/VDI/VDI_IP_2003_5.tif
#
# 	Month: 6
# 	saving VDI result for 2003-6 to CDI_data/drought_indices/VDI/VDI_IP_2003_6.tif
#
# 	Month: 7
# 	saving VDI result for 2003-7 to CDI_data/drought_indices/VDI/VDI_IP_2003_7.tif
#
# 	Month: 8
# 	saving VDI result for 2003-8 to CDI_data/drought_indices/VDI/VDI_IP_2003_8.tif
#
# 	Month: 9
# 	saving VDI result for 2003-9 to CDI_data/drought_indices/VDI/VDI_IP_2003_9.tif
#
# 	Month: 10
# 	saving VDI result for 2003-10 to CDI_data/drought_indices/VDI/VDI_IP_2003_10.tif
#
# 	Month: 11
# 	saving VDI result for 2003-11 to CDI_data/drought_indices/VDI/VDI_IP_2003_11.tif
#
# 	Month: 12
# 	saving VDI result for 2003-12 to CDI_data/drought_indices/VDI/VDI_IP_2003_12.tif
#
# 2004
# 	Month: 1
# 	saving VDI result for 2004-1 to CDI_data/drought_indices/VDI/VDI_IP_2004_1.tif
#
# 	Month: 2
# 	saving VDI result for 2004-2 to CDI_data/drought_indices/VDI/VDI_IP_2004_2.tif
#
# 	Month: 3
# 	saving VDI result for 2004-3 to CDI_data/drought_indices/VDI/VDI_IP_2004_3.tif
#
# 	Month: 4
# 	saving VDI result for 2004-4 to CDI_data/drought_indices/VDI/VDI_IP_2004_4.tif
#
# 	Month: 5
# 	saving VDI result for 2004-5 to CDI_data/drought_indices/VDI/VDI_IP_2004_5.tif
#
# 	Month: 6
# 	saving VDI result for 2004-6 to CDI_data/drought_indices/VDI/VDI_IP_2004_6.tif
#
# 	Month: 7
# 	saving VDI result for 2004-7 to CDI_data/drought_indices/VDI/VDI_IP_2004_7.tif
#
# 	Month: 8
# 	saving VDI result for 2004-8 to CDI_data/drought_indices/VDI/VDI_IP_2004_8.tif
#
# 	Month: 9
# 	saving VDI result for 2004-9 to CDI_data/drought_indices/VDI/VDI_IP_2004_9.tif
#
# 	Month: 10
# 	saving VDI result for 2004-10 to CDI_data/drought_indices/VDI/VDI_IP_2004_10.tif
#
# 	Month: 11
# 	saving VDI result for 2004-11 to CDI_data/drought_indices/VDI/VDI_IP_2004_11.tif
#
# 	Month: 12
# 	saving VDI result for 2004-12 to CDI_data/drought_indices/VDI/VDI_IP_2004_12.tif
#
# 2005
# 	Month: 1
# 	saving VDI result for 2005-1 to CDI_data/drought_indices/VDI/VDI_IP_2005_1.tif
#
# 	Month: 2
# 	saving VDI result for 2005-2 to CDI_data/drought_indices/VDI/VDI_IP_2005_2.tif
#
# 	Month: 3
# 	saving VDI result for 2005-3 to CDI_data/drought_indices/VDI/VDI_IP_2005_3.tif
#
# 	Month: 4
# 	saving VDI result for 2005-4 to CDI_data/drought_indices/VDI/VDI_IP_2005_4.tif
#
# 	Month: 5
# 	saving VDI result for 2005-5 to CDI_data/drought_indices/VDI/VDI_IP_2005_5.tif
#
# 	Month: 6
# 	saving VDI result for 2005-6 to CDI_data/drought_indices/VDI/VDI_IP_2005_6.tif
#
# 	Month: 7
# 	saving VDI result for 2005-7 to CDI_data/drought_indices/VDI/VDI_IP_2005_7.tif
#
# 	Month: 8
# 	saving VDI result for 2005-8 to CDI_data/drought_indices/VDI/VDI_IP_2005_8.tif
#
# 	Month: 9
# 	saving VDI result for 2005-9 to CDI_data/drought_indices/VDI/VDI_IP_2005_9.tif
#
# 	Month: 10
# 	saving VDI result for 2005-10 to CDI_data/drought_indices/VDI/VDI_IP_2005_10.tif
#
# 	Month: 11
# 	saving VDI result for 2005-11 to CDI_data/drought_indices/VDI/VDI_IP_2005_11.tif
#
# 	Month: 12
# 	saving VDI result for 2005-12 to CDI_data/drought_indices/VDI/VDI_IP_2005_12.tif
#
# 2006
# 	Month: 1
# 	saving VDI result for 2006-1 to CDI_data/drought_indices/VDI/VDI_IP_2006_1.tif
#
# 	Month: 2
# 	saving VDI result for 2006-2 to CDI_data/drought_indices/VDI/VDI_IP_2006_2.tif
#
# 	Month: 3
# 	saving VDI result for 2006-3 to CDI_data/drought_indices/VDI/VDI_IP_2006_3.tif
#
# 	Month: 4
# 	saving VDI result for 2006-4 to CDI_data/drought_indices/VDI/VDI_IP_2006_4.tif
#
# 	Month: 5
# 	saving VDI result for 2006-5 to CDI_data/drought_indices/VDI/VDI_IP_2006_5.tif
#
# 	Month: 6
# 	saving VDI result for 2006-6 to CDI_data/drought_indices/VDI/VDI_IP_2006_6.tif
#
# 	Month: 7
# 	saving VDI result for 2006-7 to CDI_data/drought_indices/VDI/VDI_IP_2006_7.tif
#
# 	Month: 8
# 	saving VDI result for 2006-8 to CDI_data/drought_indices/VDI/VDI_IP_2006_8.tif
#
# 	Month: 9
# 	saving VDI result for 2006-9 to CDI_data/drought_indices/VDI/VDI_IP_2006_9.tif
#
# 	Month: 10
# 	saving VDI result for 2006-10 to CDI_data/drought_indices/VDI/VDI_IP_2006_10.tif
#
# 	Month: 11
# 	saving VDI result for 2006-11 to CDI_data/drought_indices/VDI/VDI_IP_2006_11.tif
#
# 	Month: 12
# 	saving VDI result for 2006-12 to CDI_data/drought_indices/VDI/VDI_IP_2006_12.tif
#
# 2007
# 	Month: 1
# 	saving VDI result for 2007-1 to CDI_data/drought_indices/VDI/VDI_IP_2007_1.tif
#
# 	Month: 2
# 	saving VDI result for 2007-2 to CDI_data/drought_indices/VDI/VDI_IP_2007_2.tif
#
# 	Month: 3
# 	saving VDI result for 2007-3 to CDI_data/drought_indices/VDI/VDI_IP_2007_3.tif
#
# 	Month: 4
# 	saving VDI result for 2007-4 to CDI_data/drought_indices/VDI/VDI_IP_2007_4.tif
#
# 	Month: 5
# 	saving VDI result for 2007-5 to CDI_data/drought_indices/VDI/VDI_IP_2007_5.tif
#
# 	Month: 6
# 	saving VDI result for 2007-6 to CDI_data/drought_indices/VDI/VDI_IP_2007_6.tif
#
# 	Month: 7
# 	saving VDI result for 2007-7 to CDI_data/drought_indices/VDI/VDI_IP_2007_7.tif
#
# 	Month: 8
# 	saving VDI result for 2007-8 to CDI_data/drought_indices/VDI/VDI_IP_2007_8.tif
#
# 	Month: 9
# 	saving VDI result for 2007-9 to CDI_data/drought_indices/VDI/VDI_IP_2007_9.tif
#
# 	Month: 10
# 	saving VDI result for 2007-10 to CDI_data/drought_indices/VDI/VDI_IP_2007_10.tif
#
# 	Month: 11
# 	saving VDI result for 2007-11 to CDI_data/drought_indices/VDI/VDI_IP_2007_11.tif
#
# 	Month: 12
# 	saving VDI result for 2007-12 to CDI_data/drought_indices/VDI/VDI_IP_2007_12.tif
#
# 2008
# 	Month: 1
# 	saving VDI result for 2008-1 to CDI_data/drought_indices/VDI/VDI_IP_2008_1.tif
#
# 	Month: 2
# 	saving VDI result for 2008-2 to CDI_data/drought_indices/VDI/VDI_IP_2008_2.tif
#
# 	Month: 3
# 	saving VDI result for 2008-3 to CDI_data/drought_indices/VDI/VDI_IP_2008_3.tif
#
# 	Month: 4
# 	saving VDI result for 2008-4 to CDI_data/drought_indices/VDI/VDI_IP_2008_4.tif
#
# 	Month: 5
# 	saving VDI result for 2008-5 to CDI_data/drought_indices/VDI/VDI_IP_2008_5.tif
#
# 	Month: 6
# 	saving VDI result for 2008-6 to CDI_data/drought_indices/VDI/VDI_IP_2008_6.tif
#
# 	Month: 7
# 	saving VDI result for 2008-7 to CDI_data/drought_indices/VDI/VDI_IP_2008_7.tif
#
# 	Month: 8
# 	saving VDI result for 2008-8 to CDI_data/drought_indices/VDI/VDI_IP_2008_8.tif
#
# 	Month: 9
# 	saving VDI result for 2008-9 to CDI_data/drought_indices/VDI/VDI_IP_2008_9.tif
#
# 	Month: 10
# 	saving VDI result for 2008-10 to CDI_data/drought_indices/VDI/VDI_IP_2008_10.tif
#
# 	Month: 11
# 	saving VDI result for 2008-11 to CDI_data/drought_indices/VDI/VDI_IP_2008_11.tif
#
# 	Month: 12
# 	saving VDI result for 2008-12 to CDI_data/drought_indices/VDI/VDI_IP_2008_12.tif
#
# 2009
# 	Month: 1
# 	saving VDI result for 2009-1 to CDI_data/drought_indices/VDI/VDI_IP_2009_1.tif
#
# 	Month: 2
# 	saving VDI result for 2009-2 to CDI_data/drought_indices/VDI/VDI_IP_2009_2.tif
#
# 	Month: 3
# 	saving VDI result for 2009-3 to CDI_data/drought_indices/VDI/VDI_IP_2009_3.tif
#
# 	Month: 4
# 	saving VDI result for 2009-4 to CDI_data/drought_indices/VDI/VDI_IP_2009_4.tif
#
# 	Month: 5
# 	saving VDI result for 2009-5 to CDI_data/drought_indices/VDI/VDI_IP_2009_5.tif
#
# 	Month: 6
# 	saving VDI result for 2009-6 to CDI_data/drought_indices/VDI/VDI_IP_2009_6.tif
#
# 	Month: 7
# 	saving VDI result for 2009-7 to CDI_data/drought_indices/VDI/VDI_IP_2009_7.tif
#
# 	Month: 8
# 	saving VDI result for 2009-8 to CDI_data/drought_indices/VDI/VDI_IP_2009_8.tif
#
# 	Month: 9
# 	saving VDI result for 2009-9 to CDI_data/drought_indices/VDI/VDI_IP_2009_9.tif
#
# 	Month: 10
# 	saving VDI result for 2009-10 to CDI_data/drought_indices/VDI/VDI_IP_2009_10.tif
#
# 	Month: 11
# 	saving VDI result for 2009-11 to CDI_data/drought_indices/VDI/VDI_IP_2009_11.tif
#
# 	Month: 12
# 	saving VDI result for 2009-12 to CDI_data/drought_indices/VDI/VDI_IP_2009_12.tif
#
# 2010
# 	Month: 1
# 	saving VDI result for 2010-1 to CDI_data/drought_indices/VDI/VDI_IP_2010_1.tif
#
# 	Month: 2
# 	saving VDI result for 2010-2 to CDI_data/drought_indices/VDI/VDI_IP_2010_2.tif
#
# 	Month: 3
# 	saving VDI result for 2010-3 to CDI_data/drought_indices/VDI/VDI_IP_2010_3.tif
#
# 	Month: 4
# 	saving VDI result for 2010-4 to CDI_data/drought_indices/VDI/VDI_IP_2010_4.tif
#
# 	Month: 5
# 	saving VDI result for 2010-5 to CDI_data/drought_indices/VDI/VDI_IP_2010_5.tif
#
# 	Month: 6
# 	saving VDI result for 2010-6 to CDI_data/drought_indices/VDI/VDI_IP_2010_6.tif
#
# 	Month: 7
# 	saving VDI result for 2010-7 to CDI_data/drought_indices/VDI/VDI_IP_2010_7.tif
#
# 	Month: 8
# 	saving VDI result for 2010-8 to CDI_data/drought_indices/VDI/VDI_IP_2010_8.tif
#
# 	Month: 9
# 	saving VDI result for 2010-9 to CDI_data/drought_indices/VDI/VDI_IP_2010_9.tif
#
# 	Month: 10
# 	saving VDI result for 2010-10 to CDI_data/drought_indices/VDI/VDI_IP_2010_10.tif
#
# 	Month: 11
# 	saving VDI result for 2010-11 to CDI_data/drought_indices/VDI/VDI_IP_2010_11.tif
#
# 	Month: 12
# 	saving VDI result for 2010-12 to CDI_data/drought_indices/VDI/VDI_IP_2010_12.tif
#
# 2011
# 	Month: 1
# 	saving VDI result for 2011-1 to CDI_data/drought_indices/VDI/VDI_IP_2011_1.tif
#
# 	Month: 2
# 	saving VDI result for 2011-2 to CDI_data/drought_indices/VDI/VDI_IP_2011_2.tif
#
# 	Month: 3
# 	saving VDI result for 2011-3 to CDI_data/drought_indices/VDI/VDI_IP_2011_3.tif
#
# 	Month: 4
# 	saving VDI result for 2011-4 to CDI_data/drought_indices/VDI/VDI_IP_2011_4.tif
#
# 	Month: 5
# 	saving VDI result for 2011-5 to CDI_data/drought_indices/VDI/VDI_IP_2011_5.tif
#
# 	Month: 6
# 	saving VDI result for 2011-6 to CDI_data/drought_indices/VDI/VDI_IP_2011_6.tif
#
# 	Month: 7
# 	saving VDI result for 2011-7 to CDI_data/drought_indices/VDI/VDI_IP_2011_7.tif
#
# 	Month: 8
# 	saving VDI result for 2011-8 to CDI_data/drought_indices/VDI/VDI_IP_2011_8.tif
#
# 	Month: 9
# 	saving VDI result for 2011-9 to CDI_data/drought_indices/VDI/VDI_IP_2011_9.tif
#
# 	Month: 10
# 	saving VDI result for 2011-10 to CDI_data/drought_indices/VDI/VDI_IP_2011_10.tif
#
# 	Month: 11
# 	saving VDI result for 2011-11 to CDI_data/drought_indices/VDI/VDI_IP_2011_11.tif
#
# 	Month: 12
# 	saving VDI result for 2011-12 to CDI_data/drought_indices/VDI/VDI_IP_2011_12.tif
#
# 2012
# 	Month: 1
# 	saving VDI result for 2012-1 to CDI_data/drought_indices/VDI/VDI_IP_2012_1.tif
#
# 	Month: 2
# 	saving VDI result for 2012-2 to CDI_data/drought_indices/VDI/VDI_IP_2012_2.tif
#
# 	Month: 3
# 	saving VDI result for 2012-3 to CDI_data/drought_indices/VDI/VDI_IP_2012_3.tif
#
# 	Month: 4
# 	saving VDI result for 2012-4 to CDI_data/drought_indices/VDI/VDI_IP_2012_4.tif
#
# 	Month: 5
# 	saving VDI result for 2012-5 to CDI_data/drought_indices/VDI/VDI_IP_2012_5.tif
#
# 	Month: 6
# 	saving VDI result for 2012-6 to CDI_data/drought_indices/VDI/VDI_IP_2012_6.tif
#
# 	Month: 7
# 	saving VDI result for 2012-7 to CDI_data/drought_indices/VDI/VDI_IP_2012_7.tif
#
# 	Month: 8
# 	saving VDI result for 2012-8 to CDI_data/drought_indices/VDI/VDI_IP_2012_8.tif
#
# 	Month: 9
# 	saving VDI result for 2012-9 to CDI_data/drought_indices/VDI/VDI_IP_2012_9.tif
#
# 	Month: 10
# 	saving VDI result for 2012-10 to CDI_data/drought_indices/VDI/VDI_IP_2012_10.tif
#
# 	Month: 11
# 	saving VDI result for 2012-11 to CDI_data/drought_indices/VDI/VDI_IP_2012_11.tif
#
# 	Month: 12
# 	saving VDI result for 2012-12 to CDI_data/drought_indices/VDI/VDI_IP_2012_12.tif
#
# 2013
# 	Month: 1
# 	saving VDI result for 2013-1 to CDI_data/drought_indices/VDI/VDI_IP_2013_1.tif
#
# 	Month: 2
# 	saving VDI result for 2013-2 to CDI_data/drought_indices/VDI/VDI_IP_2013_2.tif
#
# 	Month: 3
# 	saving VDI result for 2013-3 to CDI_data/drought_indices/VDI/VDI_IP_2013_3.tif
#
# 	Month: 4
# 	saving VDI result for 2013-4 to CDI_data/drought_indices/VDI/VDI_IP_2013_4.tif
#
# 	Month: 5
# 	saving VDI result for 2013-5 to CDI_data/drought_indices/VDI/VDI_IP_2013_5.tif
#
# 	Month: 6
# 	saving VDI result for 2013-6 to CDI_data/drought_indices/VDI/VDI_IP_2013_6.tif
#
# 	Month: 7
# 	saving VDI result for 2013-7 to CDI_data/drought_indices/VDI/VDI_IP_2013_7.tif
#
# 	Month: 8
# 	saving VDI result for 2013-8 to CDI_data/drought_indices/VDI/VDI_IP_2013_8.tif
#
# 	Month: 9
# 	saving VDI result for 2013-9 to CDI_data/drought_indices/VDI/VDI_IP_2013_9.tif
#
# 	Month: 10
# 	saving VDI result for 2013-10 to CDI_data/drought_indices/VDI/VDI_IP_2013_10.tif
#
# 	Month: 11
# 	saving VDI result for 2013-11 to CDI_data/drought_indices/VDI/VDI_IP_2013_11.tif
#
# 	Month: 12
# 	saving VDI result for 2013-12 to CDI_data/drought_indices/VDI/VDI_IP_2013_12.tif
#
# 2014
# 	Month: 1
# 	saving VDI result for 2014-1 to CDI_data/drought_indices/VDI/VDI_IP_2014_1.tif
#
# 	Month: 2
# 	saving VDI result for 2014-2 to CDI_data/drought_indices/VDI/VDI_IP_2014_2.tif
#
# 	Month: 3
# 	saving VDI result for 2014-3 to CDI_data/drought_indices/VDI/VDI_IP_2014_3.tif
#
# 	Month: 4
# 	saving VDI result for 2014-4 to CDI_data/drought_indices/VDI/VDI_IP_2014_4.tif
#
# 	Month: 5
# 	saving VDI result for 2014-5 to CDI_data/drought_indices/VDI/VDI_IP_2014_5.tif
#
# 	Month: 6
# 	saving VDI result for 2014-6 to CDI_data/drought_indices/VDI/VDI_IP_2014_6.tif
#
# 	Month: 7
# 	saving VDI result for 2014-7 to CDI_data/drought_indices/VDI/VDI_IP_2014_7.tif
#
# 	Month: 8
# 	saving VDI result for 2014-8 to CDI_data/drought_indices/VDI/VDI_IP_2014_8.tif
#
# 	Month: 9
# 	saving VDI result for 2014-9 to CDI_data/drought_indices/VDI/VDI_IP_2014_9.tif
#
# 	Month: 10
# 	saving VDI result for 2014-10 to CDI_data/drought_indices/VDI/VDI_IP_2014_10.tif
#
# 	Month: 11
# 	saving VDI result for 2014-11 to CDI_data/drought_indices/VDI/VDI_IP_2014_11.tif
#
# 	Month: 12
# 	saving VDI result for 2014-12 to CDI_data/drought_indices/VDI/VDI_IP_2014_12.tif
#
# 2015
# 	Month: 1
# 	saving VDI result for 2015-1 to CDI_data/drought_indices/VDI/VDI_IP_2015_1.tif
#
# 	Month: 2
# 	saving VDI result for 2015-2 to CDI_data/drought_indices/VDI/VDI_IP_2015_2.tif
#
# 	Month: 3
# 	saving VDI result for 2015-3 to CDI_data/drought_indices/VDI/VDI_IP_2015_3.tif
#
# 	Month: 4
# 	saving VDI result for 2015-4 to CDI_data/drought_indices/VDI/VDI_IP_2015_4.tif
#
# 	Month: 5
# 	saving VDI result for 2015-5 to CDI_data/drought_indices/VDI/VDI_IP_2015_5.tif
#
# 	Month: 6
# 	saving VDI result for 2015-6 to CDI_data/drought_indices/VDI/VDI_IP_2015_6.tif
#
# 	Month: 7
# 	saving VDI result for 2015-7 to CDI_data/drought_indices/VDI/VDI_IP_2015_7.tif
#
# 	Month: 8
# 	saving VDI result for 2015-8 to CDI_data/drought_indices/VDI/VDI_IP_2015_8.tif
#
# 	Month: 9
# 	saving VDI result for 2015-9 to CDI_data/drought_indices/VDI/VDI_IP_2015_9.tif
#
# 	Month: 10
# 	saving VDI result for 2015-10 to CDI_data/drought_indices/VDI/VDI_IP_2015_10.tif
#
# 	Month: 11
# 	saving VDI result for 2015-11 to CDI_data/drought_indices/VDI/VDI_IP_2015_11.tif
#
# 	Month: 12
# 	saving VDI result for 2015-12 to CDI_data/drought_indices/VDI/VDI_IP_2015_12.tif
#
# 2016
# 	Month: 1
# 	saving VDI result for 2016-1 to CDI_data/drought_indices/VDI/VDI_IP_2016_1.tif
#
# 	Month: 2
# 	saving VDI result for 2016-2 to CDI_data/drought_indices/VDI/VDI_IP_2016_2.tif
#
# 	Month: 3
# 	saving VDI result for 2016-3 to CDI_data/drought_indices/VDI/VDI_IP_2016_3.tif
#
# 	Month: 4
# 	saving VDI result for 2016-4 to CDI_data/drought_indices/VDI/VDI_IP_2016_4.tif
#
# 	Month: 5
# 	saving VDI result for 2016-5 to CDI_data/drought_indices/VDI/VDI_IP_2016_5.tif
#
# 	Month: 6
# 	saving VDI result for 2016-6 to CDI_data/drought_indices/VDI/VDI_IP_2016_6.tif
#
# 	Month: 7
# 	saving VDI result for 2016-7 to CDI_data/drought_indices/VDI/VDI_IP_2016_7.tif
#
# 	Month: 8
# 	saving VDI result for 2016-8 to CDI_data/drought_indices/VDI/VDI_IP_2016_8.tif
#
# 	Month: 9
# 	saving VDI result for 2016-9 to CDI_data/drought_indices/VDI/VDI_IP_2016_9.tif
#
# 	Month: 10
# 	saving VDI result for 2016-10 to CDI_data/drought_indices/VDI/VDI_IP_2016_10.tif
#
# 	Month: 11
# 	saving VDI result for 2016-11 to CDI_data/drought_indices/VDI/VDI_IP_2016_11.tif
#
# 	Month: 12
# 	saving VDI result for 2016-12 to CDI_data/drought_indices/VDI/VDI_IP_2016_12.tif
#
# 2017
# 	Month: 1
# 	saving VDI result for 2017-1 to CDI_data/drought_indices/VDI/VDI_IP_2017_1.tif
#
# 	Month: 2
# 	saving VDI result for 2017-2 to CDI_data/drought_indices/VDI/VDI_IP_2017_2.tif
#
# 	Month: 3
# 	saving VDI result for 2017-3 to CDI_data/drought_indices/VDI/VDI_IP_2017_3.tif
#
# 	Month: 4
# 	saving VDI result for 2017-4 to CDI_data/drought_indices/VDI/VDI_IP_2017_4.tif
#
# 	Month: 5
# 	saving VDI result for 2017-5 to CDI_data/drought_indices/VDI/VDI_IP_2017_5.tif
#
# 	Month: 6
# 	saving VDI result for 2017-6 to CDI_data/drought_indices/VDI/VDI_IP_2017_6.tif
#
# 	Month: 7
# 	saving VDI result for 2017-7 to CDI_data/drought_indices/VDI/VDI_IP_2017_7.tif
#
# 	Month: 8
# 	saving VDI result for 2017-8 to CDI_data/drought_indices/VDI/VDI_IP_2017_8.tif
#
# 	Month: 9
# 	saving VDI result for 2017-9 to CDI_data/drought_indices/VDI/VDI_IP_2017_9.tif
#
# 	Month: 10
# 	saving VDI result for 2017-10 to CDI_data/drought_indices/VDI/VDI_IP_2017_10.tif
#
# 	Month: 11
# 	saving VDI result for 2017-11 to CDI_data/drought_indices/VDI/VDI_IP_2017_11.tif
#
# 	Month: 12
# 	saving VDI result for 2017-12 to CDI_data/drought_indices/VDI/VDI_IP_2017_12.tif
#
# 2018
# 	Month: 1
# 	saving VDI result for 2018-1 to CDI_data/drought_indices/VDI/VDI_IP_2018_1.tif
#
# 	Month: 2
# 	saving VDI result for 2018-2 to CDI_data/drought_indices/VDI/VDI_IP_2018_2.tif
#
# 	Month: 3
# 	saving VDI result for 2018-3 to CDI_data/drought_indices/VDI/VDI_IP_2018_3.tif
#
# 	Month: 4
# 	saving VDI result for 2018-4 to CDI_data/drought_indices/VDI/VDI_IP_2018_4.tif
#
# 	Month: 5
# 	saving VDI result for 2018-5 to CDI_data/drought_indices/VDI/VDI_IP_2018_5.tif
#
# 	Month: 6
# 	saving VDI result for 2018-6 to CDI_data/drought_indices/VDI/VDI_IP_2018_6.tif
#
# 	Month: 7
# 	saving VDI result for 2018-7 to CDI_data/drought_indices/VDI/VDI_IP_2018_7.tif
#
# 	Month: 8
# 	saving VDI result for 2018-8 to CDI_data/drought_indices/VDI/VDI_IP_2018_8.tif
#
# 	Month: 9
# 	saving VDI result for 2018-9 to CDI_data/drought_indices/VDI/VDI_IP_2018_9.tif
#
# 	Month: 10
# 	saving VDI result for 2018-10 to CDI_data/drought_indices/VDI/VDI_IP_2018_10.tif
#
# 	Month: 11
# 	saving VDI result for 2018-11 to CDI_data/drought_indices/VDI/VDI_IP_2018_11.tif
#
# 	Month: 12
# 	saving VDI result for 2018-12 to CDI_data/drought_indices/VDI/VDI_IP_2018_12.tif
#
# 2019
# 	Month: 1
# 	saving VDI result for 2019-1 to CDI_data/drought_indices/VDI/VDI_IP_2019_1.tif
#
# 	Month: 2
# 	saving VDI result for 2019-2 to CDI_data/drought_indices/VDI/VDI_IP_2019_2.tif
#
# 	Month: 3
# 	saving VDI result for 2019-3 to CDI_data/drought_indices/VDI/VDI_IP_2019_3.tif
#
# 	Month: 4
# 	saving VDI result for 2019-4 to CDI_data/drought_indices/VDI/VDI_IP_2019_4.tif
#
# 	Month: 5
# 	saving VDI result for 2019-5 to CDI_data/drought_indices/VDI/VDI_IP_2019_5.tif
#
# 	Month: 6
# 	saving VDI result for 2019-6 to CDI_data/drought_indices/VDI/VDI_IP_2019_6.tif
#
# 	Month: 7
# 	saving VDI result for 2019-7 to CDI_data/drought_indices/VDI/VDI_IP_2019_7.tif
#
# 	Month: 8
# 	saving VDI result for 2019-8 to CDI_data/drought_indices/VDI/VDI_IP_2019_8.tif
#
# 	Month: 9
# 	saving VDI result for 2019-9 to CDI_data/drought_indices/VDI/VDI_IP_2019_9.tif
#
# 	Month: 10
# 	saving VDI result for 2019-10 to CDI_data/drought_indices/VDI/VDI_IP_2019_10.tif
#
# 	Month: 11
# 	saving VDI result for 2019-11 to CDI_data/drought_indices/VDI/VDI_IP_2019_11.tif
#
# 	Month: 12
# 	saving VDI result for 2019-12 to CDI_data/drought_indices/VDI/VDI_IP_2019_12.tif
#
# 2020
# 	Month: 1
# 	saving VDI result for 2020-1 to CDI_data/drought_indices/VDI/VDI_IP_2020_1.tif
#
# 	Month: 2
# 	saving VDI result for 2020-2 to CDI_data/drought_indices/VDI/VDI_IP_2020_2.tif
#
# 	Month: 3
# 	saving VDI result for 2020-3 to CDI_data/drought_indices/VDI/VDI_IP_2020_3.tif
#
# 	Month: 4
# 	saving VDI result for 2020-4 to CDI_data/drought_indices/VDI/VDI_IP_2020_4.tif
#
# 	Month: 5
# 	saving VDI result for 2020-5 to CDI_data/drought_indices/VDI/VDI_IP_2020_5.tif
#
# 	Month: 6
# 	saving VDI result for 2020-6 to CDI_data/drought_indices/VDI/VDI_IP_2020_6.tif
#
# 	Month: 7
# 	saving VDI result for 2020-7 to CDI_data/drought_indices/VDI/VDI_IP_2020_7.tif
#
# 	Month: 8
# 	saving VDI result for 2020-8 to CDI_data/drought_indices/VDI/VDI_IP_2020_8.tif
#
# 	Month: 9
# 	saving VDI result for 2020-9 to CDI_data/drought_indices/VDI/VDI_IP_2020_9.tif
#
# 	Month: 10
# 	saving VDI result for 2020-10 to CDI_data/drought_indices/VDI/VDI_IP_2020_10.tif
#
# 	Month: 11
# 	saving VDI result for 2020-11 to CDI_data/drought_indices/VDI/VDI_IP_2020_11.tif
#
# 	Month: 12
# 	saving VDI result for 2020-12 to CDI_data/drought_indices/VDI/VDI_IP_2020_12.tif
#
# 2021
# 	Month: 1
# 	saving VDI result for 2021-1 to CDI_data/drought_indices/VDI/VDI_IP_2021_1.tif
#
# 	Month: 2
# 	saving VDI result for 2021-2 to CDI_data/drought_indices/VDI/VDI_IP_2021_2.tif
#
# 	Month: 3
# 	saving VDI result for 2021-3 to CDI_data/drought_indices/VDI/VDI_IP_2021_3.tif
#
# 	Month: 4
# 	saving VDI result for 2021-4 to CDI_data/drought_indices/VDI/VDI_IP_2021_4.tif
#
# 	Month: 5
# 	saving VDI result for 2021-5 to CDI_data/drought_indices/VDI/VDI_IP_2021_5.tif
#
# 	Month: 6
# 	saving VDI result for 2021-6 to CDI_data/drought_indices/VDI/VDI_IP_2021_6.tif
#
# 	Month: 7
# 	saving VDI result for 2021-7 to CDI_data/drought_indices/VDI/VDI_IP_2021_7.tif
#
# 	Month: 8
# 	saving VDI result for 2021-8 to CDI_data/drought_indices/VDI/VDI_IP_2021_8.tif
#
# 	Month: 9
# 	saving VDI result for 2021-9 to CDI_data/drought_indices/VDI/VDI_IP_2021_9.tif
#
# 	Month: 10
# 	saving VDI result for 2021-10 to CDI_data/drought_indices/VDI/VDI_IP_2021_10.tif
#
# 	Month: 11
# 	saving VDI result for 2021-11 to CDI_data/drought_indices/VDI/VDI_IP_2021_11.tif
#
# 	Month: 12
# 	saving VDI result for 2021-12 to CDI_data/drought_indices/VDI/VDI_IP_2021_12.tif
#
# 2022
# 	Month: 1
# 	saving VDI result for 2022-1 to CDI_data/drought_indices/VDI/VDI_IP_2022_1.tif
#
# 	Month: 2
# 	saving VDI result for 2022-2 to CDI_data/drought_indices/VDI/VDI_IP_2022_2.tif
#
# 	Month: 3
# 	saving VDI result for 2022-3 to CDI_data/drought_indices/VDI/VDI_IP_2022_3.tif
#
# 	Month: 4
# 	saving VDI result for 2022-4 to CDI_data/drought_indices/VDI/VDI_IP_2022_4.tif
#
# 	Month: 5
# 	saving VDI result for 2022-5 to CDI_data/drought_indices/VDI/VDI_IP_2022_5.tif
#
# 	Month: 6
# 	saving VDI result for 2022-6 to CDI_data/drought_indices/VDI/VDI_IP_2022_6.tif
#
# 	Month: 7
# 	saving VDI result for 2022-7 to CDI_data/drought_indices/VDI/VDI_IP_2022_7.tif
#
# 	Month: 8
# 	saving VDI result for 2022-8 to CDI_data/drought_indices/VDI/VDI_IP_2022_8.tif
#
# 	Month: 9
# 	saving VDI result for 2022-9 to CDI_data/drought_indices/VDI/VDI_IP_2022_9.tif
#
# 	Month: 10
# 	saving VDI result for 2022-10 to CDI_data/drought_indices/VDI/VDI_IP_2022_10.tif
#
# 	Month: 11
# 	saving VDI result for 2022-11 to CDI_data/drought_indices/VDI/VDI_IP_2022_11.tif
#
# 	Month: 12
# 	saving VDI result for 2022-12 to CDI_data/drought_indices/VDI/VDI_IP_2022_12.tif

# %% [markdown]
# ## 4. CDI calculation
# Now that we have produced the three components of the CDI (PDI, TDI and VDI), we can now merged them together and obtain the final CDI for each of the IPs.
#
# First, we need to resample all the of the datasets to have a common pixel size and extent. We will use the NDVI files as the template to resample all data to the same pixel size. We will also take advantage to clip the datasets to the region of interest (ROI) over the Borena region.

# %%
vdi_folder = outfolder / 'VDI'
template_file = list(vdi_folder.glob('*.tif'))[0]

# file pathname to Borena ROI shapefile
roi_file = Path() / 'CDI_data' / 'roi_info' / 'Borena_outline_utm.geojson'

pdi_ds, tdi_ds, vdi_ds = cdi.resample_indices(outfolder, roi_file, template_file, start_date, end_date, indices = ['PDI', 'TDI', 'VDI'])
# Out:
# resampling PDI images
# 2002-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2002_1_roi.tif
# 2005-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2005_12_roi.tif
# 2013-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2013_9_roi.tif
# 2006-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2006_5_roi.tif
# 2020-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2020_6_roi.tif
# 2017-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2017_12_roi.tif
# 2004-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2004_7_roi.tif
# 2022-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2022_4_roi.tif
# 2009-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2009_12_roi.tif
# 2019-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2019_2_roi.tif
# 2019-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2019_3_roi.tif
# 2022-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2022_5_roi.tif
# 2021-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2021_12_roi.tif
# 2004-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2004_6_roi.tif
# 2020-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2020_7_roi.tif
# 2006-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2006_4_roi.tif
# 2013-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2013_8_roi.tif
# 2002-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2002_2_roi.tif
# 2011-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2011_8_roi.tif
# 2005-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2005_11_roi.tif
# 2020-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2020_5_roi.tif
# 2006-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2006_6_roi.tif
# 2008-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2008_9_roi.tif
# 2017-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2017_11_roi.tif
# 2021-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2021_10_roi.tif
# 2022-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2022_7_roi.tif
# 2004-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2004_4_roi.tif
# 2009-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2009_11_roi.tif
# 2019-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2019_1_roi.tif
# 2009-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2009_10_roi.tif
# 2004-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2004_5_roi.tif
# 2021-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2021_11_roi.tif
# 2022-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2022_6_roi.tif
# 2017-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2017_10_roi.tif
# 2008-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2008_8_roi.tif
# 2006-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2006_7_roi.tif
# 2020-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2020_4_roi.tif
# 2005-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2005_10_roi.tif
# 2011-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2011_9_roi.tif
# 2002-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2002_3_roi.tif
# 2002-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2002_7_roi.tif
# 2015-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2015_11_roi.tif
# 2015-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2015_9_roi.tif
# 2006-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2006_3_roi.tif
# 2019-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2019_11_roi.tif
# 2022-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2022_2_roi.tif
# 2004-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2004_1_roi.tif
# 2007-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2007_11_roi.tif
# 2019-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2019_4_roi.tif
# 2019-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2019_5_roi.tif
# 2007-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2007_10_roi.tif
# 2022-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2022_3_roi.tif
# 2019-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2019_10_roi.tif
# 2006-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2006_2_roi.tif
# 2015-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2015_8_roi.tif
# 2020-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2020_1_roi.tif
# 2015-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2015_10_roi.tif
# 2002-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2002_6_roi.tif
# 2002-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2002_4_roi.tif
# 2015-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2015_12_roi.tif
# 2020-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2020_3_roi.tif
# 2019-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2019_12_roi.tif
# 2004-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2004_2_roi.tif
# 2017-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2017_8_roi.tif
# 2022-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2022_1_roi.tif
# 2019-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2019_7_roi.tif
# 2007-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2007_12_roi.tif
# 2019-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2019_6_roi.tif
# 2017-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2017_9_roi.tif
# 2004-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2004_3_roi.tif
# 2020-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2020_2_roi.tif
# 2006-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2006_1_roi.tif
# 2002-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2002_5_roi.tif
# 2005-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2005_4_roi.tif
# 2011-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2011_10_roi.tif
# 2018-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2018_1_roi.tif
# 2021-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2021_5_roi.tif
# 2007-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2007_6_roi.tif
# 2009-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2009_9_roi.tif
# 2003-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2003_10_roi.tif
# 2003-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2003_2_roi.tif
# 2010-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2010_8_roi.tif
# 2010-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2010_9_roi.tif
# 2003-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2003_3_roi.tif
# 2003-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2003_11_roi.tif
# 2001-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2001_1_roi.tif
# 2009-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2009_8_roi.tif
# 2007-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2007_7_roi.tif
# 2021-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2021_4_roi.tif
# 2011-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2011_11_roi.tif
# 2005-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2005_5_roi.tif
# 2005-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2005_7_roi.tif
# 2018-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2018_2_roi.tif
# 2007-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2007_5_roi.tif
# 2021-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2021_6_roi.tif
# 2012-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2012_9_roi.tif
# 2001-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2001_3_roi.tif
# 2003-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2003_1_roi.tif
# 2003-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2003_12_roi.tif
# 2001-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2001_2_roi.tif
# 2012-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2012_8_roi.tif
# 2021-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2021_7_roi.tif
# 2007-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2007_4_roi.tif
# 2011-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2011_12_roi.tif
# 2018-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2018_3_roi.tif
# 2005-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2005_6_roi.tif
# 2005-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2005_2_roi.tif
# 2016-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2016_8_roi.tif
# 2018-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2018_7_roi.tif
# 2021-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2021_3_roi.tif
# 2001-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2001_6_roi.tif
# 2003-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2003_4_roi.tif
# 2013-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2013_12_roi.tif
# 2003-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2003_5_roi.tif
# 2001-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2001_7_roi.tif
# 2001-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2001_12_roi.tif
# 2021-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2021_2_roi.tif
# 2007-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2007_1_roi.tif
# 2018-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2018_6_roi.tif
# 2016-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2016_9_roi.tif
# 2005-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2005_3_roi.tif
# 2005-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2005_1_roi.tif
# 2018-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2018_4_roi.tif
# 2014-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2014_9_roi.tif
# 2007-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2007_3_roi.tif
# 2001-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2001_10_roi.tif
# 2001-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2001_5_roi.tif
# 2003-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2003_7_roi.tif
# 2013-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2013_10_roi.tif
# 2013-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2013_11_roi.tif
# 2003-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2003_6_roi.tif
# 2001-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2001_4_roi.tif
# 2001-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2001_11_roi.tif
# 2007-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2007_2_roi.tif
# 2014-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2014_8_roi.tif
# 2021-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2021_1_roi.tif
# 2018-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2018_5_roi.tif
# 2016-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2016_7_roi.tif
# 2018-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2018_8_roi.tif
# 2016-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2016_10_roi.tif
# 2020-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2020_11_roi.tif
# 2014-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2014_5_roi.tif
# 2008-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2008_10_roi.tif
# 2012-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2012_3_roi.tif
# 2001-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2001_9_roi.tif
# 2004-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2004_10_roi.tif
# 2010-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2010_1_roi.tif
# 2004-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2004_11_roi.tif
# 2001-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2001_8_roi.tif
# 2012-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2012_2_roi.tif
# 2008-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2008_11_roi.tif
# 2009-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2009_1_roi.tif
# 2014-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2014_4_roi.tif
# 2020-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2020_10_roi.tif
# 2016-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2016_11_roi.tif
# 2018-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2018_9_roi.tif
# 2016-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2016_6_roi.tif
# 2016-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2016_4_roi.tif
# 2014-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2014_6_roi.tif
# 2020-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2020_12_roi.tif
# 2009-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2009_3_roi.tif
# 2003-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2003_8_roi.tif
# 2010-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2010_2_roi.tif
# 2010-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2010_3_roi.tif
# 2003-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2003_9_roi.tif
# 2004-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2004_12_roi.tif
# 2012-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2012_1_roi.tif
# 2008-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2008_12_roi.tif
# 2009-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2009_2_roi.tif
# 2014-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2014_7_roi.tif
# 2016-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2016_12_roi.tif
# 2016-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2016_5_roi.tif
# 2016-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2016_1_roi.tif
# 2014-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2014_3_roi.tif
# 2007-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2007_9_roi.tif
# 2009-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2009_6_roi.tif
# 2012-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2012_5_roi.tif
# 2022-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2022_12_roi.tif
# 2010-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2010_7_roi.tif
# 2014-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2014_12_roi.tif
# 2010-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2010_6_roi.tif
# 2012-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2012_4_roi.tif
# 2006-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2006_12_roi.tif
# 2009-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2009_7_roi.tif
# 2007-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2007_8_roi.tif
# 2014-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2014_2_roi.tif
# 2018-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2018_12_roi.tif
# 2005-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2005_8_roi.tif
# 2016-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2016_2_roi.tif
# 2018-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2018_10_roi.tif
# 2021-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2021_9_roi.tif
# 2006-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2006_10_roi.tif
# 2009-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2009_5_roi.tif
# 2022-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2022_11_roi.tif
# 2012-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2012_6_roi.tif
# 2010-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2010_4_roi.tif
# 2014-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2014_10_roi.tif
# 2014-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2014_11_roi.tif
# 2010-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2010_5_roi.tif
# 2022-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2022_10_roi.tif
# 2012-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2012_7_roi.tif
# 2009-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2009_4_roi.tif
# 2006-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2006_11_roi.tif
# 2021-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2021_8_roi.tif
# 2014-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2014_1_roi.tif
# 2018-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2018_11_roi.tif
# 2016-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2016_3_roi.tif
# 2005-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2005_9_roi.tif
# 2002-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2002_8_roi.tif
# 2011-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2011_2_roi.tif
# 2002-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2002_12_roi.tif
# 2015-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2015_6_roi.tif
# 2008-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2008_3_roi.tif
# 2010-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2010_12_roi.tif
# 2017-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2017_4_roi.tif
# 2017-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2017_5_roi.tif
# 2008-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2008_2_roi.tif
# 2015-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2015_7_roi.tif
# 2013-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2013_1_roi.tif
# 2011-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2011_3_roi.tif
# 2002-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2002_9_roi.tif
# 2011-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2011_1_roi.tif
# 2002-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2002_11_roi.tif
# 2013-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2013_3_roi.tif
# 2015-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2015_5_roi.tif
# 2010-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2010_11_roi.tif
# 2017-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2017_7_roi.tif
# 2019-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2019_8_roi.tif
# 2019-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2019_9_roi.tif
# 2017-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2017_6_roi.tif
# 2008-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2008_1_roi.tif
# 2010-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2010_10_roi.tif
# 2015-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2015_4_roi.tif
# 2013-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2013_2_roi.tif
# 2002-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2002_10_roi.tif
# 2011-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2011_4_roi.tif
# 2013-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2013_6_roi.tif
# 2012-11-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2012_11_roi.tif
# 2020-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2020_9_roi.tif
# 2008-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2008_5_roi.tif
# 2004-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2004_8_roi.tif
# 2017-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2017_2_roi.tif
# 2017-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2017_3_roi.tif
# 2004-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2004_9_roi.tif
# 2008-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2008_4_roi.tif
# 2020-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2020_8_roi.tif
# 2015-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2015_1_roi.tif
# 2012-10-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2012_10_roi.tif
# 2013-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2013_7_roi.tif
# 2011-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2011_5_roi.tif
# 2011-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2011_7_roi.tif
# 2013-05-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2013_5_roi.tif
# 2012-12-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2012_12_roi.tif
# 2015-03-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2015_3_roi.tif
# 2006-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2006_9_roi.tif
# 2008-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2008_6_roi.tif
# 2022-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2022_8_roi.tif
# 2017-01-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2017_1_roi.tif
# 2022-09-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2022_9_roi.tif
# 2008-07-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2008_7_roi.tif
# 2006-08-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2006_8_roi.tif
# 2015-02-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2015_2_roi.tif
# 2013-04-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2013_4_roi.tif
# 2011-06-01 00:00:00
# Saving as CDI_data/drought_indices/PDI/ROI/PDI_IP_2011_6_roi.tif
# resampling TDI images
# 2014-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2014_6_roi.tif
# 2009-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2009_3_roi.tif
# 2016-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2016_4_roi.tif
# 2010-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2010_2_roi.tif
# 2003-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2003_8_roi.tif
# 2015-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2015_12_roi.tif
# 2012-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2012_1_roi.tif
# 2003-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2003_9_roi.tif
# 2010-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2010_3_roi.tif
# 2007-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2007_12_roi.tif
# 2016-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2016_5_roi.tif
# 2009-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2009_2_roi.tif
# 2019-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2019_12_roi.tif
# 2014-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2014_7_roi.tif
# 2014-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2014_5_roi.tif
# 2019-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2019_10_roi.tif
# 2016-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2016_7_roi.tif
# 2018-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2018_8_roi.tif
# 2007-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2007_10_roi.tif
# 2010-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2010_1_roi.tif
# 2001-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2001_9_roi.tif
# 2012-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2012_3_roi.tif
# 2015-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2015_10_roi.tif
# 2015-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2015_11_roi.tif
# 2012-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2012_2_roi.tif
# 2001-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2001_8_roi.tif
# 2007-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2007_11_roi.tif
# 2018-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2018_9_roi.tif
# 2016-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2016_6_roi.tif
# 2019-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2019_11_roi.tif
# 2009-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2009_1_roi.tif
# 2014-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2014_4_roi.tif
# 2021-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2021_9_roi.tif
# 2017-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2017_10_roi.tif
# 2009-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2009_5_roi.tif
# 2021-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2021_11_roi.tif
# 2016-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2016_2_roi.tif
# 2005-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2005_8_roi.tif
# 2009-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2009_10_roi.tif
# 2010-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2010_4_roi.tif
# 2005-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2005_10_roi.tif
# 2012-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2012_6_roi.tif
# 2012-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2012_7_roi.tif
# 2005-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2005_11_roi.tif
# 2010-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2010_5_roi.tif
# 2009-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2009_11_roi.tif
# 2005-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2005_9_roi.tif
# 2016-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2016_3_roi.tif
# 2021-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2021_10_roi.tif
# 2009-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2009_4_roi.tif
# 2017-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2017_11_roi.tif
# 2021-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2021_8_roi.tif
# 2014-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2014_1_roi.tif
# 2007-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2007_9_roi.tif
# 2014-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2014_3_roi.tif
# 2009-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2009_6_roi.tif
# 2021-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2021_12_roi.tif
# 2016-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2016_1_roi.tif
# 2010-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2010_7_roi.tif
# 2012-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2012_5_roi.tif
# 2012-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2012_4_roi.tif
# 2005-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2005_12_roi.tif
# 2010-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2010_6_roi.tif
# 2009-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2009_12_roi.tif
# 2009-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2009_7_roi.tif
# 2017-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2017_12_roi.tif
# 2014-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2014_2_roi.tif
# 2007-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2007_8_roi.tif
# 2013-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2013_3_roi.tif
# 2011-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2011_1_roi.tif
# 2013-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2013_11_roi.tif
# 2017-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2017_7_roi.tif
# 2019-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2019_8_roi.tif
# 2015-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2015_5_roi.tif
# 2001-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2001_11_roi.tif
# 2001-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2001_10_roi.tif
# 2008-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2008_1_roi.tif
# 2015-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2015_4_roi.tif
# 2019-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2019_9_roi.tif
# 2017-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2017_6_roi.tif
# 2013-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2013_10_roi.tif
# 2013-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2013_2_roi.tif
# 2011-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2011_2_roi.tif
# 2002-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2002_8_roi.tif
# 2013-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2013_12_roi.tif
# 2017-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2017_4_roi.tif
# 2015-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2015_6_roi.tif
# 2008-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2008_3_roi.tif
# 2001-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2001_12_roi.tif
# 2008-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2008_2_roi.tif
# 2015-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2015_7_roi.tif
# 2017-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2017_5_roi.tif
# 2002-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2002_9_roi.tif
# 2011-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2011_3_roi.tif
# 2013-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2013_1_roi.tif
# 2013-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2013_5_roi.tif
# 2003-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2003_12_roi.tif
# 2011-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2011_7_roi.tif
# 2022-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2022_8_roi.tif
# 2017-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2017_1_roi.tif
# 2011-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2011_12_roi.tif
# 2006-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2006_9_roi.tif
# 2015-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2015_3_roi.tif
# 2008-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2008_6_roi.tif
# 2008-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2008_7_roi.tif
# 2015-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2015_2_roi.tif
# 2006-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2006_8_roi.tif
# 2022-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2022_9_roi.tif
# 2011-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2011_6_roi.tif
# 2013-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2013_4_roi.tif
# 2013-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2013_6_roi.tif
# 2003-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2003_11_roi.tif
# 2011-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2011_4_roi.tif
# 2017-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2017_2_roi.tif
# 2004-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2004_8_roi.tif
# 2011-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2011_11_roi.tif
# 2020-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2020_9_roi.tif
# 2008-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2008_5_roi.tif
# 2008-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2008_4_roi.tif
# 2020-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2020_8_roi.tif
# 2015-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2015_1_roi.tif
# 2011-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2011_10_roi.tif
# 2004-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2004_9_roi.tif
# 2017-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2017_3_roi.tif
# 2011-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2011_5_roi.tif
# 2003-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2003_10_roi.tif
# 2013-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2013_7_roi.tif
# 2022-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2022_10_roi.tif
# 2011-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2011_8_roi.tif
# 2002-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2002_2_roi.tif
# 2014-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2014_11_roi.tif
# 2004-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2004_4_roi.tif
# 2022-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2022_7_roi.tif
# 2019-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2019_1_roi.tif
# 2018-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2018_11_roi.tif
# 2006-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2006_6_roi.tif
# 2020-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2020_5_roi.tif
# 2006-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2006_11_roi.tif
# 2008-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2008_9_roi.tif
# 2008-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2008_8_roi.tif
# 2006-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2006_10_roi.tif
# 2020-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2020_4_roi.tif
# 2006-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2006_7_roi.tif
# 2018-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2018_10_roi.tif
# 2022-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2022_6_roi.tif
# 2004-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2004_5_roi.tif
# 2014-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2014_10_roi.tif
# 2002-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2002_3_roi.tif
# 2011-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2011_9_roi.tif
# 2022-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2022_11_roi.tif
# 2013-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2013_9_roi.tif
# 2002-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2002_1_roi.tif
# 2014-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2014_12_roi.tif
# 2022-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2022_4_roi.tif
# 2004-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2004_7_roi.tif
# 2018-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2018_12_roi.tif
# 2019-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2019_2_roi.tif
# 2020-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2020_6_roi.tif
# 2006-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2006_5_roi.tif
# 2006-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2006_12_roi.tif
# 2006-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2006_4_roi.tif
# 2020-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2020_7_roi.tif
# 2019-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2019_3_roi.tif
# 2004-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2004_6_roi.tif
# 2022-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2022_5_roi.tif
# 2013-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2013_8_roi.tif
# 2022-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2022_12_roi.tif
# 2004-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2004_12_roi.tif
# 2002-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2002_4_roi.tif
# 2017-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2017_8_roi.tif
# 2022-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2022_1_roi.tif
# 2004-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2004_2_roi.tif
# 2019-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2019_7_roi.tif
# 2016-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2016_12_roi.tif
# 2020-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2020_3_roi.tif
# 2008-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2008_12_roi.tif
# 2020-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2020_12_roi.tif
# 2006-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2006_1_roi.tif
# 2020-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2020_2_roi.tif
# 2019-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2019_6_roi.tif
# 2004-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2004_3_roi.tif
# 2017-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2017_9_roi.tif
# 2002-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2002_5_roi.tif
# 2004-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2004_11_roi.tif
# 2002-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2002_7_roi.tif
# 2004-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2004_1_roi.tif
# 2022-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2022_2_roi.tif
# 2019-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2019_4_roi.tif
# 2016-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2016_11_roi.tif
# 2006-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2006_3_roi.tif
# 2015-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2015_9_roi.tif
# 2020-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2020_10_roi.tif
# 2008-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2008_11_roi.tif
# 2008-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2008_10_roi.tif
# 2020-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2020_11_roi.tif
# 2015-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2015_8_roi.tif
# 2020-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2020_1_roi.tif
# 2006-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2006_2_roi.tif
# 2016-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2016_10_roi.tif
# 2019-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2019_5_roi.tif
# 2022-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2022_3_roi.tif
# 2002-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2002_6_roi.tif
# 2004-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2004_10_roi.tif
# 2021-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2021_6_roi.tif
# 2007-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2007_5_roi.tif
# 2005-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2005_7_roi.tif
# 2018-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2018_2_roi.tif
# 2003-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2003_1_roi.tif
# 2001-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2001_3_roi.tif
# 2012-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2012_9_roi.tif
# 2012-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2012_12_roi.tif
# 2012-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2012_8_roi.tif
# 2001-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2001_2_roi.tif
# 2018-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2018_3_roi.tif
# 2005-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2005_6_roi.tif
# 2007-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2007_4_roi.tif
# 2021-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2021_7_roi.tif
# 2007-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2007_6_roi.tif
# 2021-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2021_5_roi.tif
# 2009-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2009_9_roi.tif
# 2005-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2005_4_roi.tif
# 2018-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2018_1_roi.tif
# 2010-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2010_8_roi.tif
# 2003-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2003_2_roi.tif
# 2012-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2012_10_roi.tif
# 2012-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2012_11_roi.tif
# 2001-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2001_1_roi.tif
# 2003-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2003_3_roi.tif
# 2010-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2010_9_roi.tif
# 2005-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2005_5_roi.tif
# 2009-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2009_8_roi.tif
# 2021-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2021_4_roi.tif
# 2007-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2007_7_roi.tif
# 2007-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2007_3_roi.tif
# 2014-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2014_9_roi.tif
# 2010-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2010_10_roi.tif
# 2005-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2005_1_roi.tif
# 2018-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2018_4_roi.tif
# 2003-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2003_7_roi.tif
# 2002-10-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2002_10_roi.tif
# 2001-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2001_5_roi.tif
# 2001-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2001_4_roi.tif
# 2002-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2002_11_roi.tif
# 2003-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2003_6_roi.tif
# 2018-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2018_5_roi.tif
# 2010-11-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2010_11_roi.tif
# 2014-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2014_8_roi.tif
# 2021-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2021_1_roi.tif
# 2007-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2007_2_roi.tif
# 2021-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2021_3_roi.tif
# 2016-08-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2016_8_roi.tif
# 2005-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2005_2_roi.tif
# 2018-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2018_7_roi.tif
# 2003-04-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2003_4_roi.tif
# 2001-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2001_6_roi.tif
# 2001-07-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2001_7_roi.tif
# 2002-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2002_12_roi.tif
# 2003-05-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2003_5_roi.tif
# 2018-06-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2018_6_roi.tif
# 2005-03-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2005_3_roi.tif
# 2016-09-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2016_9_roi.tif
# 2010-12-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2010_12_roi.tif
# 2007-01-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2007_1_roi.tif
# 2021-02-01 00:00:00
# Saving as CDI_data/drought_indices/TDI/ROI/TDI_IP_2021_2_roi.tif
# resampling VDI images
# 2012-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2012_8_roi.tif
# 2001-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2001_2_roi.tif
# 2022-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2022_12_roi.tif
# 2005-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2005_6_roi.tif
# 2018-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2018_3_roi.tif
# 2007-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2007_4_roi.tif
# 2021-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2021_7_roi.tif
# 2018-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2018_12_roi.tif
# 2021-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2021_6_roi.tif
# 2007-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2007_5_roi.tif
# 2006-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2006_12_roi.tif
# 2018-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2018_2_roi.tif
# 2005-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2005_7_roi.tif
# 2003-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2003_1_roi.tif
# 2014-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2014_12_roi.tif
# 2001-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2001_3_roi.tif
# 2012-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2012_9_roi.tif
# 2001-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2001_1_roi.tif
# 2014-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2014_10_roi.tif
# 2003-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2003_3_roi.tif
# 2022-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2022_11_roi.tif
# 2010-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2010_9_roi.tif
# 2005-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2005_5_roi.tif
# 2006-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2006_10_roi.tif
# 2021-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2021_4_roi.tif
# 2007-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2007_7_roi.tif
# 2009-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2009_8_roi.tif
# 2018-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2018_10_roi.tif
# 2018-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2018_11_roi.tif
# 2009-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2009_9_roi.tif
# 2007-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2007_6_roi.tif
# 2021-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2021_5_roi.tif
# 2018-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2018_1_roi.tif
# 2006-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2006_11_roi.tif
# 2005-04-01 00:00:00
# ...
# 2006-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2006_7_roi.tif
# 2008-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2008_8_roi.tif
# 2022-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2022_6_roi.tif
# 2004-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2004_5_roi.tif
# 2002-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2002_3_roi.tif
# 2011-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2011_9_roi.tif
# 2012-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2012_11_roi.tif
# 2012-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2012_10_roi.tif
# 2011-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2011_8_roi.tif
# 2002-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2002_2_roi.tif
# 2019-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2019_1_roi.tif
# 2004-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2004_4_roi.tif
# 2022-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2022_7_roi.tif
# 2008-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2008_9_roi.tif
# 2006-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2006_6_roi.tif
# 2020-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2020_5_roi.tif
# 2006-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2006_4_roi.tif
# 2020-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2020_7_roi.tif
# 2004-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2004_6_roi.tif
# 2022-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2022_5_roi.tif
# 2019-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2019_3_roi.tif
# 2012-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2012_12_roi.tif
# 2013-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2013_8_roi.tif
# 2013-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2013_9_roi.tif
# 2002-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2002_1_roi.tif
# 2019-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2019_2_roi.tif
# 2022-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2022_4_roi.tif
# 2004-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2004_7_roi.tif
# 2020-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2020_6_roi.tif
# 2006-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2006_5_roi.tif
# 2006-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2006_1_roi.tif
# 2020-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2020_2_roi.tif
# 2004-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2004_3_roi.tif
# 2017-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2017_9_roi.tif
# 2019-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2019_6_roi.tif
# 2010-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2010_12_roi.tif
# 2002-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2002_5_roi.tif
# 2002-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2002_12_roi.tif
# 2002-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2002_4_roi.tif
# 2019-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2019_7_roi.tif
# 2017-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2017_8_roi.tif
# 2022-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2022_1_roi.tif
# 2004-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2004_2_roi.tif
# 2020-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2020_3_roi.tif
# 2015-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2015_8_roi.tif
# 2020-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2020_1_roi.tif
# 2006-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2006_2_roi.tif
# 2022-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2022_3_roi.tif
# 2010-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2010_11_roi.tif
# 2019-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2019_5_roi.tif
# 2002-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2002_6_roi.tif
# 2002-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2002_11_roi.tif
# 2002-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2002_10_roi.tif
# 2002-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2002_7_roi.tif
# 2019-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2019_4_roi.tif
# 2010-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2010_10_roi.tif
# 2004-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2004_1_roi.tif
# 2022-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2022_2_roi.tif
# 2006-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2006_3_roi.tif
# 2015-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2015_9_roi.tif
# 2015-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2015_4_roi.tif
# 2007-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2007_11_roi.tif
# 2008-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2008_1_roi.tif
# 2017-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2017_6_roi.tif
# 2019-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2019_11_roi.tif
# 2019-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2019_9_roi.tif
# 2015-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2015_11_roi.tif
# 2013-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2013_2_roi.tif
# 2013-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2013_3_roi.tif
# 2015-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2015_10_roi.tif
# 2011-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2011_1_roi.tif
# 2019-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2019_8_roi.tif
# 2019-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2019_10_roi.tif
# 2017-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2017_7_roi.tif
# 2007-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2007_10_roi.tif
# 2015-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2015_5_roi.tif
# 2015-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2015_7_roi.tif
# 2008-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2008_2_roi.tif
# 2007-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2007_12_roi.tif
# 2017-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2017_5_roi.tif
# 2019-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2019_12_roi.tif
# 2002-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2002_9_roi.tif
# 2011-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2011_3_roi.tif
# 2015-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2015_12_roi.tif
# 2013-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2013_1_roi.tif
# 2011-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2011_2_roi.tif
# 2002-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2002_8_roi.tif
# 2017-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2017_4_roi.tif
# 2008-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2008_3_roi.tif
# 2015-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2015_6_roi.tif
# 2015-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2015_2_roi.tif
# 2006-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2006_8_roi.tif
# 2008-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2008_7_roi.tif
# 2009-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2009_12_roi.tif
# 2022-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2022_9_roi.tif
# 2017-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2017_12_roi.tif
# 2011-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2011_6_roi.tif
# 2013-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2013_4_roi.tif
# 2005-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2005_12_roi.tif
# 2013-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2013_5_roi.tif
# 2011-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2011_7_roi.tif
# 2022-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2022_8_roi.tif
# 2017-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2017_1_roi.tif
# 2008-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2008_6_roi.tif
# 2021-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2021_12_roi.tif
# 2006-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2006_9_roi.tif
# 2015-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2015_3_roi.tif
# 2021-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2021_10_roi.tif
# 2020-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2020_8_roi.tif
# 2015-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2015_1_roi.tif
# 2008-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2008_4_roi.tif
# 2009-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2009_11_roi.tif
# 2004-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2004_9_roi.tif
# 2017-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2017_3_roi.tif
# 2017-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2017_11_roi.tif
# 2011-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2011_5_roi.tif
# 2013-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2013_7_roi.tif
# 2005-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2005_11_roi.tif
# 2005-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2005_10_roi.tif
# 2013-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2013_6_roi.tif
# 2011-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2011_4_roi.tif
# 2017-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2017_10_roi.tif
# 2017-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2017_2_roi.tif
# 2004-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2004_8_roi.tif
# 2009-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2009_10_roi.tif
# 2008-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2008_5_roi.tif
# 2020-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2020_9_roi.tif
# 2021-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2021_11_roi.tif
# 2012-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2012_1_roi.tif
# 2003-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2003_9_roi.tif
# 2010-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2010_3_roi.tif
# 2016-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2016_5_roi.tif
# 2014-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2014_7_roi.tif
# 2009-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2009_2_roi.tif
# 2009-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2009_3_roi.tif
# 2014-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2014_6_roi.tif
# 2001-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2001_12_roi.tif
# 2016-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2016_4_roi.tif
# 2010-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2010_2_roi.tif
# 2003-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2003_8_roi.tif
# 2013-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2013_12_roi.tif
# 2012-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2012_2_roi.tif
# 2001-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2001_8_roi.tif
# 2013-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2013_10_roi.tif
# 2016-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2016_6_roi.tif
# 2018-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2018_9_roi.tif
# 2001-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2001_10_roi.tif
# 2014-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2014_4_roi.tif
# 2009-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2009_1_roi.tif
# 2014-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2014_5_roi.tif
# 2001-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2001_11_roi.tif
# 2018-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2018_8_roi.tif
# 2016-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2016_7_roi.tif
# 2010-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2010_1_roi.tif
# 2013-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2013_11_roi.tif
# 2001-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2001_9_roi.tif
# 2012-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2012_3_roi.tif
# 2012-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2012_7_roi.tif
# 2010-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2010_5_roi.tif
# 2003-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2003_10_roi.tif
# 2005-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2005_9_roi.tif
# 2016-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2016_3_roi.tif
# 2021-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2021_8_roi.tif
# 2014-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2014_1_roi.tif
# 2011-10-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2011_10_roi.tif
# 2009-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2009_4_roi.tif
# 2009-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2009_5_roi.tif
# 2011-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2011_11_roi.tif
# 2021-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2021_9_roi.tif
# 2016-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2016_2_roi.tif
# 2005-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2005_8_roi.tif
# 2003-11-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2003_11_roi.tif
# 2010-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2010_4_roi.tif
# 2012-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2012_6_roi.tif
# 2012-04-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2012_4_roi.tif
# 2010-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2010_6_roi.tif
# 2014-02-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2014_2_roi.tif
# 2007-08-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2007_8_roi.tif
# 2009-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2009_7_roi.tif
# 2011-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2011_12_roi.tif
# 2009-06-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2009_6_roi.tif
# 2007-09-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2007_9_roi.tif
# 2014-03-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2014_3_roi.tif
# 2016-01-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2016_1_roi.tif
# 2003-12-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2003_12_roi.tif
# 2010-07-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2010_7_roi.tif
# 2012-05-01 00:00:00
# Saving as CDI_data/drought_indices/VDI/ROI/VDI_IP_2012_5_roi.tif

# %% [markdown]
# Now we can finnaly merge all drought indices to compute the CDI

# %%
outfolder = Path() / 'CDI_data' / 'drought_indices'

# use template of the ROI image
template_folder = outfolder/'VDI'/'ROI'
template_file = list(template_folder.glob('*.tif'))[0]
# get geotransform and projection data from ROI image
proj, gt, _ , _ , _ , _ , _ = gu.raster_info(str(template_file))

# compute CDI
#cdi_ds = cdi.calc_cdi(pdi_ds, tdi_ds, vdi_ds, gt, proj, outfolder)
cdi_ds = cdi.calc_cdi_img(start_date, end_date, gt, proj, outfolder)
# Out:
# 2001-01-01 00:00:00
# 	saving final CDI image for 2001-1 to CDI_data/drought_indices/CDI/CDI_IP_2001_1.tif
#
# 2001-02-01 00:00:00
# 	saving final CDI image for 2001-2 to CDI_data/drought_indices/CDI/CDI_IP_2001_2.tif
#
# 2001-03-01 00:00:00
# 	saving final CDI image for 2001-3 to CDI_data/drought_indices/CDI/CDI_IP_2001_3.tif
#
# 2001-04-01 00:00:00
# 	saving final CDI image for 2001-4 to CDI_data/drought_indices/CDI/CDI_IP_2001_4.tif
#
# 2001-05-01 00:00:00
# 	saving final CDI image for 2001-5 to CDI_data/drought_indices/CDI/CDI_IP_2001_5.tif
#
# 2001-06-01 00:00:00
# 	saving final CDI image for 2001-6 to CDI_data/drought_indices/CDI/CDI_IP_2001_6.tif
#
# 2001-07-01 00:00:00
# 	saving final CDI image for 2001-7 to CDI_data/drought_indices/CDI/CDI_IP_2001_7.tif
#
# 2001-08-01 00:00:00
# 	saving final CDI image for 2001-8 to CDI_data/drought_indices/CDI/CDI_IP_2001_8.tif
#
# 2001-09-01 00:00:00
# 	saving final CDI image for 2001-9 to CDI_data/drought_indices/CDI/CDI_IP_2001_9.tif
#
# 2001-10-01 00:00:00
# 	saving final CDI image for 2001-10 to CDI_data/drought_indices/CDI/CDI_IP_2001_10.tif
#
# 2001-11-01 00:00:00
# 	saving final CDI image for 2001-11 to CDI_data/drought_indices/CDI/CDI_IP_2001_11.tif
#
# 2001-12-01 00:00:00
# 	saving final CDI image for 2001-12 to CDI_data/drought_indices/CDI/CDI_IP_2001_12.tif
#
# 2002-01-01 00:00:00
# 	saving final CDI image for 2002-1 to CDI_data/drought_indices/CDI/CDI_IP_2002_1.tif
#
# 2002-02-01 00:00:00
# 	saving final CDI image for 2002-2 to CDI_data/drought_indices/CDI/CDI_IP_2002_2.tif
#
# 2002-03-01 00:00:00
# 	saving final CDI image for 2002-3 to CDI_data/drought_indices/CDI/CDI_IP_2002_3.tif
#
# 2002-04-01 00:00:00
# 	saving final CDI image for 2002-4 to CDI_data/drought_indices/CDI/CDI_IP_2002_4.tif
#
# 2002-05-01 00:00:00
# 	saving final CDI image for 2002-5 to CDI_data/drought_indices/CDI/CDI_IP_2002_5.tif
#
# 2002-06-01 00:00:00
# 	saving final CDI image for 2002-6 to CDI_data/drought_indices/CDI/CDI_IP_2002_6.tif
#
# 2002-07-01 00:00:00
# 	saving final CDI image for 2002-7 to CDI_data/drought_indices/CDI/CDI_IP_2002_7.tif
#
# 2002-08-01 00:00:00
# 	saving final CDI image for 2002-8 to CDI_data/drought_indices/CDI/CDI_IP_2002_8.tif
#
# 2002-09-01 00:00:00
# 	saving final CDI image for 2002-9 to CDI_data/drought_indices/CDI/CDI_IP_2002_9.tif
#
# 2002-10-01 00:00:00
# 	saving final CDI image for 2002-10 to CDI_data/drought_indices/CDI/CDI_IP_2002_10.tif
#
# 2002-11-01 00:00:00
# 	saving final CDI image for 2002-11 to CDI_data/drought_indices/CDI/CDI_IP_2002_11.tif
#
# 2002-12-01 00:00:00
# 	saving final CDI image for 2002-12 to CDI_data/drought_indices/CDI/CDI_IP_2002_12.tif
#
# 2003-01-01 00:00:00
# 	saving final CDI image for 2003-1 to CDI_data/drought_indices/CDI/CDI_IP_2003_1.tif
#
# 2003-02-01 00:00:00
# 	saving final CDI image for 2003-2 to CDI_data/drought_indices/CDI/CDI_IP_2003_2.tif
#
# 2003-03-01 00:00:00
# 	saving final CDI image for 2003-3 to CDI_data/drought_indices/CDI/CDI_IP_2003_3.tif
#
# 2003-04-01 00:00:00
# 	saving final CDI image for 2003-4 to CDI_data/drought_indices/CDI/CDI_IP_2003_4.tif
#
# 2003-05-01 00:00:00
# 	saving final CDI image for 2003-5 to CDI_data/drought_indices/CDI/CDI_IP_2003_5.tif
#
# 2003-06-01 00:00:00
# 	saving final CDI image for 2003-6 to CDI_data/drought_indices/CDI/CDI_IP_2003_6.tif
#
# 2003-07-01 00:00:00
# 	saving final CDI image for 2003-7 to CDI_data/drought_indices/CDI/CDI_IP_2003_7.tif
#
# 2003-08-01 00:00:00
# 	saving final CDI image for 2003-8 to CDI_data/drought_indices/CDI/CDI_IP_2003_8.tif
#
# 2003-09-01 00:00:00
# 	saving final CDI image for 2003-9 to CDI_data/drought_indices/CDI/CDI_IP_2003_9.tif
#
# 2003-10-01 00:00:00
# 	saving final CDI image for 2003-10 to CDI_data/drought_indices/CDI/CDI_IP_2003_10.tif
#
# 2003-11-01 00:00:00
# 	saving final CDI image for 2003-11 to CDI_data/drought_indices/CDI/CDI_IP_2003_11.tif
#
# 2003-12-01 00:00:00
# 	saving final CDI image for 2003-12 to CDI_data/drought_indices/CDI/CDI_IP_2003_12.tif
#
# 2004-01-01 00:00:00
# 	saving final CDI image for 2004-1 to CDI_data/drought_indices/CDI/CDI_IP_2004_1.tif
#
# 2004-02-01 00:00:00
# 	saving final CDI image for 2004-2 to CDI_data/drought_indices/CDI/CDI_IP_2004_2.tif
#
# 2004-03-01 00:00:00
# 	saving final CDI image for 2004-3 to CDI_data/drought_indices/CDI/CDI_IP_2004_3.tif
#
# 2004-04-01 00:00:00
# 	saving final CDI image for 2004-4 to CDI_data/drought_indices/CDI/CDI_IP_2004_4.tif
#
# 2004-05-01 00:00:00
# 	saving final CDI image for 2004-5 to CDI_data/drought_indices/CDI/CDI_IP_2004_5.tif
#
# 2004-06-01 00:00:00
# 	saving final CDI image for 2004-6 to CDI_data/drought_indices/CDI/CDI_IP_2004_6.tif
#
# 2004-07-01 00:00:00
# 	saving final CDI image for 2004-7 to CDI_data/drought_indices/CDI/CDI_IP_2004_7.tif
#
# 2004-08-01 00:00:00
# 	saving final CDI image for 2004-8 to CDI_data/drought_indices/CDI/CDI_IP_2004_8.tif
#
# 2004-09-01 00:00:00
# 	saving final CDI image for 2004-9 to CDI_data/drought_indices/CDI/CDI_IP_2004_9.tif
#
# 2004-10-01 00:00:00
# 	saving final CDI image for 2004-10 to CDI_data/drought_indices/CDI/CDI_IP_2004_10.tif
#
# 2004-11-01 00:00:00
# 	saving final CDI image for 2004-11 to CDI_data/drought_indices/CDI/CDI_IP_2004_11.tif
#
# 2004-12-01 00:00:00
# 	saving final CDI image for 2004-12 to CDI_data/drought_indices/CDI/CDI_IP_2004_12.tif
#
# 2005-01-01 00:00:00
# 	saving final CDI image for 2005-1 to CDI_data/drought_indices/CDI/CDI_IP_2005_1.tif
#
# 2005-02-01 00:00:00
# 	saving final CDI image for 2005-2 to CDI_data/drought_indices/CDI/CDI_IP_2005_2.tif
#
# 2005-03-01 00:00:00
# 	saving final CDI image for 2005-3 to CDI_data/drought_indices/CDI/CDI_IP_2005_3.tif
#
# 2005-04-01 00:00:00
# 	saving final CDI image for 2005-4 to CDI_data/drought_indices/CDI/CDI_IP_2005_4.tif
#
# 2005-05-01 00:00:00
# 	saving final CDI image for 2005-5 to CDI_data/drought_indices/CDI/CDI_IP_2005_5.tif
#
# 2005-06-01 00:00:00
# 	saving final CDI image for 2005-6 to CDI_data/drought_indices/CDI/CDI_IP_2005_6.tif
#
# 2005-07-01 00:00:00
# 	saving final CDI image for 2005-7 to CDI_data/drought_indices/CDI/CDI_IP_2005_7.tif
#
# 2005-08-01 00:00:00
# 	saving final CDI image for 2005-8 to CDI_data/drought_indices/CDI/CDI_IP_2005_8.tif
#
# 2005-09-01 00:00:00
# 	saving final CDI image for 2005-9 to CDI_data/drought_indices/CDI/CDI_IP_2005_9.tif
#
# 2005-10-01 00:00:00
# 	saving final CDI image for 2005-10 to CDI_data/drought_indices/CDI/CDI_IP_2005_10.tif
#
# 2005-11-01 00:00:00
# 	saving final CDI image for 2005-11 to CDI_data/drought_indices/CDI/CDI_IP_2005_11.tif
#
# 2005-12-01 00:00:00
# 	saving final CDI image for 2005-12 to CDI_data/drought_indices/CDI/CDI_IP_2005_12.tif
#
# 2006-01-01 00:00:00
# 	saving final CDI image for 2006-1 to CDI_data/drought_indices/CDI/CDI_IP_2006_1.tif
#
# 2006-02-01 00:00:00
# 	saving final CDI image for 2006-2 to CDI_data/drought_indices/CDI/CDI_IP_2006_2.tif
#
# 2006-03-01 00:00:00
# 	saving final CDI image for 2006-3 to CDI_data/drought_indices/CDI/CDI_IP_2006_3.tif
#
# 2006-04-01 00:00:00
# 	saving final CDI image for 2006-4 to CDI_data/drought_indices/CDI/CDI_IP_2006_4.tif
#
# 2006-05-01 00:00:00
# 	saving final CDI image for 2006-5 to CDI_data/drought_indices/CDI/CDI_IP_2006_5.tif
#
# 2006-06-01 00:00:00
# 	saving final CDI image for 2006-6 to CDI_data/drought_indices/CDI/CDI_IP_2006_6.tif
#
# 2006-07-01 00:00:00
# 	saving final CDI image for 2006-7 to CDI_data/drought_indices/CDI/CDI_IP_2006_7.tif
#
# 2006-08-01 00:00:00
# 	saving final CDI image for 2006-8 to CDI_data/drought_indices/CDI/CDI_IP_2006_8.tif
#
# 2006-09-01 00:00:00
# 	saving final CDI image for 2006-9 to CDI_data/drought_indices/CDI/CDI_IP_2006_9.tif
#
# 2006-10-01 00:00:00
# 	saving final CDI image for 2006-10 to CDI_data/drought_indices/CDI/CDI_IP_2006_10.tif
#
# 2006-11-01 00:00:00
# 	saving final CDI image for 2006-11 to CDI_data/drought_indices/CDI/CDI_IP_2006_11.tif
#
# 2006-12-01 00:00:00
# 	saving final CDI image for 2006-12 to CDI_data/drought_indices/CDI/CDI_IP_2006_12.tif
#
# 2007-01-01 00:00:00
# 	saving final CDI image for 2007-1 to CDI_data/drought_indices/CDI/CDI_IP_2007_1.tif
#
# 2007-02-01 00:00:00
# 	saving final CDI image for 2007-2 to CDI_data/drought_indices/CDI/CDI_IP_2007_2.tif
#
# 2007-03-01 00:00:00
# 	saving final CDI image for 2007-3 to CDI_data/drought_indices/CDI/CDI_IP_2007_3.tif
#
# 2007-04-01 00:00:00
# 	saving final CDI image for 2007-4 to CDI_data/drought_indices/CDI/CDI_IP_2007_4.tif
#
# 2007-05-01 00:00:00
# 	saving final CDI image for 2007-5 to CDI_data/drought_indices/CDI/CDI_IP_2007_5.tif
#
# 2007-06-01 00:00:00
# 	saving final CDI image for 2007-6 to CDI_data/drought_indices/CDI/CDI_IP_2007_6.tif
#
# 2007-07-01 00:00:00
# 	saving final CDI image for 2007-7 to CDI_data/drought_indices/CDI/CDI_IP_2007_7.tif
#
# 2007-08-01 00:00:00
# 	saving final CDI image for 2007-8 to CDI_data/drought_indices/CDI/CDI_IP_2007_8.tif
#
# 2007-09-01 00:00:00
# 	saving final CDI image for 2007-9 to CDI_data/drought_indices/CDI/CDI_IP_2007_9.tif
#
# 2007-10-01 00:00:00
# 	saving final CDI image for 2007-10 to CDI_data/drought_indices/CDI/CDI_IP_2007_10.tif
#
# 2007-11-01 00:00:00
# 	saving final CDI image for 2007-11 to CDI_data/drought_indices/CDI/CDI_IP_2007_11.tif
#
# 2007-12-01 00:00:00
# 	saving final CDI image for 2007-12 to CDI_data/drought_indices/CDI/CDI_IP_2007_12.tif
#
# 2008-01-01 00:00:00
# 	saving final CDI image for 2008-1 to CDI_data/drought_indices/CDI/CDI_IP_2008_1.tif
#
# 2008-02-01 00:00:00
# 	saving final CDI image for 2008-2 to CDI_data/drought_indices/CDI/CDI_IP_2008_2.tif
#
# 2008-03-01 00:00:00
# 	saving final CDI image for 2008-3 to CDI_data/drought_indices/CDI/CDI_IP_2008_3.tif
#
# 2008-04-01 00:00:00
# 	saving final CDI image for 2008-4 to CDI_data/drought_indices/CDI/CDI_IP_2008_4.tif
#
# 2008-05-01 00:00:00
# 	saving final CDI image for 2008-5 to CDI_data/drought_indices/CDI/CDI_IP_2008_5.tif
#
# 2008-06-01 00:00:00
# 	saving final CDI image for 2008-6 to CDI_data/drought_indices/CDI/CDI_IP_2008_6.tif
#
# 2008-07-01 00:00:00
# 	saving final CDI image for 2008-7 to CDI_data/drought_indices/CDI/CDI_IP_2008_7.tif
#
# 2008-08-01 00:00:00
# 	saving final CDI image for 2008-8 to CDI_data/drought_indices/CDI/CDI_IP_2008_8.tif
#
# 2008-09-01 00:00:00
# 	saving final CDI image for 2008-9 to CDI_data/drought_indices/CDI/CDI_IP_2008_9.tif
#
# 2008-10-01 00:00:00
# 	saving final CDI image for 2008-10 to CDI_data/drought_indices/CDI/CDI_IP_2008_10.tif
#
# 2008-11-01 00:00:00
# 	saving final CDI image for 2008-11 to CDI_data/drought_indices/CDI/CDI_IP_2008_11.tif
#
# 2008-12-01 00:00:00
# 	saving final CDI image for 2008-12 to CDI_data/drought_indices/CDI/CDI_IP_2008_12.tif
#
# 2009-01-01 00:00:00
# 	saving final CDI image for 2009-1 to CDI_data/drought_indices/CDI/CDI_IP_2009_1.tif
#
# 2009-02-01 00:00:00
# 	saving final CDI image for 2009-2 to CDI_data/drought_indices/CDI/CDI_IP_2009_2.tif
#
# 2009-03-01 00:00:00
# 	saving final CDI image for 2009-3 to CDI_data/drought_indices/CDI/CDI_IP_2009_3.tif
#
# 2009-04-01 00:00:00
# 	saving final CDI image for 2009-4 to CDI_data/drought_indices/CDI/CDI_IP_2009_4.tif
#
# 2009-05-01 00:00:00
# 	saving final CDI image for 2009-5 to CDI_data/drought_indices/CDI/CDI_IP_2009_5.tif
#
# 2009-06-01 00:00:00
# 	saving final CDI image for 2009-6 to CDI_data/drought_indices/CDI/CDI_IP_2009_6.tif
#
# 2009-07-01 00:00:00
# 	saving final CDI image for 2009-7 to CDI_data/drought_indices/CDI/CDI_IP_2009_7.tif
#
# 2009-08-01 00:00:00
# 	saving final CDI image for 2009-8 to CDI_data/drought_indices/CDI/CDI_IP_2009_8.tif
#
# 2009-09-01 00:00:00
# 	saving final CDI image for 2009-9 to CDI_data/drought_indices/CDI/CDI_IP_2009_9.tif
#
# 2009-10-01 00:00:00
# 	saving final CDI image for 2009-10 to CDI_data/drought_indices/CDI/CDI_IP_2009_10.tif
#
# 2009-11-01 00:00:00
# 	saving final CDI image for 2009-11 to CDI_data/drought_indices/CDI/CDI_IP_2009_11.tif
#
# 2009-12-01 00:00:00
# 	saving final CDI image for 2009-12 to CDI_data/drought_indices/CDI/CDI_IP_2009_12.tif
#
# 2010-01-01 00:00:00
# 	saving final CDI image for 2010-1 to CDI_data/drought_indices/CDI/CDI_IP_2010_1.tif
#
# 2010-02-01 00:00:00
# 	saving final CDI image for 2010-2 to CDI_data/drought_indices/CDI/CDI_IP_2010_2.tif
#
# 2010-03-01 00:00:00
# 	saving final CDI image for 2010-3 to CDI_data/drought_indices/CDI/CDI_IP_2010_3.tif
#
# 2010-04-01 00:00:00
# 	saving final CDI image for 2010-4 to CDI_data/drought_indices/CDI/CDI_IP_2010_4.tif
#
# 2010-05-01 00:00:00
# 	saving final CDI image for 2010-5 to CDI_data/drought_indices/CDI/CDI_IP_2010_5.tif
#
# 2010-06-01 00:00:00
# 	saving final CDI image for 2010-6 to CDI_data/drought_indices/CDI/CDI_IP_2010_6.tif
#
# 2010-07-01 00:00:00
# 	saving final CDI image for 2010-7 to CDI_data/drought_indices/CDI/CDI_IP_2010_7.tif
#
# 2010-08-01 00:00:00
# 	saving final CDI image for 2010-8 to CDI_data/drought_indices/CDI/CDI_IP_2010_8.tif
#
# 2010-09-01 00:00:00
# 	saving final CDI image for 2010-9 to CDI_data/drought_indices/CDI/CDI_IP_2010_9.tif
#
# 2010-10-01 00:00:00
# 	saving final CDI image for 2010-10 to CDI_data/drought_indices/CDI/CDI_IP_2010_10.tif
#
# 2010-11-01 00:00:00
# 	saving final CDI image for 2010-11 to CDI_data/drought_indices/CDI/CDI_IP_2010_11.tif
#
# 2010-12-01 00:00:00
# 	saving final CDI image for 2010-12 to CDI_data/drought_indices/CDI/CDI_IP_2010_12.tif
#
# 2011-01-01 00:00:00
# 	saving final CDI image for 2011-1 to CDI_data/drought_indices/CDI/CDI_IP_2011_1.tif
#
# 2011-02-01 00:00:00
# 	saving final CDI image for 2011-2 to CDI_data/drought_indices/CDI/CDI_IP_2011_2.tif
#
# 2011-03-01 00:00:00
# 	saving final CDI image for 2011-3 to CDI_data/drought_indices/CDI/CDI_IP_2011_3.tif
#
# 2011-04-01 00:00:00
# 	saving final CDI image for 2011-4 to CDI_data/drought_indices/CDI/CDI_IP_2011_4.tif
#
# 2011-05-01 00:00:00
# 	saving final CDI image for 2011-5 to CDI_data/drought_indices/CDI/CDI_IP_2011_5.tif
#
# 2011-06-01 00:00:00
# 	saving final CDI image for 2011-6 to CDI_data/drought_indices/CDI/CDI_IP_2011_6.tif
#
# 2011-07-01 00:00:00
# 	saving final CDI image for 2011-7 to CDI_data/drought_indices/CDI/CDI_IP_2011_7.tif
#
# 2011-08-01 00:00:00
# 	saving final CDI image for 2011-8 to CDI_data/drought_indices/CDI/CDI_IP_2011_8.tif
#
# 2011-09-01 00:00:00
# 	saving final CDI image for 2011-9 to CDI_data/drought_indices/CDI/CDI_IP_2011_9.tif
#
# 2011-10-01 00:00:00
# 	saving final CDI image for 2011-10 to CDI_data/drought_indices/CDI/CDI_IP_2011_10.tif
#
# 2011-11-01 00:00:00
# 	saving final CDI image for 2011-11 to CDI_data/drought_indices/CDI/CDI_IP_2011_11.tif
#
# 2011-12-01 00:00:00
# 	saving final CDI image for 2011-12 to CDI_data/drought_indices/CDI/CDI_IP_2011_12.tif
#
# 2012-01-01 00:00:00
# 	saving final CDI image for 2012-1 to CDI_data/drought_indices/CDI/CDI_IP_2012_1.tif
#
# 2012-02-01 00:00:00
# 	saving final CDI image for 2012-2 to CDI_data/drought_indices/CDI/CDI_IP_2012_2.tif
#
# 2012-03-01 00:00:00
# 	saving final CDI image for 2012-3 to CDI_data/drought_indices/CDI/CDI_IP_2012_3.tif
#
# 2012-04-01 00:00:00
# 	saving final CDI image for 2012-4 to CDI_data/drought_indices/CDI/CDI_IP_2012_4.tif
#
# 2012-05-01 00:00:00
# 	saving final CDI image for 2012-5 to CDI_data/drought_indices/CDI/CDI_IP_2012_5.tif
#
# 2012-06-01 00:00:00
# 	saving final CDI image for 2012-6 to CDI_data/drought_indices/CDI/CDI_IP_2012_6.tif
#
# 2012-07-01 00:00:00
# 	saving final CDI image for 2012-7 to CDI_data/drought_indices/CDI/CDI_IP_2012_7.tif
#
# 2012-08-01 00:00:00
# 	saving final CDI image for 2012-8 to CDI_data/drought_indices/CDI/CDI_IP_2012_8.tif
#
# 2012-09-01 00:00:00
# 	saving final CDI image for 2012-9 to CDI_data/drought_indices/CDI/CDI_IP_2012_9.tif
#
# 2012-10-01 00:00:00
# 	saving final CDI image for 2012-10 to CDI_data/drought_indices/CDI/CDI_IP_2012_10.tif
#
# 2012-11-01 00:00:00
# 	saving final CDI image for 2012-11 to CDI_data/drought_indices/CDI/CDI_IP_2012_11.tif
#
# 2012-12-01 00:00:00
# 	saving final CDI image for 2012-12 to CDI_data/drought_indices/CDI/CDI_IP_2012_12.tif
#
# 2013-01-01 00:00:00
# 	saving final CDI image for 2013-1 to CDI_data/drought_indices/CDI/CDI_IP_2013_1.tif
#
# 2013-02-01 00:00:00
# 	saving final CDI image for 2013-2 to CDI_data/drought_indices/CDI/CDI_IP_2013_2.tif
#
# 2013-03-01 00:00:00
# 	saving final CDI image for 2013-3 to CDI_data/drought_indices/CDI/CDI_IP_2013_3.tif
#
# 2013-04-01 00:00:00
# 	saving final CDI image for 2013-4 to CDI_data/drought_indices/CDI/CDI_IP_2013_4.tif
#
# 2013-05-01 00:00:00
# 	saving final CDI image for 2013-5 to CDI_data/drought_indices/CDI/CDI_IP_2013_5.tif
#
# 2013-06-01 00:00:00
# 	saving final CDI image for 2013-6 to CDI_data/drought_indices/CDI/CDI_IP_2013_6.tif
#
# 2013-07-01 00:00:00
# 	saving final CDI image for 2013-7 to CDI_data/drought_indices/CDI/CDI_IP_2013_7.tif
#
# 2013-08-01 00:00:00
# 	saving final CDI image for 2013-8 to CDI_data/drought_indices/CDI/CDI_IP_2013_8.tif
#
# 2013-09-01 00:00:00
# 	saving final CDI image for 2013-9 to CDI_data/drought_indices/CDI/CDI_IP_2013_9.tif
#
# 2013-10-01 00:00:00
# 	saving final CDI image for 2013-10 to CDI_data/drought_indices/CDI/CDI_IP_2013_10.tif
#
# 2013-11-01 00:00:00
# 	saving final CDI image for 2013-11 to CDI_data/drought_indices/CDI/CDI_IP_2013_11.tif
#
# 2013-12-01 00:00:00
# 	saving final CDI image for 2013-12 to CDI_data/drought_indices/CDI/CDI_IP_2013_12.tif
#
# 2014-01-01 00:00:00
# 	saving final CDI image for 2014-1 to CDI_data/drought_indices/CDI/CDI_IP_2014_1.tif
#
# 2014-02-01 00:00:00
# 	saving final CDI image for 2014-2 to CDI_data/drought_indices/CDI/CDI_IP_2014_2.tif
#
# 2014-03-01 00:00:00
# 	saving final CDI image for 2014-3 to CDI_data/drought_indices/CDI/CDI_IP_2014_3.tif
#
# 2014-04-01 00:00:00
# 	saving final CDI image for 2014-4 to CDI_data/drought_indices/CDI/CDI_IP_2014_4.tif
#
# 2014-05-01 00:00:00
# 	saving final CDI image for 2014-5 to CDI_data/drought_indices/CDI/CDI_IP_2014_5.tif
#
# 2014-06-01 00:00:00
# 	saving final CDI image for 2014-6 to CDI_data/drought_indices/CDI/CDI_IP_2014_6.tif
#
# 2014-07-01 00:00:00
# 	saving final CDI image for 2014-7 to CDI_data/drought_indices/CDI/CDI_IP_2014_7.tif
#
# 2014-08-01 00:00:00
# 	saving final CDI image for 2014-8 to CDI_data/drought_indices/CDI/CDI_IP_2014_8.tif
#
# 2014-09-01 00:00:00
# 	saving final CDI image for 2014-9 to CDI_data/drought_indices/CDI/CDI_IP_2014_9.tif
#
# 2014-10-01 00:00:00
# 	saving final CDI image for 2014-10 to CDI_data/drought_indices/CDI/CDI_IP_2014_10.tif
#
# 2014-11-01 00:00:00
# 	saving final CDI image for 2014-11 to CDI_data/drought_indices/CDI/CDI_IP_2014_11.tif
#
# 2014-12-01 00:00:00
# 	saving final CDI image for 2014-12 to CDI_data/drought_indices/CDI/CDI_IP_2014_12.tif
#
# 2015-01-01 00:00:00
# 	saving final CDI image for 2015-1 to CDI_data/drought_indices/CDI/CDI_IP_2015_1.tif
#
# 2015-02-01 00:00:00
# 	saving final CDI image for 2015-2 to CDI_data/drought_indices/CDI/CDI_IP_2015_2.tif
#
# 2015-03-01 00:00:00
# 	saving final CDI image for 2015-3 to CDI_data/drought_indices/CDI/CDI_IP_2015_3.tif
#
# 2015-04-01 00:00:00
# 	saving final CDI image for 2015-4 to CDI_data/drought_indices/CDI/CDI_IP_2015_4.tif
#
# 2015-05-01 00:00:00
# 	saving final CDI image for 2015-5 to CDI_data/drought_indices/CDI/CDI_IP_2015_5.tif
#
# 2015-06-01 00:00:00
# 	saving final CDI image for 2015-6 to CDI_data/drought_indices/CDI/CDI_IP_2015_6.tif
#
# 2015-07-01 00:00:00
# 	saving final CDI image for 2015-7 to CDI_data/drought_indices/CDI/CDI_IP_2015_7.tif
#
# 2015-08-01 00:00:00
# 	saving final CDI image for 2015-8 to CDI_data/drought_indices/CDI/CDI_IP_2015_8.tif
#
# 2015-09-01 00:00:00
# 	saving final CDI image for 2015-9 to CDI_data/drought_indices/CDI/CDI_IP_2015_9.tif
#
# 2015-10-01 00:00:00
# 	saving final CDI image for 2015-10 to CDI_data/drought_indices/CDI/CDI_IP_2015_10.tif
#
# 2015-11-01 00:00:00
# 	saving final CDI image for 2015-11 to CDI_data/drought_indices/CDI/CDI_IP_2015_11.tif
#
# 2015-12-01 00:00:00
# 	saving final CDI image for 2015-12 to CDI_data/drought_indices/CDI/CDI_IP_2015_12.tif
#
# 2016-01-01 00:00:00
# 	saving final CDI image for 2016-1 to CDI_data/drought_indices/CDI/CDI_IP_2016_1.tif
#
# 2016-02-01 00:00:00
# 	saving final CDI image for 2016-2 to CDI_data/drought_indices/CDI/CDI_IP_2016_2.tif
#
# 2016-03-01 00:00:00
# 	saving final CDI image for 2016-3 to CDI_data/drought_indices/CDI/CDI_IP_2016_3.tif
#
# 2016-04-01 00:00:00
# 	saving final CDI image for 2016-4 to CDI_data/drought_indices/CDI/CDI_IP_2016_4.tif
#
# 2016-05-01 00:00:00
# 	saving final CDI image for 2016-5 to CDI_data/drought_indices/CDI/CDI_IP_2016_5.tif
#
# 2016-06-01 00:00:00
# 	saving final CDI image for 2016-6 to CDI_data/drought_indices/CDI/CDI_IP_2016_6.tif
#
# 2016-07-01 00:00:00
# 	saving final CDI image for 2016-7 to CDI_data/drought_indices/CDI/CDI_IP_2016_7.tif
#
# 2016-08-01 00:00:00
# 	saving final CDI image for 2016-8 to CDI_data/drought_indices/CDI/CDI_IP_2016_8.tif
#
# 2016-09-01 00:00:00
# 	saving final CDI image for 2016-9 to CDI_data/drought_indices/CDI/CDI_IP_2016_9.tif
#
# 2016-10-01 00:00:00
# 	saving final CDI image for 2016-10 to CDI_data/drought_indices/CDI/CDI_IP_2016_10.tif
#
# 2016-11-01 00:00:00
# 	saving final CDI image for 2016-11 to CDI_data/drought_indices/CDI/CDI_IP_2016_11.tif
#
# 2016-12-01 00:00:00
# 	saving final CDI image for 2016-12 to CDI_data/drought_indices/CDI/CDI_IP_2016_12.tif
#
# 2017-01-01 00:00:00
# 	saving final CDI image for 2017-1 to CDI_data/drought_indices/CDI/CDI_IP_2017_1.tif
#
# 2017-02-01 00:00:00
# 	saving final CDI image for 2017-2 to CDI_data/drought_indices/CDI/CDI_IP_2017_2.tif
#
# 2017-03-01 00:00:00
# 	saving final CDI image for 2017-3 to CDI_data/drought_indices/CDI/CDI_IP_2017_3.tif
#
# 2017-04-01 00:00:00
# 	saving final CDI image for 2017-4 to CDI_data/drought_indices/CDI/CDI_IP_2017_4.tif
#
# 2017-05-01 00:00:00
# 	saving final CDI image for 2017-5 to CDI_data/drought_indices/CDI/CDI_IP_2017_5.tif
#
# 2017-06-01 00:00:00
# 	saving final CDI image for 2017-6 to CDI_data/drought_indices/CDI/CDI_IP_2017_6.tif
#
# 2017-07-01 00:00:00
# 	saving final CDI image for 2017-7 to CDI_data/drought_indices/CDI/CDI_IP_2017_7.tif
#
# 2017-08-01 00:00:00
# 	saving final CDI image for 2017-8 to CDI_data/drought_indices/CDI/CDI_IP_2017_8.tif
#
# 2017-09-01 00:00:00
# 	saving final CDI image for 2017-9 to CDI_data/drought_indices/CDI/CDI_IP_2017_9.tif
#
# 2017-10-01 00:00:00
# 	saving final CDI image for 2017-10 to CDI_data/drought_indices/CDI/CDI_IP_2017_10.tif
#
# 2017-11-01 00:00:00
# 	saving final CDI image for 2017-11 to CDI_data/drought_indices/CDI/CDI_IP_2017_11.tif
#
# 2017-12-01 00:00:00
# 	saving final CDI image for 2017-12 to CDI_data/drought_indices/CDI/CDI_IP_2017_12.tif
#
# 2018-01-01 00:00:00
# 	saving final CDI image for 2018-1 to CDI_data/drought_indices/CDI/CDI_IP_2018_1.tif
#
# 2018-02-01 00:00:00
# 	saving final CDI image for 2018-2 to CDI_data/drought_indices/CDI/CDI_IP_2018_2.tif
#
# 2018-03-01 00:00:00
# 	saving final CDI image for 2018-3 to CDI_data/drought_indices/CDI/CDI_IP_2018_3.tif
#
# 2018-04-01 00:00:00
# 	saving final CDI image for 2018-4 to CDI_data/drought_indices/CDI/CDI_IP_2018_4.tif
#
# 2018-05-01 00:00:00
# 	saving final CDI image for 2018-5 to CDI_data/drought_indices/CDI/CDI_IP_2018_5.tif
#
# 2018-06-01 00:00:00
# 	saving final CDI image for 2018-6 to CDI_data/drought_indices/CDI/CDI_IP_2018_6.tif
#
# 2018-07-01 00:00:00
# 	saving final CDI image for 2018-7 to CDI_data/drought_indices/CDI/CDI_IP_2018_7.tif
#
# 2018-08-01 00:00:00
# 	saving final CDI image for 2018-8 to CDI_data/drought_indices/CDI/CDI_IP_2018_8.tif
#
# 2018-09-01 00:00:00
# 	saving final CDI image for 2018-9 to CDI_data/drought_indices/CDI/CDI_IP_2018_9.tif
#
# 2018-10-01 00:00:00
# 	saving final CDI image for 2018-10 to CDI_data/drought_indices/CDI/CDI_IP_2018_10.tif
#
# 2018-11-01 00:00:00
# 	saving final CDI image for 2018-11 to CDI_data/drought_indices/CDI/CDI_IP_2018_11.tif
#
# 2018-12-01 00:00:00
# 	saving final CDI image for 2018-12 to CDI_data/drought_indices/CDI/CDI_IP_2018_12.tif
#
# 2019-01-01 00:00:00
# 	saving final CDI image for 2019-1 to CDI_data/drought_indices/CDI/CDI_IP_2019_1.tif
#
# 2019-02-01 00:00:00
# 	saving final CDI image for 2019-2 to CDI_data/drought_indices/CDI/CDI_IP_2019_2.tif
#
# 2019-03-01 00:00:00
# 	saving final CDI image for 2019-3 to CDI_data/drought_indices/CDI/CDI_IP_2019_3.tif
#
# 2019-04-01 00:00:00
# 	saving final CDI image for 2019-4 to CDI_data/drought_indices/CDI/CDI_IP_2019_4.tif
#
# 2019-05-01 00:00:00
# 	saving final CDI image for 2019-5 to CDI_data/drought_indices/CDI/CDI_IP_2019_5.tif
#
# 2019-06-01 00:00:00
# 	saving final CDI image for 2019-6 to CDI_data/drought_indices/CDI/CDI_IP_2019_6.tif
#
# 2019-07-01 00:00:00
# 	saving final CDI image for 2019-7 to CDI_data/drought_indices/CDI/CDI_IP_2019_7.tif
#
# 2019-08-01 00:00:00
# 	saving final CDI image for 2019-8 to CDI_data/drought_indices/CDI/CDI_IP_2019_8.tif
#
# 2019-09-01 00:00:00
# 	saving final CDI image for 2019-9 to CDI_data/drought_indices/CDI/CDI_IP_2019_9.tif
#
# 2019-10-01 00:00:00
# 	saving final CDI image for 2019-10 to CDI_data/drought_indices/CDI/CDI_IP_2019_10.tif
#
# 2019-11-01 00:00:00
# 	saving final CDI image for 2019-11 to CDI_data/drought_indices/CDI/CDI_IP_2019_11.tif
#
# 2019-12-01 00:00:00
# 	saving final CDI image for 2019-12 to CDI_data/drought_indices/CDI/CDI_IP_2019_12.tif
#
# 2020-01-01 00:00:00
# 	saving final CDI image for 2020-1 to CDI_data/drought_indices/CDI/CDI_IP_2020_1.tif
#
# 2020-02-01 00:00:00
# 	saving final CDI image for 2020-2 to CDI_data/drought_indices/CDI/CDI_IP_2020_2.tif
#
# 2020-03-01 00:00:00
# 	saving final CDI image for 2020-3 to CDI_data/drought_indices/CDI/CDI_IP_2020_3.tif
#
# 2020-04-01 00:00:00
# 	saving final CDI image for 2020-4 to CDI_data/drought_indices/CDI/CDI_IP_2020_4.tif
#
# 2020-05-01 00:00:00
# 	saving final CDI image for 2020-5 to CDI_data/drought_indices/CDI/CDI_IP_2020_5.tif
#
# 2020-06-01 00:00:00
# 	saving final CDI image for 2020-6 to CDI_data/drought_indices/CDI/CDI_IP_2020_6.tif
#
# 2020-07-01 00:00:00
# 	saving final CDI image for 2020-7 to CDI_data/drought_indices/CDI/CDI_IP_2020_7.tif
#
# 2020-08-01 00:00:00
# 	saving final CDI image for 2020-8 to CDI_data/drought_indices/CDI/CDI_IP_2020_8.tif
#
# 2020-09-01 00:00:00
# 	saving final CDI image for 2020-9 to CDI_data/drought_indices/CDI/CDI_IP_2020_9.tif
#
# 2020-10-01 00:00:00
# 	saving final CDI image for 2020-10 to CDI_data/drought_indices/CDI/CDI_IP_2020_10.tif
#
# 2020-11-01 00:00:00
# 	saving final CDI image for 2020-11 to CDI_data/drought_indices/CDI/CDI_IP_2020_11.tif
#
# 2020-12-01 00:00:00
# 	saving final CDI image for 2020-12 to CDI_data/drought_indices/CDI/CDI_IP_2020_12.tif
#
# 2021-01-01 00:00:00
# 	saving final CDI image for 2021-1 to CDI_data/drought_indices/CDI/CDI_IP_2021_1.tif
#
# 2021-02-01 00:00:00
# 	saving final CDI image for 2021-2 to CDI_data/drought_indices/CDI/CDI_IP_2021_2.tif
#
# 2021-03-01 00:00:00
# 	saving final CDI image for 2021-3 to CDI_data/drought_indices/CDI/CDI_IP_2021_3.tif
#
# 2021-04-01 00:00:00
# 	saving final CDI image for 2021-4 to CDI_data/drought_indices/CDI/CDI_IP_2021_4.tif
#
# 2021-05-01 00:00:00
# 	saving final CDI image for 2021-5 to CDI_data/drought_indices/CDI/CDI_IP_2021_5.tif
#
# 2021-06-01 00:00:00
# 	saving final CDI image for 2021-6 to CDI_data/drought_indices/CDI/CDI_IP_2021_6.tif
#
# 2021-07-01 00:00:00
# 	saving final CDI image for 2021-7 to CDI_data/drought_indices/CDI/CDI_IP_2021_7.tif
#
# 2021-08-01 00:00:00
# 	saving final CDI image for 2021-8 to CDI_data/drought_indices/CDI/CDI_IP_2021_8.tif
#
# 2021-09-01 00:00:00
# 	saving final CDI image for 2021-9 to CDI_data/drought_indices/CDI/CDI_IP_2021_9.tif
#
# 2021-10-01 00:00:00
# 	saving final CDI image for 2021-10 to CDI_data/drought_indices/CDI/CDI_IP_2021_10.tif
#
# 2021-11-01 00:00:00
# 	saving final CDI image for 2021-11 to CDI_data/drought_indices/CDI/CDI_IP_2021_11.tif
#
# 2021-12-01 00:00:00
# 	saving final CDI image for 2021-12 to CDI_data/drought_indices/CDI/CDI_IP_2021_12.tif
#
# 2022-01-01 00:00:00
# 	saving final CDI image for 2022-1 to CDI_data/drought_indices/CDI/CDI_IP_2022_1.tif
#
# 2022-02-01 00:00:00
# 	saving final CDI image for 2022-2 to CDI_data/drought_indices/CDI/CDI_IP_2022_2.tif
#
# 2022-03-01 00:00:00
# 	saving final CDI image for 2022-3 to CDI_data/drought_indices/CDI/CDI_IP_2022_3.tif
#
# 2022-04-01 00:00:00
# 	saving final CDI image for 2022-4 to CDI_data/drought_indices/CDI/CDI_IP_2022_4.tif
#
# 2022-05-01 00:00:00
# 	saving final CDI image for 2022-5 to CDI_data/drought_indices/CDI/CDI_IP_2022_5.tif
#
# 2022-06-01 00:00:00
# 	saving final CDI image for 2022-6 to CDI_data/drought_indices/CDI/CDI_IP_2022_6.tif
#
# 2022-07-01 00:00:00
# 	saving final CDI image for 2022-7 to CDI_data/drought_indices/CDI/CDI_IP_2022_7.tif
#
# 2022-08-01 00:00:00
# 	saving final CDI image for 2022-8 to CDI_data/drought_indices/CDI/CDI_IP_2022_8.tif
#
# 2022-09-01 00:00:00
# 	saving final CDI image for 2022-9 to CDI_data/drought_indices/CDI/CDI_IP_2022_9.tif
#
# 2022-10-01 00:00:00
# 	saving final CDI image for 2022-10 to CDI_data/drought_indices/CDI/CDI_IP_2022_10.tif
#
# 2022-11-01 00:00:00
# 	saving final CDI image for 2022-11 to CDI_data/drought_indices/CDI/CDI_IP_2022_11.tif
#
# 2022-12-01 00:00:00
# 	saving final CDI image for 2022-12 to CDI_data/drought_indices/CDI/CDI_IP_2022_12.tif

# %% [markdown]
# #### 4.2 Visualizing results
# Here we can visualize some of the results using Leafmap
#
# CDI values higher than 1 indicates no drought warning while any CDI value below 1 should be considered as possible drought warning:
#
# ![CDI values](images/cdi_value_range.png)

# %%
from leafmap import leafmap
import rasterio

# output CDI folder
cdi_folder =  outfolder/'CDI'

# choose image to show
# choose year and month
year = 2021
month = 3 

img = cdi_folder / f'CDI_IP_{year}_{month}.tif'
m = leafmap.Map(center=(lat, lon), zoom=8)

# add CDI raster from march 
fid = rasterio.open(str(img))
m.add_raster(fid, colormap="Spectral", layer_name=f"{year} month {month}", vmin=0.4, vmax=1)

# add CDI raster from Sept 
month = 9
img = cdi_folder / f'CDI_IP_{year}_{month}.tif'
fid2 = rasterio.open(str(img))
m.add_raster(fid2, colormap="Spectral", layer_name=f"{year} month {month}", vmin=0.4, vmax=1)

params = {
    "width": 4.0,
    "height": 0.3,
    "vmin": 0.4,
    "vmax": 1,
    "cmap": "Spectral",
    "label": "CDI ()",
    "orientation": "horizontal",
}
m.add_colormap(position='bottomright', **params)
m
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from leafmap import leafmap
#       2 import rasterio
#       4 # output CDI folder
#
# ModuleNotFoundError: No module named 'leafmap'
